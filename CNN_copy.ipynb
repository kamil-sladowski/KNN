# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilo116/KNN/blob/master/CNN_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import os
import csv
import sys
from random import shuffle
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
# %matplotlib inline
from sklearn.model_selection import train_test_split

import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
from torch.utils.data.sampler import SubsetRandomSampler

import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T
import torchvision.transforms as transforms
from torchvision import models
import timeit

np.random.seed(4) 
torch.manual_seed(4) 
torch.cuda.manual_seed(4)

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! git clone https://github.com/wang-chen/kervolution.git 

sys.path.append("kervolution/")
from kervolution import Kerv2d
# Out:
# fatal: destination path 'kervolution' already exists and is not an empty directory.

# %%
MALIGNANT_DATASET = '/content/drive/My Drive/Colab_data/malignant/malignant/'
BENIGN_DATASET = '/content/drive/My Drive/Colab_data/benign/benign/'
DATA_FOLDER = '/content/drive/My Drive/Colab_data/'
LIMIT_IMAGES_NUM = 700

benign_file_list = sorted(os.listdir(BENIGN_DATASET))[:LIMIT_IMAGES_NUM]
malignant_file_list = sorted(os.listdir(MALIGNANT_DATASET))[:LIMIT_IMAGES_NUM]
shuffle(benign_file_list)
shuffle(malignant_file_list)

print(f"Number of benign {len(benign_file_list)} images")
print(f"Number of malignant {len(malignant_file_list)} images")

data_transforms = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Out:
# Number of benign 700 images
# Number of malignant 700 images

# %%
benign_dict = {filename: 0 for filename in benign_file_list}
malignant_dict = {filename: 1 for filename in malignant_file_list}
img_class_dict = {**benign_dict , **malignant_dict}
labeled_data = pd.Series(img_class_dict)

# %%
class IsicDataset(Dataset):
    def __init__(self, data_folder, labeled_data, 
                 transform=transforms.Compose([transforms.ToTensor()])):
        self.labeled_data = labeled_data
        self.transform = transform
        self.data_folder = data_folder
        
        
    def __len__(self):
        return len(self.labeled_data)

    def __getitem__(self, index):
        label = self.labeled_data[index]
        if label == 0:
          image = Image.open(os.path.join(self.data_folder, "benign", "benign", index ))
        else:
          image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", index ))
        image = self.transform(image)
        return image, label

    @property
    def labels(self):
      return self.labeled_data

# %%
 
dataset = IsicDataset(DATA_FOLDER, labeled_data, transform=data_transforms)
print(dataset.labels)

X_train, X_test = train_test_split(dataset.labels, test_size=0.2)
print("number of training data: ",len(X_train))
print("number of testing  data: ",len(X_test))

train_sampler = SubsetRandomSampler(list(X_train.index))
valid_sampler = SubsetRandomSampler(list(X_test.index))
batch_size = 64
num_workers = 0

train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
# Out:
# ISIC_0000252.jpeg    0
# ISIC_0000478.jpeg    0
# ISIC_0000352.jpeg    0
# ISIC_0001024.jpeg    0
# ISIC_0000108.jpeg    0
#                     ..
# ISIC_0000173.jpeg    1
# ISIC_0010241.jpeg    1
# ISIC_0011811.jpeg    1
# ISIC_0011118.jpeg    1
# ISIC_0011268.jpeg    1
# Length: 1400, dtype: int64
# number of training data:  1120
# number of testing  data:  280

# %%
avg_loss_list = []
acc_list = []

def train(model, train_loader ,loss_fn, optimizer, num_epochs = 1):
    total_loss =0

    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()

        for t, (x, y) in enumerate(train_loader):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())
            scores = model(x_var)
            loss = loss_fn(scores, y_var)
            total_loss += loss.data
            
            if (t + 1) % print_every == 0:
                avg_loss = total_loss/print_every
                print('t = %d, avg_loss = %.4f' % (t + 1, avg_loss) )
                avg_loss_list.append(avg_loss)
                total_loss = 0
                

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        acc = check_accuracy(fixed_model_gpu, valid_loader)
        print('acc = %f' %(acc))
            
def check_accuracy(model, loader):
    print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() 
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype))

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    acc_list.append(acc)
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size()
        return x.view(N, -1)

# %%
print_every = 1
gpu_dtype = torch.cuda.FloatTensor

out_1 = 64
out_2 = 48
out_3 = 32
out_4 = 24
out_5 = 16

k_size_1 = 3
padding_1 = 1
in_channels = 3

num_epochs = 50


fixed_model_base = nn.Sequential( 
                nn.Conv2d(in_channels , out_1, padding= padding_1, kernel_size=k_size_1, stride=1), 
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_1),
                nn.MaxPool2d(2, stride=2),
                nn.Conv2d(out_1 , out_2, padding= padding_1, kernel_size=k_size_1, stride=1), 
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_2),
                nn.MaxPool2d(2, stride=2),
                nn.Conv2d(out_2 , out_3, padding= padding_1, kernel_size=k_size_1, stride=1),  
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_3),
                nn.MaxPool2d(2, stride=2),
                nn.Conv2d(out_3 , out_4, padding= padding_1, kernel_size=k_size_1, stride=1), 
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_4),
                nn.Conv2d(out_4 , out_5, padding= padding_1, kernel_size=k_size_1, stride=1), 
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_5),
                nn.MaxPool2d(2, stride=2),
                nn.Dropout(0.5),
                Flatten(),
                nn.Linear(576,64),
                nn.ReLU(inplace=True),
                nn.Linear(64,10),
                nn.ReLU(inplace=True),
                nn.Linear(10,2)
            )
fixed_model_gpu = fixed_model_base.type(gpu_dtype)
print(fixed_model_gpu)
loss_fn = nn.modules.loss.CrossEntropyLoss()
optimizer = optim.Adam(fixed_model_gpu.parameters(), lr = 0.0011, weight_decay=0.05) 

train(fixed_model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
check_accuracy(fixed_model_gpu, valid_loader)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU(inplace=True)
#   (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (8): Conv2d(48, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (12): Conv2d(32, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): Conv2d(24, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (16): ReLU(inplace=True)
#   (17): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (19): Dropout(p=0.5, inplace=False)
#   (20): Flatten()
#   (21): Linear(in_features=576, out_features=64, bias=True)
#   (22): ReLU(inplace=True)
#   (23): Linear(in_features=64, out_features=10, bias=True)
#   (24): ReLU(inplace=True)
#   (25): Linear(in_features=10, out_features=2, bias=True)
# )
# Starting epoch 1 / 50
# t = 1, avg_loss = 0.7032
# t = 2, avg_loss = 0.7003
# t = 3, avg_loss = 0.6887
# t = 4, avg_loss = 0.6945
# t = 5, avg_loss = 0.6711
# t = 6, avg_loss = 0.6592
# t = 7, avg_loss = 0.6631
# t = 8, avg_loss = 0.6385
# t = 9, avg_loss = 0.6387
# t = 10, avg_loss = 0.6030
# t = 11, avg_loss = 0.6011
# t = 12, avg_loss = 0.5721
# t = 13, avg_loss = 0.5563
# t = 14, avg_loss = 0.5342
# t = 15, avg_loss = 0.4850
# t = 16, avg_loss = 0.6309
# t = 17, avg_loss = 0.4627
# t = 18, avg_loss = 0.5747
# Checking accuracy on test set
# Got 136 / 280 correct (48.57)
# acc = 0.485714
# Starting epoch 2 / 50
# t = 1, avg_loss = 0.5399
# t = 2, avg_loss = 0.4806
# t = 3, avg_loss = 0.3796
# t = 4, avg_loss = 0.5017
# t = 5, avg_loss = 0.4224
# t = 6, avg_loss = 0.4097
# t = 7, avg_loss = 0.5228
# t = 8, avg_loss = 0.5020
# t = 9, avg_loss = 0.4516
# t = 10, avg_loss = 0.4345
# t = 11, avg_loss = 0.4435
# t = 12, avg_loss = 0.3612
# t = 13, avg_loss = 0.5895
# t = 14, avg_loss = 0.4687
# t = 15, avg_loss = 0.3479
# t = 16, avg_loss = 0.3785
# t = 17, avg_loss = 0.4703
# t = 18, avg_loss = 0.4664
# Checking accuracy on test set
# Got 136 / 280 correct (48.57)
# acc = 0.485714
# Starting epoch 3 / 50
# t = 1, avg_loss = 0.4110
# t = 2, avg_loss = 0.4565
# t = 3, avg_loss = 0.3552
# t = 4, avg_loss = 0.3235
# t = 5, avg_loss = 0.4509
# t = 6, avg_loss = 0.4902
# t = 7, avg_loss = 0.3926
# t = 8, avg_loss = 0.4212
# t = 9, avg_loss = 0.4878
# t = 10, avg_loss = 0.4340
# t = 11, avg_loss = 0.4060
# t = 12, avg_loss = 0.5734
# t = 13, avg_loss = 0.3760
# t = 14, avg_loss = 0.4194
# t = 15, avg_loss = 0.4048
# t = 16, avg_loss = 0.4308
# t = 17, avg_loss = 0.5249
# t = 18, avg_loss = 0.5665
# Checking accuracy on test set
# Got 190 / 280 correct (67.86)
# acc = 0.678571
# Starting epoch 4 / 50
# t = 1, avg_loss = 0.4154
# t = 2, avg_loss = 0.5072
# t = 3, avg_loss = 0.4965
# t = 4, avg_loss = 0.4232
# t = 5, avg_loss = 0.5062
# t = 6, avg_loss = 0.4181
# t = 7, avg_loss = 0.3965
# t = 8, avg_loss = 0.4195
# t = 9, avg_loss = 0.4396
# t = 10, avg_loss = 0.4125
# t = 11, avg_loss = 0.3999
# t = 12, avg_loss = 0.3706
# t = 13, avg_loss = 0.3647
# t = 14, avg_loss = 0.3334
# t = 15, avg_loss = 0.4595
# t = 16, avg_loss = 0.4409
# t = 17, avg_loss = 0.5067
# t = 18, avg_loss = 0.3440
# Checking accuracy on test set
# Got 214 / 280 correct (76.43)
# acc = 0.764286
# Starting epoch 5 / 50
# t = 1, avg_loss = 0.4920
# t = 2, avg_loss = 0.4570
# t = 3, avg_loss = 0.4022
# t = 4, avg_loss = 0.4248
# t = 5, avg_loss = 0.4123
# t = 6, avg_loss = 0.3085
# t = 7, avg_loss = 0.6247
# t = 8, avg_loss = 0.3190
# t = 9, avg_loss = 0.3321
# t = 10, avg_loss = 0.3924
# t = 11, avg_loss = 0.4211
# t = 12, avg_loss = 0.3931
# t = 13, avg_loss = 0.5104
# t = 14, avg_loss = 0.2926
# t = 15, avg_loss = 0.3895
# t = 16, avg_loss = 0.3083
# t = 17, avg_loss = 0.3550
# t = 18, avg_loss = 0.4716
# Checking accuracy on test set
# Got 205 / 280 correct (73.21)
# acc = 0.732143
# Starting epoch 6 / 50
# t = 1, avg_loss = 0.3404
# t = 2, avg_loss = 0.3938
# t = 3, avg_loss = 0.3629
# t = 4, avg_loss = 0.3606
# t = 5, avg_loss = 0.4559
# t = 6, avg_loss = 0.5056
# t = 7, avg_loss = 0.4647
# t = 8, avg_loss = 0.4046
# t = 9, avg_loss = 0.5105
# t = 10, avg_loss = 0.4722
# t = 11, avg_loss = 0.5116
# t = 12, avg_loss = 0.4021
# t = 13, avg_loss = 0.3917
# t = 14, avg_loss = 0.4275
# t = 15, avg_loss = 0.5037
# t = 16, avg_loss = 0.3280
# t = 17, avg_loss = 0.4122
# t = 18, avg_loss = 0.4494
# Checking accuracy on test set
# Got 199 / 280 correct (71.07)
# acc = 0.710714
# Starting epoch 7 / 50
# t = 1, avg_loss = 0.3532
# t = 2, avg_loss = 0.3272
# t = 3, avg_loss = 0.4640
# t = 4, avg_loss = 0.4151
# t = 5, avg_loss = 0.4587
# t = 6, avg_loss = 0.4482
# t = 7, avg_loss = 0.3223
# t = 8, avg_loss = 0.3432
# t = 9, avg_loss = 0.4903
# t = 10, avg_loss = 0.3886
# t = 11, avg_loss = 0.2951
# t = 12, avg_loss = 0.3000
# t = 13, avg_loss = 0.4740
# t = 14, avg_loss = 0.5192
# t = 15, avg_loss = 0.3659
# t = 16, avg_loss = 0.4407
# t = 17, avg_loss = 0.3376
# t = 18, avg_loss = 0.4615
# Checking accuracy on test set
# Got 214 / 280 correct (76.43)
# acc = 0.764286
# Starting epoch 8 / 50
# t = 1, avg_loss = 0.3808
# t = 2, avg_loss = 0.3060
# t = 3, avg_loss = 0.3197
# t = 4, avg_loss = 0.4274
# t = 5, avg_loss = 0.3736
# t = 6, avg_loss = 0.3931
# t = 7, avg_loss = 0.3993
# t = 8, avg_loss = 0.3165
# t = 9, avg_loss = 0.3336
# t = 10, avg_loss = 0.3573
# t = 11, avg_loss = 0.3734
# t = 12, avg_loss = 0.2676
# t = 13, avg_loss = 0.3944
# t = 14, avg_loss = 0.4368
# t = 15, avg_loss = 0.3833
# t = 16, avg_loss = 0.5150
# t = 17, avg_loss = 0.3926
# t = 18, avg_loss = 0.4305
# Checking accuracy on test set
# Got 217 / 280 correct (77.50)
# acc = 0.775000
# Starting epoch 9 / 50
# t = 1, avg_loss = 0.3011
# t = 2, avg_loss = 0.2737
# t = 3, avg_loss = 0.3883
# t = 4, avg_loss = 0.3802
# t = 5, avg_loss = 0.3495
# t = 6, avg_loss = 0.3873
# t = 7, avg_loss = 0.3259
# t = 8, avg_loss = 0.3494
# t = 9, avg_loss = 0.4031
# t = 10, avg_loss = 0.3062
# t = 11, avg_loss = 0.4553
# t = 12, avg_loss = 0.3561
# t = 13, avg_loss = 0.5210
# t = 14, avg_loss = 0.2834
# t = 15, avg_loss = 0.3438
# t = 16, avg_loss = 0.4169
# t = 17, avg_loss = 0.3924
# t = 18, avg_loss = 0.3037
# Checking accuracy on test set
# Got 230 / 280 correct (82.14)
# acc = 0.821429
# Starting epoch 10 / 50
# t = 1, avg_loss = 0.3562
# t = 2, avg_loss = 0.4645
# t = 3, avg_loss = 0.3760
# t = 4, avg_loss = 0.2402
# t = 5, avg_loss = 0.3018
# t = 6, avg_loss = 0.3272
# t = 7, avg_loss = 0.2640
# t = 8, avg_loss = 0.3745
# t = 9, avg_loss = 0.4343
# t = 10, avg_loss = 0.2765
# t = 11, avg_loss = 0.3445
# t = 12, avg_loss = 0.5663
# t = 13, avg_loss = 0.3722
# t = 14, avg_loss = 0.3712
# t = 15, avg_loss = 0.3796
# t = 16, avg_loss = 0.3320
# t = 17, avg_loss = 0.3264
# t = 18, avg_loss = 0.4560
# Checking accuracy on test set
# Got 205 / 280 correct (73.21)
# acc = 0.732143
# Starting epoch 11 / 50
# t = 1, avg_loss = 0.3089
# t = 2, avg_loss = 0.3714
# t = 3, avg_loss = 0.4942
# t = 4, avg_loss = 0.3682
# t = 5, avg_loss = 0.3897
# t = 6, avg_loss = 0.3294
# t = 7, avg_loss = 0.4520
# t = 8, avg_loss = 0.3869
# t = 9, avg_loss = 0.2733
# t = 10, avg_loss = 0.4056
# t = 11, avg_loss = 0.4004
# t = 12, avg_loss = 0.2867
# t = 13, avg_loss = 0.3233
# t = 14, avg_loss = 0.5357
# t = 15, avg_loss = 0.2500
# t = 16, avg_loss = 0.3875
# t = 17, avg_loss = 0.2547
# t = 18, avg_loss = 0.1440
# Checking accuracy on test set
# Got 204 / 280 correct (72.86)
# acc = 0.728571
# Starting epoch 12 / 50
# t = 1, avg_loss = 0.2621
# t = 2, avg_loss = 0.3044
# t = 3, avg_loss = 0.3094
# t = 4, avg_loss = 0.2554
# t = 5, avg_loss = 0.4203
# t = 6, avg_loss = 0.3387
# t = 7, avg_loss = 0.2658
# t = 8, avg_loss = 0.4204
# t = 9, avg_loss = 0.5014
# t = 10, avg_loss = 0.2883
# t = 11, avg_loss = 0.4588
# t = 12, avg_loss = 0.3817
# t = 13, avg_loss = 0.3514
# t = 14, avg_loss = 0.3562
# t = 15, avg_loss = 0.3589
# t = 16, avg_loss = 0.3603
# t = 17, avg_loss = 0.3137
# t = 18, avg_loss = 0.4680
# Checking accuracy on test set
# Got 217 / 280 correct (77.50)
# acc = 0.775000
# Starting epoch 13 / 50
# t = 1, avg_loss = 0.3971
# t = 2, avg_loss = 0.4254
# t = 3, avg_loss = 0.4026
# t = 4, avg_loss = 0.4963
# t = 5, avg_loss = 0.3291
# t = 6, avg_loss = 0.3601
# t = 7, avg_loss = 0.3172
# t = 8, avg_loss = 0.2818
# t = 9, avg_loss = 0.3243
# t = 10, avg_loss = 0.3954
# t = 11, avg_loss = 0.3999
# t = 12, avg_loss = 0.3362
# t = 13, avg_loss = 0.4319
# t = 14, avg_loss = 0.3918
# t = 15, avg_loss = 0.3668
# t = 16, avg_loss = 0.3202
# t = 17, avg_loss = 0.3950
# t = 18, avg_loss = 0.3368
# Checking accuracy on test set
# Got 214 / 280 correct (76.43)
# acc = 0.764286
# Starting epoch 14 / 50
# t = 1, avg_loss = 0.3330
# t = 2, avg_loss = 0.3687
# t = 3, avg_loss = 0.2964
# t = 4, avg_loss = 0.2985
# t = 5, avg_loss = 0.3208
# t = 6, avg_loss = 0.3354
# t = 7, avg_loss = 0.2753
# t = 8, avg_loss = 0.3978
# t = 9, avg_loss = 0.3453
# t = 10, avg_loss = 0.3631
# t = 11, avg_loss = 0.3461
# t = 12, avg_loss = 0.2524
# t = 13, avg_loss = 0.4178
# t = 14, avg_loss = 0.4695
# t = 15, avg_loss = 0.4759
# t = 16, avg_loss = 0.3327
# t = 17, avg_loss = 0.3993
# t = 18, avg_loss = 0.4674
# Checking accuracy on test set
# Got 211 / 280 correct (75.36)
# acc = 0.753571
# Starting epoch 15 / 50
# t = 1, avg_loss = 0.3188
# t = 2, avg_loss = 0.3046
# t = 3, avg_loss = 0.3396
# t = 4, avg_loss = 0.3686
# t = 5, avg_loss = 0.3304
# t = 6, avg_loss = 0.3775
# t = 7, avg_loss = 0.3160
# t = 8, avg_loss = 0.3935
# t = 9, avg_loss = 0.3291
# t = 10, avg_loss = 0.4022
# t = 11, avg_loss = 0.3530
# t = 12, avg_loss = 0.2857
# t = 13, avg_loss = 0.3939
# t = 14, avg_loss = 0.4142
# t = 15, avg_loss = 0.4082
# t = 16, avg_loss = 0.3427
# t = 17, avg_loss = 0.3094
# t = 18, avg_loss = 0.3081
# Checking accuracy on test set
# Got 212 / 280 correct (75.71)
# acc = 0.757143
# Starting epoch 16 / 50
# t = 1, avg_loss = 0.3619
# t = 2, avg_loss = 0.3656
# t = 3, avg_loss = 0.3206
# t = 4, avg_loss = 0.3432
# t = 5, avg_loss = 0.4429
# t = 6, avg_loss = 0.2709
# t = 7, avg_loss = 0.3247
# t = 8, avg_loss = 0.2620
# t = 9, avg_loss = 0.3181
# t = 10, avg_loss = 0.2947
# t = 11, avg_loss = 0.3005
# t = 12, avg_loss = 0.2956
# t = 13, avg_loss = 0.1853
# t = 14, avg_loss = 0.2362
# t = 15, avg_loss = 0.4634
# t = 16, avg_loss = 0.3805
# t = 17, avg_loss = 0.3242
# t = 18, avg_loss = 0.5288
# Checking accuracy on test set
# Got 216 / 280 correct (77.14)
# acc = 0.771429
# Starting epoch 17 / 50
# t = 1, avg_loss = 0.3550
# t = 2, avg_loss = 0.2238
# t = 3, avg_loss = 0.3631
# t = 4, avg_loss = 0.3145
# t = 5, avg_loss = 0.3829
# t = 6, avg_loss = 0.4186
# t = 7, avg_loss = 0.2830
# t = 8, avg_loss = 0.2532
# t = 9, avg_loss = 0.3120
# t = 10, avg_loss = 0.3595
# t = 11, avg_loss = 0.3239
# t = 12, avg_loss = 0.2778
# t = 13, avg_loss = 0.3888
# t = 14, avg_loss = 0.3218
# t = 15, avg_loss = 0.4401
# t = 16, avg_loss = 0.2781
# t = 17, avg_loss = 0.3572
# t = 18, avg_loss = 0.4156
# Checking accuracy on test set
# Got 218 / 280 correct (77.86)
# acc = 0.778571
# Starting epoch 18 / 50
# t = 1, avg_loss = 0.3029
# t = 2, avg_loss = 0.2787
# t = 3, avg_loss = 0.3314
# t = 4, avg_loss = 0.3730
# t = 5, avg_loss = 0.2620
# t = 6, avg_loss = 0.3257
# t = 7, avg_loss = 0.3507
# t = 8, avg_loss = 0.3605
# t = 9, avg_loss = 0.2765
# t = 10, avg_loss = 0.3373
# t = 11, avg_loss = 0.4782
# t = 12, avg_loss = 0.2919
# t = 13, avg_loss = 0.2969
# t = 14, avg_loss = 0.2720
# t = 15, avg_loss = 0.3284
# t = 16, avg_loss = 0.4016
# t = 17, avg_loss = 0.3048
# t = 18, avg_loss = 0.4614
# Checking accuracy on test set
# Got 197 / 280 correct (70.36)
# acc = 0.703571
# Starting epoch 19 / 50
# t = 1, avg_loss = 0.3015
# t = 2, avg_loss = 0.4220
# t = 3, avg_loss = 0.2516
# t = 4, avg_loss = 0.2757
# t = 5, avg_loss = 0.3232
# t = 6, avg_loss = 0.3608
# t = 7, avg_loss = 0.2974
# t = 8, avg_loss = 0.4935
# t = 9, avg_loss = 0.2075
# t = 10, avg_loss = 0.4885
# t = 11, avg_loss = 0.1949
# t = 12, avg_loss = 0.3459
# t = 13, avg_loss = 0.3298
# t = 14, avg_loss = 0.3503
# t = 15, avg_loss = 0.3466
# t = 16, avg_loss = 0.3846
# t = 17, avg_loss = 0.3282
# t = 18, avg_loss = 0.2874
# Checking accuracy on test set
# Got 213 / 280 correct (76.07)
# acc = 0.760714
# Starting epoch 20 / 50
# t = 1, avg_loss = 0.3799
# t = 2, avg_loss = 0.3038
# t = 3, avg_loss = 0.3086
# t = 4, avg_loss = 0.3706
# t = 5, avg_loss = 0.2930
# t = 6, avg_loss = 0.3589
# t = 7, avg_loss = 0.3599
# t = 8, avg_loss = 0.3464
# t = 9, avg_loss = 0.3238
# t = 10, avg_loss = 0.2531
# t = 11, avg_loss = 0.3884
# t = 12, avg_loss = 0.3264
# t = 13, avg_loss = 0.3026
# t = 14, avg_loss = 0.3167
# t = 15, avg_loss = 0.3083
# t = 16, avg_loss = 0.3390
# t = 17, avg_loss = 0.2967
# t = 18, avg_loss = 0.1962
# Checking accuracy on test set
# Got 223 / 280 correct (79.64)
# acc = 0.796429
# Starting epoch 21 / 50
# t = 1, avg_loss = 0.3333
# t = 2, avg_loss = 0.2639
# t = 3, avg_loss = 0.4342
# t = 4, avg_loss = 0.2951
# t = 5, avg_loss = 0.2360
# t = 6, avg_loss = 0.2877
# t = 7, avg_loss = 0.2458
# t = 8, avg_loss = 0.2920
# t = 9, avg_loss = 0.4132
# t = 10, avg_loss = 0.2472
# t = 11, avg_loss = 0.3036
# t = 12, avg_loss = 0.3087
# t = 13, avg_loss = 0.3786
# t = 14, avg_loss = 0.3899
# t = 15, avg_loss = 0.3047
# t = 16, avg_loss = 0.2937
# t = 17, avg_loss = 0.5263
# t = 18, avg_loss = 0.3422
# Checking accuracy on test set
# Got 220 / 280 correct (78.57)
# acc = 0.785714
# Starting epoch 22 / 50
# t = 1, avg_loss = 0.2717
# t = 2, avg_loss = 0.3595
# t = 3, avg_loss = 0.3043
# t = 4, avg_loss = 0.3593
# t = 5, avg_loss = 0.3368
# t = 6, avg_loss = 0.2943
# t = 7, avg_loss = 0.2929
# t = 8, avg_loss = 0.3632
# t = 9, avg_loss = 0.3568
# t = 10, avg_loss = 0.4047
# t = 11, avg_loss = 0.3799
# t = 12, avg_loss = 0.4450
# t = 13, avg_loss = 0.2789
# t = 14, avg_loss = 0.2872
# t = 15, avg_loss = 0.5453
# t = 16, avg_loss = 0.3901
# t = 17, avg_loss = 0.2769
# t = 18, avg_loss = 0.3356
# Checking accuracy on test set
# Got 220 / 280 correct (78.57)
# acc = 0.785714
# Starting epoch 23 / 50
# t = 1, avg_loss = 0.3274
# t = 2, avg_loss = 0.2668
# t = 3, avg_loss = 0.3009
# t = 4, avg_loss = 0.3312
# t = 5, avg_loss = 0.4149
# t = 6, avg_loss = 0.3764
# t = 7, avg_loss = 0.5227
# t = 8, avg_loss = 0.2968
# t = 9, avg_loss = 0.2909
# t = 10, avg_loss = 0.2753
# t = 11, avg_loss = 0.3789
# t = 12, avg_loss = 0.2656
# t = 13, avg_loss = 0.3514
# t = 14, avg_loss = 0.3493
# t = 15, avg_loss = 0.2804
# t = 16, avg_loss = 0.5519
# t = 17, avg_loss = 0.3278
# t = 18, avg_loss = 0.4474
# Checking accuracy on test set
# Got 203 / 280 correct (72.50)
# acc = 0.725000
# Starting epoch 24 / 50
# t = 1, avg_loss = 0.2964
# t = 2, avg_loss = 0.1990
# t = 3, avg_loss = 0.3332
# t = 4, avg_loss = 0.2829
# t = 5, avg_loss = 0.4060
# t = 6, avg_loss = 0.3152
# t = 7, avg_loss = 0.4251
# t = 8, avg_loss = 0.3464
# t = 9, avg_loss = 0.4835
# t = 10, avg_loss = 0.4150
# t = 11, avg_loss = 0.4362
# t = 12, avg_loss = 0.3957
# t = 13, avg_loss = 0.3900
# t = 14, avg_loss = 0.3501
# t = 15, avg_loss = 0.2989
# t = 16, avg_loss = 0.4345
# t = 17, avg_loss = 0.5028
# t = 18, avg_loss = 0.3446
# Checking accuracy on test set
# Got 214 / 280 correct (76.43)
# acc = 0.764286
# Starting epoch 25 / 50
# t = 1, avg_loss = 0.3678
# t = 2, avg_loss = 0.3010
# t = 3, avg_loss = 0.3057
# t = 4, avg_loss = 0.2989
# t = 5, avg_loss = 0.3120
# t = 6, avg_loss = 0.3271
# t = 7, avg_loss = 0.3374
# t = 8, avg_loss = 0.3480
# t = 9, avg_loss = 0.4006
# t = 10, avg_loss = 0.4063
# t = 11, avg_loss = 0.3723
# t = 12, avg_loss = 0.2891
# t = 13, avg_loss = 0.4396
# t = 14, avg_loss = 0.4126
# t = 15, avg_loss = 0.4760
# t = 16, avg_loss = 0.2255
# t = 17, avg_loss = 0.3064
# t = 18, avg_loss = 0.6406
# Checking accuracy on test set
# Got 229 / 280 correct (81.79)
# acc = 0.817857
# Starting epoch 26 / 50
# t = 1, avg_loss = 0.2863
# t = 2, avg_loss = 0.3013
# t = 3, avg_loss = 0.3647
# t = 4, avg_loss = 0.3445
# t = 5, avg_loss = 0.3871
# t = 6, avg_loss = 0.2721
# t = 7, avg_loss = 0.3146
# t = 8, avg_loss = 0.4080
# t = 9, avg_loss = 0.4280
# t = 10, avg_loss = 0.3679
# t = 11, avg_loss = 0.3274
# t = 12, avg_loss = 0.4771
# t = 13, avg_loss = 0.3540
# t = 14, avg_loss = 0.3135
# t = 15, avg_loss = 0.4567
# t = 16, avg_loss = 0.3457
# t = 17, avg_loss = 0.2783
# t = 18, avg_loss = 0.3502
# Checking accuracy on test set
# Got 231 / 280 correct (82.50)
# acc = 0.825000
# Starting epoch 27 / 50
# t = 1, avg_loss = 0.3132
# t = 2, avg_loss = 0.3981
# t = 3, avg_loss = 0.3774
# t = 4, avg_loss = 0.2691
# t = 5, avg_loss = 0.2539
# t = 6, avg_loss = 0.3046
# t = 7, avg_loss = 0.2526
# t = 8, avg_loss = 0.2865
# t = 9, avg_loss = 0.3126
# t = 10, avg_loss = 0.3274
# t = 11, avg_loss = 0.3311
# t = 12, avg_loss = 0.2979
# t = 13, avg_loss = 0.4382
# t = 14, avg_loss = 0.2814
# t = 15, avg_loss = 0.3260
# t = 16, avg_loss = 0.3136
# t = 17, avg_loss = 0.4323
# t = 18, avg_loss = 0.2721
# Checking accuracy on test set
# Got 224 / 280 correct (80.00)
# acc = 0.800000
# Starting epoch 28 / 50
# t = 1, avg_loss = 0.3125
# t = 2, avg_loss = 0.3239
# t = 3, avg_loss = 0.3704
# t = 4, avg_loss = 0.3564
# t = 5, avg_loss = 0.3024
# t = 6, avg_loss = 0.2758
# t = 7, avg_loss = 0.3039
# t = 8, avg_loss = 0.2248
# t = 9, avg_loss = 0.2566
# t = 10, avg_loss = 0.2885
# t = 11, avg_loss = 0.2546
# t = 12, avg_loss = 0.3516
# t = 13, avg_loss = 0.3662
# t = 14, avg_loss = 0.3991
# t = 15, avg_loss = 0.2911
# t = 16, avg_loss = 0.2976
# t = 17, avg_loss = 0.3218
# t = 18, avg_loss = 0.2978
# Checking accuracy on test set
# Got 209 / 280 correct (74.64)
# acc = 0.746429
# Starting epoch 29 / 50
# t = 1, avg_loss = 0.2694
# t = 2, avg_loss = 0.2996
# t = 3, avg_loss = 0.2767
# t = 4, avg_loss = 0.3210
# t = 5, avg_loss = 0.3311
# t = 6, avg_loss = 0.2132
# t = 7, avg_loss = 0.3863
# t = 8, avg_loss = 0.2066
# t = 9, avg_loss = 0.3405
# t = 10, avg_loss = 0.3397
# t = 11, avg_loss = 0.3125
# t = 12, avg_loss = 0.3378
# t = 13, avg_loss = 0.5079
# t = 14, avg_loss = 0.3932
# t = 15, avg_loss = 0.4492
# t = 16, avg_loss = 0.2441
# t = 17, avg_loss = 0.2518
# t = 18, avg_loss = 0.2612
# Checking accuracy on test set
# Got 216 / 280 correct (77.14)
# acc = 0.771429
# Starting epoch 30 / 50
# t = 1, avg_loss = 0.2801
# t = 2, avg_loss = 0.3008
# t = 3, avg_loss = 0.3444
# t = 4, avg_loss = 0.2665
# t = 5, avg_loss = 0.2123
# t = 6, avg_loss = 0.3252
# t = 7, avg_loss = 0.3362
# t = 8, avg_loss = 0.4513
# t = 9, avg_loss = 0.3714
# t = 10, avg_loss = 0.3839
# t = 11, avg_loss = 0.3569
# t = 12, avg_loss = 0.3258
# t = 13, avg_loss = 0.2752
# t = 14, avg_loss = 0.1826
# t = 15, avg_loss = 0.3874
# t = 16, avg_loss = 0.4032
# t = 17, avg_loss = 0.3050
# t = 18, avg_loss = 0.3460
# Checking accuracy on test set
# Got 214 / 280 correct (76.43)
# acc = 0.764286
# Starting epoch 31 / 50
# t = 1, avg_loss = 0.3340
# t = 2, avg_loss = 0.2955
# t = 3, avg_loss = 0.3345
# t = 4, avg_loss = 0.2711
# t = 5, avg_loss = 0.2812
# t = 6, avg_loss = 0.3895
# t = 7, avg_loss = 0.3462
# t = 8, avg_loss = 0.3635
# t = 9, avg_loss = 0.4553
# t = 10, avg_loss = 0.3353
# t = 11, avg_loss = 0.3438
# t = 12, avg_loss = 0.3298
# t = 13, avg_loss = 0.2788
# t = 14, avg_loss = 0.2823
# t = 15, avg_loss = 0.3491
# t = 16, avg_loss = 0.2859
# t = 17, avg_loss = 0.2476
# t = 18, avg_loss = 0.3253
# Checking accuracy on test set
# Got 213 / 280 correct (76.07)
# acc = 0.760714
# Starting epoch 32 / 50
# t = 1, avg_loss = 0.4067
# t = 2, avg_loss = 0.3286
# t = 3, avg_loss = 0.4323
# t = 4, avg_loss = 0.2832
# t = 5, avg_loss = 0.4365
# t = 6, avg_loss = 0.2746
# t = 7, avg_loss = 0.2697
# t = 8, avg_loss = 0.2661
# t = 9, avg_loss = 0.2859
# t = 10, avg_loss = 0.3738
# t = 11, avg_loss = 0.2552
# t = 12, avg_loss = 0.3743
# t = 13, avg_loss = 0.3653
# t = 14, avg_loss = 0.2687
# t = 15, avg_loss = 0.3028
# t = 16, avg_loss = 0.3571
# t = 17, avg_loss = 0.2611
# t = 18, avg_loss = 0.5417
# Checking accuracy on test set
# Got 234 / 280 correct (83.57)
# acc = 0.835714
# Starting epoch 33 / 50
# t = 1, avg_loss = 0.2343
# t = 2, avg_loss = 0.2586
# t = 3, avg_loss = 0.3704
# t = 4, avg_loss = 0.2655
# t = 5, avg_loss = 0.3303
# t = 6, avg_loss = 0.4546
# t = 7, avg_loss = 0.3437
# t = 8, avg_loss = 0.1645
# t = 9, avg_loss = 0.2658
# t = 10, avg_loss = 0.2842
# t = 11, avg_loss = 0.4363
# t = 12, avg_loss = 0.2550
# t = 13, avg_loss = 0.3092
# t = 14, avg_loss = 0.2871
# t = 15, avg_loss = 0.3316
# t = 16, avg_loss = 0.2920
# t = 17, avg_loss = 0.5107
# t = 18, avg_loss = 0.3130
# Checking accuracy on test set
# Got 215 / 280 correct (76.79)
# acc = 0.767857
# Starting epoch 34 / 50
# t = 1, avg_loss = 0.3522
# t = 2, avg_loss = 0.3982
# t = 3, avg_loss = 0.2691
# t = 4, avg_loss = 0.3341
# t = 5, avg_loss = 0.2202
# t = 6, avg_loss = 0.2839
# t = 7, avg_loss = 0.2625
# t = 8, avg_loss = 0.3621
# t = 9, avg_loss = 0.4096
# t = 10, avg_loss = 0.3630
# t = 11, avg_loss = 0.3324
# t = 12, avg_loss = 0.3199
# t = 13, avg_loss = 0.3934
# t = 14, avg_loss = 0.4882
# t = 15, avg_loss = 0.3540
# t = 16, avg_loss = 0.3838
# t = 17, avg_loss = 0.2458
# t = 18, avg_loss = 0.3741
# Checking accuracy on test set
# Got 217 / 280 correct (77.50)
# acc = 0.775000
# Starting epoch 35 / 50
# t = 1, avg_loss = 0.3419
# t = 2, avg_loss = 0.3007
# t = 3, avg_loss = 0.3409
# t = 4, avg_loss = 0.2879
# t = 5, avg_loss = 0.3620
# t = 6, avg_loss = 0.2792
# t = 7, avg_loss = 0.3321
# t = 8, avg_loss = 0.2221
# t = 9, avg_loss = 0.2888
# t = 10, avg_loss = 0.3485
# t = 11, avg_loss = 0.3849
# t = 12, avg_loss = 0.3857
# t = 13, avg_loss = 0.2903
# t = 14, avg_loss = 0.2672
# t = 15, avg_loss = 0.4699
# t = 16, avg_loss = 0.2714
# t = 17, avg_loss = 0.3905
# t = 18, avg_loss = 0.3950
# Checking accuracy on test set
# Got 228 / 280 correct (81.43)
# acc = 0.814286
# Starting epoch 36 / 50
# t = 1, avg_loss = 0.3012
# t = 2, avg_loss = 0.2944
# t = 3, avg_loss = 0.3098
# t = 4, avg_loss = 0.2626
# t = 5, avg_loss = 0.2675
# t = 6, avg_loss = 0.3222
# t = 7, avg_loss = 0.2523
# t = 8, avg_loss = 0.2734
# t = 9, avg_loss = 0.3098
# t = 10, avg_loss = 0.2213
# t = 11, avg_loss = 0.2643
# t = 12, avg_loss = 0.4400
# t = 13, avg_loss = 0.3315
# t = 14, avg_loss = 0.2252
# t = 15, avg_loss = 0.3037
# t = 16, avg_loss = 0.3325
# t = 17, avg_loss = 0.4271
# t = 18, avg_loss = 0.2120
# Checking accuracy on test set
# Got 215 / 280 correct (76.79)
# acc = 0.767857
# Starting epoch 37 / 50
# t = 1, avg_loss = 0.2533
# t = 2, avg_loss = 0.3387
# t = 3, avg_loss = 0.2185
# t = 4, avg_loss = 0.3004
# t = 5, avg_loss = 0.3226
# t = 6, avg_loss = 0.3316
# t = 7, avg_loss = 0.3255
# t = 8, avg_loss = 0.2197
# t = 9, avg_loss = 0.2887
# t = 10, avg_loss = 0.4157
# t = 11, avg_loss = 0.2899
# t = 12, avg_loss = 0.2924
# t = 13, avg_loss = 0.4181
# t = 14, avg_loss = 0.5563
# t = 15, avg_loss = 0.3036
# t = 16, avg_loss = 0.3304
# t = 17, avg_loss = 0.3730
# t = 18, avg_loss = 0.2872
# Checking accuracy on test set
# Got 225 / 280 correct (80.36)
# acc = 0.803571
# Starting epoch 38 / 50
# t = 1, avg_loss = 0.2932
# t = 2, avg_loss = 0.3061
# t = 3, avg_loss = 0.4002
# t = 4, avg_loss = 0.4737
# t = 5, avg_loss = 0.3623
# t = 6, avg_loss = 0.3575
# t = 7, avg_loss = 0.3338
# t = 8, avg_loss = 0.2930
# t = 9, avg_loss = 0.2887
# t = 10, avg_loss = 0.3230
# t = 11, avg_loss = 0.3498
# t = 12, avg_loss = 0.3296
# t = 13, avg_loss = 0.2716
# t = 14, avg_loss = 0.3128
# t = 15, avg_loss = 0.2485
# t = 16, avg_loss = 0.3855
# t = 17, avg_loss = 0.3705
# t = 18, avg_loss = 0.3517
# Checking accuracy on test set
# Got 215 / 280 correct (76.79)
# acc = 0.767857
# Starting epoch 39 / 50
# t = 1, avg_loss = 0.3235
# t = 2, avg_loss = 0.2243
# t = 3, avg_loss = 0.3183
# t = 4, avg_loss = 0.2529
# t = 5, avg_loss = 0.3358
# t = 6, avg_loss = 0.2949
# t = 7, avg_loss = 0.3860
# t = 8, avg_loss = 0.3043
# t = 9, avg_loss = 0.2946
# t = 10, avg_loss = 0.2725
# t = 11, avg_loss = 0.3030
# t = 12, avg_loss = 0.3571
# t = 13, avg_loss = 0.2868
# t = 14, avg_loss = 0.3049
# t = 15, avg_loss = 0.2921
# t = 16, avg_loss = 0.2045
# t = 17, avg_loss = 0.2813
# t = 18, avg_loss = 0.2602
# Checking accuracy on test set
# Got 223 / 280 correct (79.64)
# acc = 0.796429
# Starting epoch 40 / 50
# t = 1, avg_loss = 0.2894
# t = 2, avg_loss = 0.3132
# t = 3, avg_loss = 0.4582
# t = 4, avg_loss = 0.2642
# t = 5, avg_loss = 0.3602
# t = 6, avg_loss = 0.2459
# t = 7, avg_loss = 0.3316
# t = 8, avg_loss = 0.2826
# t = 9, avg_loss = 0.2750
# t = 10, avg_loss = 0.3453
# t = 11, avg_loss = 0.2036
# t = 12, avg_loss = 0.3637
# t = 13, avg_loss = 0.2436
# t = 14, avg_loss = 0.3887
# t = 15, avg_loss = 0.3270
# t = 16, avg_loss = 0.5533
# t = 17, avg_loss = 0.4208
# t = 18, avg_loss = 0.2178
# Checking accuracy on test set
# Got 226 / 280 correct (80.71)
# acc = 0.807143
# Starting epoch 41 / 50
# t = 1, avg_loss = 0.3353
# t = 2, avg_loss = 0.2584
# t = 3, avg_loss = 0.2548
# t = 4, avg_loss = 0.2114
# t = 5, avg_loss = 0.3547
# t = 6, avg_loss = 0.3033
# t = 7, avg_loss = 0.3164
# t = 8, avg_loss = 0.3104
# t = 9, avg_loss = 0.3017
# t = 10, avg_loss = 0.4074
# t = 11, avg_loss = 0.2989
# t = 12, avg_loss = 0.3352
# t = 13, avg_loss = 0.1782
# t = 14, avg_loss = 0.4311
# t = 15, avg_loss = 0.2371
# t = 16, avg_loss = 0.4262
# t = 17, avg_loss = 0.3902
# t = 18, avg_loss = 0.3406
# Checking accuracy on test set
# Got 228 / 280 correct (81.43)
# acc = 0.814286
# Starting epoch 42 / 50
# t = 1, avg_loss = 0.2803
# t = 2, avg_loss = 0.3174
# t = 3, avg_loss = 0.2707
# t = 4, avg_loss = 0.3928
# t = 5, avg_loss = 0.3301
# t = 6, avg_loss = 0.2923
# t = 7, avg_loss = 0.4608
# t = 8, avg_loss = 0.2731
# t = 9, avg_loss = 0.3787
# t = 10, avg_loss = 0.2878
# t = 11, avg_loss = 0.2973
# t = 12, avg_loss = 0.1766
# t = 13, avg_loss = 0.3220
# t = 14, avg_loss = 0.3591
# t = 15, avg_loss = 0.2762
# t = 16, avg_loss = 0.3594
# t = 17, avg_loss = 0.3567
# t = 18, avg_loss = 0.2045
# Checking accuracy on test set
# Got 231 / 280 correct (82.50)
# acc = 0.825000
# Starting epoch 43 / 50
# t = 1, avg_loss = 0.3085
# t = 2, avg_loss = 0.2480
# t = 3, avg_loss = 0.4368
# t = 4, avg_loss = 0.2758
# t = 5, avg_loss = 0.3827
# t = 6, avg_loss = 0.3526
# t = 7, avg_loss = 0.2688
# t = 8, avg_loss = 0.3449
# t = 9, avg_loss = 0.3393
# t = 10, avg_loss = 0.2667
# t = 11, avg_loss = 0.3161
# t = 12, avg_loss = 0.3616
# t = 13, avg_loss = 0.2477
# t = 14, avg_loss = 0.3931
# t = 15, avg_loss = 0.2464
# t = 16, avg_loss = 0.1909
# t = 17, avg_loss = 0.2625
# t = 18, avg_loss = 0.1625
# Checking accuracy on test set
# Got 225 / 280 correct (80.36)
# acc = 0.803571
# Starting epoch 44 / 50
# t = 1, avg_loss = 0.2690
# t = 2, avg_loss = 0.4454
# t = 3, avg_loss = 0.2825
# t = 4, avg_loss = 0.1493
# t = 5, avg_loss = 0.1829
# t = 6, avg_loss = 0.1905
# t = 7, avg_loss = 0.3548
# t = 8, avg_loss = 0.3399
# t = 9, avg_loss = 0.3545
# t = 10, avg_loss = 0.2886
# t = 11, avg_loss = 0.3291
# t = 12, avg_loss = 0.2919
# t = 13, avg_loss = 0.4210
# t = 14, avg_loss = 0.3883
# t = 15, avg_loss = 0.3828
# t = 16, avg_loss = 0.5191
# t = 17, avg_loss = 0.2262
# t = 18, avg_loss = 0.5964
# Checking accuracy on test set
# Got 221 / 280 correct (78.93)
# acc = 0.789286
# Starting epoch 45 / 50
# t = 1, avg_loss = 0.2178
# t = 2, avg_loss = 0.3408
# t = 3, avg_loss = 0.5312
# t = 4, avg_loss = 0.2849
# t = 5, avg_loss = 0.3663
# t = 6, avg_loss = 0.2904
# t = 7, avg_loss = 0.3162
# t = 8, avg_loss = 0.3730
# t = 9, avg_loss = 0.3434
# t = 10, avg_loss = 0.4076
# t = 11, avg_loss = 0.2993
# t = 12, avg_loss = 0.3331
# t = 13, avg_loss = 0.3649
# t = 14, avg_loss = 0.3914
# t = 15, avg_loss = 0.2852
# t = 16, avg_loss = 0.3691
# t = 17, avg_loss = 0.2937
# t = 18, avg_loss = 0.2906
# Checking accuracy on test set
# Got 227 / 280 correct (81.07)
# acc = 0.810714
# Starting epoch 46 / 50
# t = 1, avg_loss = 0.2794
# t = 2, avg_loss = 0.3443
# t = 3, avg_loss = 0.3085
# t = 4, avg_loss = 0.2018
# t = 5, avg_loss = 0.2685
# t = 6, avg_loss = 0.3315
# t = 7, avg_loss = 0.2816
# t = 8, avg_loss = 0.2339
# t = 9, avg_loss = 0.3203
# t = 10, avg_loss = 0.3192
# t = 11, avg_loss = 0.2946
# t = 12, avg_loss = 0.2792
# t = 13, avg_loss = 0.2458
# t = 14, avg_loss = 0.2929
# t = 15, avg_loss = 0.3213
# t = 16, avg_loss = 0.3406
# t = 17, avg_loss = 0.3541
# t = 18, avg_loss = 0.1742
# Checking accuracy on test set
# Got 225 / 280 correct (80.36)
# acc = 0.803571
# Starting epoch 47 / 50
# t = 1, avg_loss = 0.2791
# t = 2, avg_loss = 0.3245
# t = 3, avg_loss = 0.3200
# t = 4, avg_loss = 0.2880
# t = 5, avg_loss = 0.3872
# t = 6, avg_loss = 0.1737
# t = 7, avg_loss = 0.2479
# t = 8, avg_loss = 0.2212
# t = 9, avg_loss = 0.2306
# t = 10, avg_loss = 0.4455
# t = 11, avg_loss = 0.2377
# t = 12, avg_loss = 0.1927
# t = 13, avg_loss = 0.4107
# t = 14, avg_loss = 0.2997
# t = 15, avg_loss = 0.3107
# t = 16, avg_loss = 0.2988
# t = 17, avg_loss = 0.3554
# t = 18, avg_loss = 0.4339
# Checking accuracy on test set
# Got 229 / 280 correct (81.79)
# acc = 0.817857
# Starting epoch 48 / 50
# t = 1, avg_loss = 0.3001
# t = 2, avg_loss = 0.3806
# t = 3, avg_loss = 0.2799
# t = 4, avg_loss = 0.2508
# t = 5, avg_loss = 0.2534
# t = 6, avg_loss = 0.2822
# t = 7, avg_loss = 0.2768
# t = 8, avg_loss = 0.4076
# t = 9, avg_loss = 0.2632
# t = 10, avg_loss = 0.3403
# t = 11, avg_loss = 0.5113
# t = 12, avg_loss = 0.3915
# t = 13, avg_loss = 0.3534
# t = 14, avg_loss = 0.3994
# t = 15, avg_loss = 0.4134
# t = 16, avg_loss = 0.3137
# t = 17, avg_loss = 0.2696
# t = 18, avg_loss = 0.2968
# Checking accuracy on test set
# Got 222 / 280 correct (79.29)
# acc = 0.792857
# Starting epoch 49 / 50
# t = 1, avg_loss = 0.3931
# t = 2, avg_loss = 0.3719
# t = 3, avg_loss = 0.3542
# t = 4, avg_loss = 0.2803
# t = 5, avg_loss = 0.2869
# t = 6, avg_loss = 0.2673
# t = 7, avg_loss = 0.2720
# t = 8, avg_loss = 0.3351
# t = 9, avg_loss = 0.2831
# t = 10, avg_loss = 0.3180
# t = 11, avg_loss = 0.2566
# t = 12, avg_loss = 0.2751
# t = 13, avg_loss = 0.4668
# t = 14, avg_loss = 0.2837
# t = 15, avg_loss = 0.1983
# t = 16, avg_loss = 0.3738
# t = 17, avg_loss = 0.3496
# t = 18, avg_loss = 0.3301
# Checking accuracy on test set
# Got 220 / 280 correct (78.57)
# acc = 0.785714
# Starting epoch 50 / 50
# t = 1, avg_loss = 0.3084
# t = 2, avg_loss = 0.2211
# t = 3, avg_loss = 0.2704
# t = 4, avg_loss = 0.3068
# t = 5, avg_loss = 0.2661
# t = 6, avg_loss = 0.3494
# t = 7, avg_loss = 0.3578
# t = 8, avg_loss = 0.4290
# t = 9, avg_loss = 0.2773
# t = 10, avg_loss = 0.3180
# t = 11, avg_loss = 0.3905
# t = 12, avg_loss = 0.4309
# t = 13, avg_loss = 0.3748
# t = 14, avg_loss = 0.3180
# t = 15, avg_loss = 0.3609
# t = 16, avg_loss = 0.2592
# t = 17, avg_loss = 0.3442
# t = 18, avg_loss = 0.2207
# Checking accuracy on test set
# Got 229 / 280 correct (81.79)
# acc = 0.817857
# Checking accuracy on test set
# Got 231 / 280 correct (82.50)
# 0.825

# %%
import matplotlib.pyplot as plt

plt.plot([print_every*batch_size*(i+1) for i in range((len(avg_loss_list)))],avg_loss_list)
print("Loss:")
plt.show()
# Out:
# Loss:

# %%
plt.plot([i+1 for i in range((len(acc_list)))],acc_list)
print("Accurancy:")
plt.show()
# Out:
# Accurancy:
