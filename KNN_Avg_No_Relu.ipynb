# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilo116/KNN/blob/master/KNN_Avg_No_Relu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import os
import csv
import sys
from random import shuffle
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
# %matplotlib inline
from sklearn.model_selection import train_test_split

import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
from torch.utils.data.sampler import SubsetRandomSampler

import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T
import torchvision.transforms as transforms
import timeit

np.random.seed(4) 
torch.manual_seed(4) 
torch.cuda.manual_seed(4)

# %%
! git clone https://github.com/wang-chen/kervolution.git 

sys.path.append("kervolution/")
from kervolution import Kerv2d
# Out:
# fatal: destination path 'kervolution' already exists and is not an empty directory.

# %%
LIMIT_IMAGES_NUM = 500
train_test_split_size = 0.2
image_resize = (100, 100)
batch_size = 64
num_workers = 0

in_channels = 3
out_channels_0 = 8
out_channels_1 = 16
out_channels_2 = 32
out_channels_3 = 64
out_channels_4 = 128

kernel_size = 3
padding_1 = 1
num_epochs = 80

learning_rate = 0.0001
weight_decay = 0

MALIGNANT_DATASET = '/content/drive/My Drive/Colab_data/malignant/malignant/'
BENIGN_DATASET = '/content/drive/My Drive/Colab_data/benign/benign/'
DATA_FOLDER = '/content/drive/My Drive/Colab_data/'
model_backup_path = os.path.join(DATA_FOLDER, 'backup_model')

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
benign_file_list = sorted(os.listdir(BENIGN_DATASET))
malignant_file_list = sorted(os.listdir(MALIGNANT_DATASET))
shuffle(benign_file_list)
shuffle(malignant_file_list)
benign_file_list = benign_file_list[:LIMIT_IMAGES_NUM]
malignant_file_list = malignant_file_list[:LIMIT_IMAGES_NUM]

print(f"Number of benign {len(benign_file_list)} images")
print(f"Number of malignant {len(malignant_file_list)} images")

data_transforms = transforms.Compose([
    transforms.Resize(image_resize),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Out:
# Number of benign 500 images
# Number of malignant 500 images

# %%
benign_dict = {filename: 0 for filename in benign_file_list}
malignant_dict = {filename: 1 for filename in malignant_file_list}
img_class_dict = {**benign_dict , **malignant_dict}
labeled_data = pd.Series(img_class_dict)

# %%
class IsicDataset(Dataset):
    def __init__(self, data_folder, labeled_data, 
                 transform=transforms.Compose([transforms.ToTensor()])):
        self.labeled_data = labeled_data
        self.transform = transform
        self.data_folder = data_folder
        
        
    def __len__(self):
        return len(self.labeled_data)

    def __getitem__(self, index):
        label = self.labeled_data[index]
        if label == 0:
          image = Image.open(os.path.join(self.data_folder, "benign", "benign", index ))
        else:
          image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", index ))
        image = self.transform(image)
        return image, label

    @property
    def labels(self):
      return self.labeled_data

# %%
 
dataset = IsicDataset(DATA_FOLDER, labeled_data, transform=data_transforms)
print(dataset.labels)

X_train, X_test = train_test_split(dataset.labels, test_size=train_test_split_size)
print("number of training data: ",len(X_train))
print("number of testing  data: ",len(X_test))

train_sampler = SubsetRandomSampler(list(X_train.index))
valid_sampler = SubsetRandomSampler(list(X_test.index))


train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
# Out:
# ISIC_0000770.jpeg    0
# ISIC_0000437.jpeg    0
# ISIC_0002375.jpeg    0
# ISIC_0000772.jpeg    0
# ISIC_0000128.jpeg    0
#                     ..
# ISIC_0011874.jpeg    1
# ISIC_0010415.jpeg    1
# ISIC_0000002.jpeg    1
# ISIC_0010631.jpeg    1
# ISIC_0013995.jpeg    1
# Length: 1000, dtype: int64
# number of training data:  800
# number of testing  data:  200

# %%
avg_loss_list = []
acc_list = []

def train(model, train_loader ,loss_fn, optimizer, num_epochs=1, starting_from_epoch=1):
    total_loss =0

    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()

        for t, (x, y) in enumerate(train_loader):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())
            scores = model(x_var)
            loss = loss_fn(scores, y_var)
            total_loss += loss.data
            
            if (t + 1) % print_every == 0:
                avg_loss = total_loss/print_every
                print('t = %d, avg_loss = %.4f' % (t + 1, avg_loss) )
                avg_loss_list.append(avg_loss)
                total_loss = 0
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        acc = check_accuracy(model_gpu, valid_loader)
        print('acc = %f' %(acc))
        torch.save({
            'epoch': epoch,
            'model_state_dict': model_gpu.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
            }, model_backup_path)
            
def check_accuracy(model, loader):
    print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() 
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype))

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    acc_list.append(acc)
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size()
        return x.view(N, -1)

# %%
gpu_dtype = torch.cuda.FloatTensor

print_every = 1


'''
Kerv2d
kervolution with following options:
kernel_type: [linear, polynomial, gaussian, etc.]
default is convolution:
          kernel_type --> linear,
balance, power, gamma is valid only when the kernel_type is specified
if learnable_kernel = True,  they just be the initial value of learable parameters
if learnable_kernel = False, they are the value of kernel_type's parameter
the parameter [power] cannot be learned due to integer limitation
dilation (int or tuple, optional): Spacing between kernel
elements. Default: 1
groups (int, optional): Number of blocked connections from input
channels to output channels. Default: 1
bias (bool, optional): If ``True``, adds a learnable bias to the output. Default: ``True``
kernel_type (str), Default: 'linear'
learnable_kernel (bool): Learnable kernel parameters.  Default: False 
balance: 0, 1
power: 3, 4, 5
gamma:
'''


model_base = nn.Sequential( 
                nn.Kerv2d(in_channels , out_channels_0, padding=padding_1, dilation=1, groups=1, bias=True, 
                          kernel_type='polynomial', kernel_size=kernel_size, learnable_kernel=True,
                          kernel_regularizer=True, stride=1, balance=1, power=3, gamma=1
                          ),
                           nn.BatchNorm2d(out_channels_0),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_0 , out_channels_1, padding= padding_1, kernel_size=kernel_size, stride=1), 
                nn.BatchNorm2d(out_channels_1),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_1 , out_channels_2, padding= padding_1, kernel_size=kernel_size, stride=1), 
                nn.BatchNorm2d(out_channels_2),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_2 , out_channels_3, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_3),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_3 , out_channels_4, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_4),
                nn.AvgPool2d(2, stride=2),
                nn.Dropout(0.5),
                Flatten(),
                nn.Linear(1152,64),
                nn.Linear(64,2)
            )
model_gpu = model_base.type(gpu_dtype)
print(model_gpu)
loss_fn = nn.modules.loss.CrossEntropyLoss()
optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay) 

train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
check_accuracy(model_gpu, valid_loader)
# Out:
# Sequential(
#   (0): Kerv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (6): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (9): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (12): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (15): Dropout(p=0.5, inplace=False)
#   (16): Flatten()
#   (17): Linear(in_features=1152, out_features=64, bias=True)
#   (18): Linear(in_features=64, out_features=2, bias=True)
# )
# Starting epoch 1 / 80
# t = 1, avg_loss = 0.7985
# t = 2, avg_loss = 0.7286
# t = 3, avg_loss = 0.6570
# t = 4, avg_loss = 0.6608
# t = 5, avg_loss = 0.6749
# t = 6, avg_loss = 0.5704
# t = 7, avg_loss = 0.6979
# t = 8, avg_loss = 0.6868
# t = 9, avg_loss = 0.8288
# t = 10, avg_loss = 0.6962
# t = 11, avg_loss = 0.7253
# t = 12, avg_loss = 0.6484
# t = 13, avg_loss = 0.7673
# Checking accuracy on test set
# Got 100 / 200 correct (50.00)
# acc = 0.500000
# Starting epoch 2 / 80
# t = 1, avg_loss = 0.6960
# t = 2, avg_loss = 0.6678
# t = 3, avg_loss = 0.6376
# t = 4, avg_loss = 0.6879
# t = 5, avg_loss = 0.7131
# t = 6, avg_loss = 0.7761
# t = 7, avg_loss = 0.6676
# t = 8, avg_loss = 0.6539
# t = 9, avg_loss = 0.6583
# t = 10, avg_loss = 0.7198
# t = 11, avg_loss = 0.6937
# t = 12, avg_loss = 0.5686
# t = 13, avg_loss = 0.6685
# Checking accuracy on test set
# Got 117 / 200 correct (58.50)
# acc = 0.585000
# Starting epoch 3 / 80
# t = 1, avg_loss = 0.6218
# t = 2, avg_loss = 0.5832
# t = 3, avg_loss = 0.6253
# t = 4, avg_loss = 0.6926
# t = 5, avg_loss = 0.6748
# t = 6, avg_loss = 0.6824
# t = 7, avg_loss = 0.6169
# t = 8, avg_loss = 0.6185
# t = 9, avg_loss = 0.7096
# t = 10, avg_loss = 0.6704
# t = 11, avg_loss = 0.6607
# t = 12, avg_loss = 0.7189
# t = 13, avg_loss = 0.6146
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 4 / 80
# t = 1, avg_loss = 0.5998
# t = 2, avg_loss = 0.6186
# t = 3, avg_loss = 0.6328
# t = 4, avg_loss = 0.6473
# t = 5, avg_loss = 0.7078
# t = 6, avg_loss = 0.7238
# t = 7, avg_loss = 0.6694
# t = 8, avg_loss = 0.6737
# t = 9, avg_loss = 0.6265
# t = 10, avg_loss = 0.6249
# t = 11, avg_loss = 0.6695
# t = 12, avg_loss = 0.5407
# t = 13, avg_loss = 0.5775
# Checking accuracy on test set
# Got 136 / 200 correct (68.00)
# acc = 0.680000
# Starting epoch 5 / 80
# t = 1, avg_loss = 0.5572
# t = 2, avg_loss = 0.6117
# t = 3, avg_loss = 0.6639
# t = 4, avg_loss = 0.7377
# t = 5, avg_loss = 0.7676
# t = 6, avg_loss = 0.6847
# t = 7, avg_loss = 0.5682
# t = 8, avg_loss = 0.6385
# t = 9, avg_loss = 0.6412
# t = 10, avg_loss = 0.6520
# t = 11, avg_loss = 0.6394
# t = 12, avg_loss = 0.6628
# t = 13, avg_loss = 0.7072
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 6 / 80
# t = 1, avg_loss = 0.6581
# t = 2, avg_loss = 0.6030
# t = 3, avg_loss = 0.6216
# t = 4, avg_loss = 0.6931
# t = 5, avg_loss = 0.6335
# t = 6, avg_loss = 0.5880
# t = 7, avg_loss = 0.6861
# t = 8, avg_loss = 0.6000
# t = 9, avg_loss = 0.7161
# t = 10, avg_loss = 0.6317
# t = 11, avg_loss = 0.7059
# t = 12, avg_loss = 0.6291
# t = 13, avg_loss = 0.4156
# Checking accuracy on test set
# Got 134 / 200 correct (67.00)
# acc = 0.670000
# Starting epoch 7 / 80
# t = 1, avg_loss = 0.6434
# t = 2, avg_loss = 0.6098
# t = 3, avg_loss = 0.6141
# t = 4, avg_loss = 0.5661
# t = 5, avg_loss = 0.6411
# t = 6, avg_loss = 0.6509
# t = 7, avg_loss = 0.6283
# t = 8, avg_loss = 0.6574
# t = 9, avg_loss = 0.5855
# t = 10, avg_loss = 0.7319
# t = 11, avg_loss = 0.6625
# t = 12, avg_loss = 0.5949
# t = 13, avg_loss = 0.6774
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 8 / 80
# t = 1, avg_loss = 0.6379
# t = 2, avg_loss = 0.6035
# t = 3, avg_loss = 0.6423
# t = 4, avg_loss = 0.5860
# t = 5, avg_loss = 0.5888
# t = 6, avg_loss = 0.6273
# t = 7, avg_loss = 0.6249
# t = 8, avg_loss = 0.6478
# t = 9, avg_loss = 0.7253
# t = 10, avg_loss = 0.6251
# t = 11, avg_loss = 0.6450
# t = 12, avg_loss = 0.6399
# t = 13, avg_loss = 0.6932
# Checking accuracy on test set
# Got 143 / 200 correct (71.50)
# acc = 0.715000
# Starting epoch 9 / 80
# t = 1, avg_loss = 0.5463
# t = 2, avg_loss = 0.5358
# t = 3, avg_loss = 0.6413
# t = 4, avg_loss = 0.5281
# t = 5, avg_loss = 0.6640
# t = 6, avg_loss = 0.6076
# t = 7, avg_loss = 0.6597
# t = 8, avg_loss = 0.5364
# t = 9, avg_loss = 0.5702
# t = 10, avg_loss = 0.6226
# t = 11, avg_loss = 0.6547
# t = 12, avg_loss = 0.7387
# t = 13, avg_loss = 0.7057
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 10 / 80
# t = 1, avg_loss = 0.6622
# t = 2, avg_loss = 0.5593
# t = 3, avg_loss = 0.5555
# t = 4, avg_loss = 0.6091
# t = 5, avg_loss = 0.5982
# t = 6, avg_loss = 0.6603
# t = 7, avg_loss = 0.5993
# t = 8, avg_loss = 0.6093
# t = 9, avg_loss = 0.6227
# t = 10, avg_loss = 0.6046
# t = 11, avg_loss = 0.5904
# t = 12, avg_loss = 0.5905
# t = 13, avg_loss = 0.6523
# Checking accuracy on test set
# Got 144 / 200 correct (72.00)
# acc = 0.720000
# Starting epoch 11 / 80
# t = 1, avg_loss = 0.6161
# t = 2, avg_loss = 0.6227
# t = 3, avg_loss = 0.5651
# t = 4, avg_loss = 0.6122
# t = 5, avg_loss = 0.5899
# t = 6, avg_loss = 0.5506
# t = 7, avg_loss = 0.6023
# t = 8, avg_loss = 0.5831
# t = 9, avg_loss = 0.6157
# t = 10, avg_loss = 0.6789
# t = 11, avg_loss = 0.5361
# t = 12, avg_loss = 0.6442
# t = 13, avg_loss = 0.5737
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 12 / 80
# t = 1, avg_loss = 0.5583
# t = 2, avg_loss = 0.6301
# t = 3, avg_loss = 0.6687
# t = 4, avg_loss = 0.5471
# t = 5, avg_loss = 0.7342
# t = 6, avg_loss = 0.5493
# t = 7, avg_loss = 0.5629
# t = 8, avg_loss = 0.5284
# t = 9, avg_loss = 0.5487
# t = 10, avg_loss = 0.6081
# t = 11, avg_loss = 0.6205
# t = 12, avg_loss = 0.5881
# t = 13, avg_loss = 0.6656
# Checking accuracy on test set
# Got 143 / 200 correct (71.50)
# acc = 0.715000
# Starting epoch 13 / 80
# t = 1, avg_loss = 0.5378
# t = 2, avg_loss = 0.5551
# t = 3, avg_loss = 0.6481
# t = 4, avg_loss = 0.5998
# t = 5, avg_loss = 0.6279
# t = 6, avg_loss = 0.6086
# t = 7, avg_loss = 0.5262
# t = 8, avg_loss = 0.7249
# t = 9, avg_loss = 0.6035
# t = 10, avg_loss = 0.6683
# t = 11, avg_loss = 0.6694
# t = 12, avg_loss = 0.6309
# t = 13, avg_loss = 0.6123
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 14 / 80
# t = 1, avg_loss = 0.6052
# t = 2, avg_loss = 0.5841
# t = 3, avg_loss = 0.6131
# t = 4, avg_loss = 0.6208
# t = 5, avg_loss = 0.7259
# t = 6, avg_loss = 0.6267
# t = 7, avg_loss = 0.5849
# t = 8, avg_loss = 0.6337
# t = 9, avg_loss = 0.6074
# t = 10, avg_loss = 0.6436
# t = 11, avg_loss = 0.5649
# t = 12, avg_loss = 0.5872
# t = 13, avg_loss = 0.6661
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 15 / 80
# t = 1, avg_loss = 0.6191
# t = 2, avg_loss = 0.6966
# t = 3, avg_loss = 0.5581
# t = 4, avg_loss = 0.5587
# t = 5, avg_loss = 0.6387
# t = 6, avg_loss = 0.6258
# t = 7, avg_loss = 0.5907
# t = 8, avg_loss = 0.5331
# t = 9, avg_loss = 0.7446
# t = 10, avg_loss = 0.5995
# t = 11, avg_loss = 0.5739
# t = 12, avg_loss = 0.6650
# t = 13, avg_loss = 0.6355
# Checking accuracy on test set
# Got 144 / 200 correct (72.00)
# acc = 0.720000
# Starting epoch 16 / 80
# t = 1, avg_loss = 0.5556
# t = 2, avg_loss = 0.5671
# t = 3, avg_loss = 0.5840
# t = 4, avg_loss = 0.6201
# t = 5, avg_loss = 0.6024
# t = 6, avg_loss = 0.5934
# t = 7, avg_loss = 0.6121
# t = 8, avg_loss = 0.6852
# t = 9, avg_loss = 0.7052
# t = 10, avg_loss = 0.6102
# t = 11, avg_loss = 0.6273
# t = 12, avg_loss = 0.5797
# t = 13, avg_loss = 0.6030
# Checking accuracy on test set
# Got 146 / 200 correct (73.00)
# acc = 0.730000
# Starting epoch 17 / 80
# t = 1, avg_loss = 0.5933
# t = 2, avg_loss = 0.5987
# t = 3, avg_loss = 0.6264
# t = 4, avg_loss = 0.6515
# t = 5, avg_loss = 0.5091
# t = 6, avg_loss = 0.5936
# t = 7, avg_loss = 0.6713
# t = 8, avg_loss = 0.6212
# t = 9, avg_loss = 0.6396
# t = 10, avg_loss = 0.6055
# t = 11, avg_loss = 0.5673
# t = 12, avg_loss = 0.6040
# t = 13, avg_loss = 0.5551
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 18 / 80
# t = 1, avg_loss = 0.6709
# t = 2, avg_loss = 0.5082
# t = 3, avg_loss = 0.5076
# t = 4, avg_loss = 0.6217
# t = 5, avg_loss = 0.6882
# t = 6, avg_loss = 0.5214
# t = 7, avg_loss = 0.6748
# t = 8, avg_loss = 0.5391
# t = 9, avg_loss = 0.6088
# t = 10, avg_loss = 0.5557
# t = 11, avg_loss = 0.6062
# t = 12, avg_loss = 0.6230
# t = 13, avg_loss = 0.7691
# Checking accuracy on test set
# Got 151 / 200 correct (75.50)
# acc = 0.755000
# Starting epoch 19 / 80
# t = 1, avg_loss = 0.5428
# t = 2, avg_loss = 0.5472
# t = 3, avg_loss = 0.5227
# t = 4, avg_loss = 0.6459
# t = 5, avg_loss = 0.6491
# t = 6, avg_loss = 0.6094
# t = 7, avg_loss = 0.6167
# t = 8, avg_loss = 0.7161
# t = 9, avg_loss = 0.6396
# t = 10, avg_loss = 0.5785
# t = 11, avg_loss = 0.6062
# t = 12, avg_loss = 0.6019
# t = 13, avg_loss = 0.5233
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 20 / 80
# t = 1, avg_loss = 0.5928
# t = 2, avg_loss = 0.6031
# t = 3, avg_loss = 0.5482
# t = 4, avg_loss = 0.5602
# t = 5, avg_loss = 0.6339
# t = 6, avg_loss = 0.5835
# t = 7, avg_loss = 0.5802
# t = 8, avg_loss = 0.5210
# t = 9, avg_loss = 0.5597
# t = 10, avg_loss = 0.6097
# t = 11, avg_loss = 0.6337
# t = 12, avg_loss = 0.5902
# t = 13, avg_loss = 0.6491
# Checking accuracy on test set
# Got 148 / 200 correct (74.00)
# acc = 0.740000
# Starting epoch 21 / 80
# t = 1, avg_loss = 0.5495
# t = 2, avg_loss = 0.6010
# t = 3, avg_loss = 0.6231
# t = 4, avg_loss = 0.6233
# t = 5, avg_loss = 0.5873
# t = 6, avg_loss = 0.5935
# t = 7, avg_loss = 0.5609
# t = 8, avg_loss = 0.6758
# t = 9, avg_loss = 0.5095
# t = 10, avg_loss = 0.5662
# t = 11, avg_loss = 0.5673
# t = 12, avg_loss = 0.6388
# t = 13, avg_loss = 0.6383
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 22 / 80
# t = 1, avg_loss = 0.5236
# t = 2, avg_loss = 0.6939
# t = 3, avg_loss = 0.5570
# t = 4, avg_loss = 0.6837
# t = 5, avg_loss = 0.5071
# t = 6, avg_loss = 0.5634
# t = 7, avg_loss = 0.5515
# t = 8, avg_loss = 0.6347
# t = 9, avg_loss = 0.5575
# t = 10, avg_loss = 0.5797
# t = 11, avg_loss = 0.5652
# t = 12, avg_loss = 0.5928
# t = 13, avg_loss = 0.5777
# Checking accuracy on test set
# Got 149 / 200 correct (74.50)
# acc = 0.745000
# Starting epoch 23 / 80
# t = 1, avg_loss = 0.7019
# t = 2, avg_loss = 0.5387
# t = 3, avg_loss = 0.5922
# t = 4, avg_loss = 0.5582
# t = 5, avg_loss = 0.6160
# t = 6, avg_loss = 0.5148
# t = 7, avg_loss = 0.6188
# t = 8, avg_loss = 0.5821
# t = 9, avg_loss = 0.5887
# t = 10, avg_loss = 0.5949
# t = 11, avg_loss = 0.6378
# t = 12, avg_loss = 0.5868
# t = 13, avg_loss = 0.5872
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 24 / 80
# t = 1, avg_loss = 0.6450
# t = 2, avg_loss = 0.6831
# t = 3, avg_loss = 0.5668
# t = 4, avg_loss = 0.5166
# t = 5, avg_loss = 0.4938
# t = 6, avg_loss = 0.6526
# t = 7, avg_loss = 0.5243
# t = 8, avg_loss = 0.6129
# t = 9, avg_loss = 0.6296
# t = 10, avg_loss = 0.5148
# t = 11, avg_loss = 0.5177
# t = 12, avg_loss = 0.6117
# t = 13, avg_loss = 0.7203
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 25 / 80
# t = 1, avg_loss = 0.6446
# t = 2, avg_loss = 0.5141
# t = 3, avg_loss = 0.6612
# t = 4, avg_loss = 0.4628
# t = 5, avg_loss = 0.5661
# t = 6, avg_loss = 0.6181
# t = 7, avg_loss = 0.5501
# t = 8, avg_loss = 0.6494
# t = 9, avg_loss = 0.6438
# t = 10, avg_loss = 0.5558
# t = 11, avg_loss = 0.5595
# t = 12, avg_loss = 0.5103
# t = 13, avg_loss = 0.6542
# Checking accuracy on test set
# Got 151 / 200 correct (75.50)
# acc = 0.755000
# Starting epoch 26 / 80
# t = 1, avg_loss = 0.5357
# t = 2, avg_loss = 0.6034
# t = 3, avg_loss = 0.5749
# t = 4, avg_loss = 0.5793
# t = 5, avg_loss = 0.7100
# t = 6, avg_loss = 0.6490
# t = 7, avg_loss = 0.6169
# t = 8, avg_loss = 0.6261
# t = 9, avg_loss = 0.5267
# t = 10, avg_loss = 0.5949
# t = 11, avg_loss = 0.5498
# t = 12, avg_loss = 0.5134
# t = 13, avg_loss = 0.5509
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 27 / 80
# t = 1, avg_loss = 0.5846
# t = 2, avg_loss = 0.6019
# t = 3, avg_loss = 0.5661
# t = 4, avg_loss = 0.5786
# t = 5, avg_loss = 0.5359
# t = 6, avg_loss = 0.5657
# t = 7, avg_loss = 0.5775
# t = 8, avg_loss = 0.4383
# t = 9, avg_loss = 0.7062
# t = 10, avg_loss = 0.5891
# t = 11, avg_loss = 0.5894
# t = 12, avg_loss = 0.7034
# t = 13, avg_loss = 0.6247
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 28 / 80
# t = 1, avg_loss = 0.6218
# t = 2, avg_loss = 0.5760
# t = 3, avg_loss = 0.5696
# t = 4, avg_loss = 0.5119
# t = 5, avg_loss = 0.6105
# t = 6, avg_loss = 0.5732
# t = 7, avg_loss = 0.5507
# t = 8, avg_loss = 0.5618
# t = 9, avg_loss = 0.5608
# t = 10, avg_loss = 0.6712
# t = 11, avg_loss = 0.5092
# t = 12, avg_loss = 0.5532
# t = 13, avg_loss = 0.7257
# Checking accuracy on test set
# Got 150 / 200 correct (75.00)
# acc = 0.750000
# Starting epoch 29 / 80
# t = 1, avg_loss = 0.5367
# t = 2, avg_loss = 0.5768
# t = 3, avg_loss = 0.5163
# t = 4, avg_loss = 0.5984
# t = 5, avg_loss = 0.6050
# t = 6, avg_loss = 0.5159
# t = 7, avg_loss = 0.6330
# t = 8, avg_loss = 0.6534
# t = 9, avg_loss = 0.5213
# t = 10, avg_loss = 0.5875
# t = 11, avg_loss = 0.6810
# t = 12, avg_loss = 0.6034
# t = 13, avg_loss = 0.6516
# Checking accuracy on test set
# Got 146 / 200 correct (73.00)
# acc = 0.730000
# Starting epoch 30 / 80
# t = 1, avg_loss = 0.5560
# t = 2, avg_loss = 0.5374
# t = 3, avg_loss = 0.6130
# t = 4, avg_loss = 0.5155
# t = 5, avg_loss = 0.5093
# t = 6, avg_loss = 0.5543
# t = 7, avg_loss = 0.6386
# t = 8, avg_loss = 0.4784
# t = 9, avg_loss = 0.5518
# t = 10, avg_loss = 0.5265
# t = 11, avg_loss = 0.6024
# t = 12, avg_loss = 0.7087
# t = 13, avg_loss = 0.8605
# Checking accuracy on test set
# Got 148 / 200 correct (74.00)
# acc = 0.740000
# Starting epoch 31 / 80
# t = 1, avg_loss = 0.5251
# t = 2, avg_loss = 0.5934
# t = 3, avg_loss = 0.5235
# t = 4, avg_loss = 0.4543
# t = 5, avg_loss = 0.6511
# t = 6, avg_loss = 0.5921
# t = 7, avg_loss = 0.5845
# t = 8, avg_loss = 0.4798
# t = 9, avg_loss = 0.5844
# t = 10, avg_loss = 0.6547
# t = 11, avg_loss = 0.5984
# t = 12, avg_loss = 0.7051
# t = 13, avg_loss = 0.6312
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 32 / 80
# t = 1, avg_loss = 0.5373
# t = 2, avg_loss = 0.4904
# t = 3, avg_loss = 0.6059
# t = 4, avg_loss = 0.6083
# t = 5, avg_loss = 0.6090
# t = 6, avg_loss = 0.4520
# t = 7, avg_loss = 0.6189
# t = 8, avg_loss = 0.6265
# t = 9, avg_loss = 0.6402
# t = 10, avg_loss = 0.5978
# t = 11, avg_loss = 0.5716
# t = 12, avg_loss = 0.6089
# t = 13, avg_loss = 0.5575
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 33 / 80
# t = 1, avg_loss = 0.5744
# t = 2, avg_loss = 0.5131
# t = 3, avg_loss = 0.5536
# t = 4, avg_loss = 0.6935
# t = 5, avg_loss = 0.5159
# t = 6, avg_loss = 0.6415
# t = 7, avg_loss = 0.5326
# t = 8, avg_loss = 0.5881
# t = 9, avg_loss = 0.4915
# t = 10, avg_loss = 0.6799
# t = 11, avg_loss = 0.6546
# t = 12, avg_loss = 0.5215
# t = 13, avg_loss = 0.6136
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 34 / 80
# t = 1, avg_loss = 0.5085
# t = 2, avg_loss = 0.6716
# t = 3, avg_loss = 0.5425
# t = 4, avg_loss = 0.6275
# t = 5, avg_loss = 0.4922
# t = 6, avg_loss = 0.5232
# t = 7, avg_loss = 0.5695
# t = 8, avg_loss = 0.5345
# t = 9, avg_loss = 0.5708
# t = 10, avg_loss = 0.5594
# t = 11, avg_loss = 0.6124
# t = 12, avg_loss = 0.5614
# t = 13, avg_loss = 0.5968
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 35 / 80
# t = 1, avg_loss = 0.5245
# t = 2, avg_loss = 0.6093
# t = 3, avg_loss = 0.7396
# t = 4, avg_loss = 0.6017
# t = 5, avg_loss = 0.6009
# t = 6, avg_loss = 0.5468
# t = 7, avg_loss = 0.5760
# t = 8, avg_loss = 0.5650
# t = 9, avg_loss = 0.5590
# t = 10, avg_loss = 0.5540
# t = 11, avg_loss = 0.5804
# t = 12, avg_loss = 0.5767
# t = 13, avg_loss = 0.4913
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 36 / 80
# t = 1, avg_loss = 0.5149
# t = 2, avg_loss = 0.5403
# t = 3, avg_loss = 0.5641
# t = 4, avg_loss = 0.5239
# t = 5, avg_loss = 0.5143
# t = 6, avg_loss = 0.4723
# t = 7, avg_loss = 0.6057
# t = 8, avg_loss = 0.5817
# t = 9, avg_loss = 0.7538
# t = 10, avg_loss = 0.5646
# t = 11, avg_loss = 0.6437
# t = 12, avg_loss = 0.5738
# t = 13, avg_loss = 0.8755
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 37 / 80
# t = 1, avg_loss = 0.5754
# t = 2, avg_loss = 0.5873
# t = 3, avg_loss = 0.6171
# t = 4, avg_loss = 0.5945
# t = 5, avg_loss = 0.5741
# t = 6, avg_loss = 0.5777
# t = 7, avg_loss = 0.6146
# t = 8, avg_loss = 0.5034
# t = 9, avg_loss = 0.6202
# t = 10, avg_loss = 0.5426
# t = 11, avg_loss = 0.6602
# t = 12, avg_loss = 0.5230
# t = 13, avg_loss = 0.5743
# Checking accuracy on test set
# Got 149 / 200 correct (74.50)
# acc = 0.745000
# Starting epoch 38 / 80
# t = 1, avg_loss = 0.6704
# t = 2, avg_loss = 0.5889
# t = 3, avg_loss = 0.4839
# t = 4, avg_loss = 0.5023
# t = 5, avg_loss = 0.6132
# t = 6, avg_loss = 0.7013
# t = 7, avg_loss = 0.6308
# t = 8, avg_loss = 0.5557
# t = 9, avg_loss = 0.6019
# t = 10, avg_loss = 0.5306
# t = 11, avg_loss = 0.6507
# t = 12, avg_loss = 0.5026
# t = 13, avg_loss = 0.4972
# Checking accuracy on test set
# Got 150 / 200 correct (75.00)
# acc = 0.750000
# Starting epoch 39 / 80
# t = 1, avg_loss = 0.5825
# t = 2, avg_loss = 0.5449
# t = 3, avg_loss = 0.5467
# t = 4, avg_loss = 0.6099
# t = 5, avg_loss = 0.5932
# t = 6, avg_loss = 0.5700
# t = 7, avg_loss = 0.6322
# t = 8, avg_loss = 0.5055
# t = 9, avg_loss = 0.5983
# t = 10, avg_loss = 0.6281
# t = 11, avg_loss = 0.5019
# t = 12, avg_loss = 0.5672
# t = 13, avg_loss = 0.5576
# Checking accuracy on test set
# Got 151 / 200 correct (75.50)
# acc = 0.755000
# Starting epoch 40 / 80
# t = 1, avg_loss = 0.5685
# t = 2, avg_loss = 0.6095
# t = 3, avg_loss = 0.5605
# t = 4, avg_loss = 0.4814
# t = 5, avg_loss = 0.4906
# t = 6, avg_loss = 0.5597
# t = 7, avg_loss = 0.5635
# t = 8, avg_loss = 0.6620
# t = 9, avg_loss = 0.6134
# t = 10, avg_loss = 0.5816
# t = 11, avg_loss = 0.6098
# t = 12, avg_loss = 0.5934
# t = 13, avg_loss = 0.5131
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 41 / 80
# t = 1, avg_loss = 0.5326
# t = 2, avg_loss = 0.6139
# t = 3, avg_loss = 0.4735
# t = 4, avg_loss = 0.7284
# t = 5, avg_loss = 0.5549
# t = 6, avg_loss = 0.5862
# t = 7, avg_loss = 0.5094
# t = 8, avg_loss = 0.5635
# t = 9, avg_loss = 0.5347
# t = 10, avg_loss = 0.6444
# t = 11, avg_loss = 0.5249
# t = 12, avg_loss = 0.5855
# t = 13, avg_loss = 0.4602
# Checking accuracy on test set
# Got 149 / 200 correct (74.50)
# acc = 0.745000
# Starting epoch 42 / 80
# t = 1, avg_loss = 0.5763
# t = 2, avg_loss = 0.6291
# t = 3, avg_loss = 0.5956
# t = 4, avg_loss = 0.5733
# t = 5, avg_loss = 0.5726
# t = 6, avg_loss = 0.5875
# t = 7, avg_loss = 0.5439
# t = 8, avg_loss = 0.5711
# t = 9, avg_loss = 0.6187
# t = 10, avg_loss = 0.4978
# t = 11, avg_loss = 0.5836
# t = 12, avg_loss = 0.6917
# t = 13, avg_loss = 0.5384
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 43 / 80
# t = 1, avg_loss = 0.5847
# t = 2, avg_loss = 0.5296
# t = 3, avg_loss = 0.5943
# t = 4, avg_loss = 0.5148
# t = 5, avg_loss = 0.5922
# t = 6, avg_loss = 0.6159
# t = 7, avg_loss = 0.6537
# t = 8, avg_loss = 0.5365
# t = 9, avg_loss = 0.5347
# t = 10, avg_loss = 0.4742
# t = 11, avg_loss = 0.5022
# t = 12, avg_loss = 0.6562
# t = 13, avg_loss = 0.5547
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 44 / 80
# t = 1, avg_loss = 0.5689
# t = 2, avg_loss = 0.6449
# t = 3, avg_loss = 0.6684
# t = 4, avg_loss = 0.5204
# t = 5, avg_loss = 0.7529
# t = 6, avg_loss = 0.5188
# t = 7, avg_loss = 0.4344
# t = 8, avg_loss = 0.5983
# t = 9, avg_loss = 0.4529
# t = 10, avg_loss = 0.6061
# t = 11, avg_loss = 0.5222
# t = 12, avg_loss = 0.5624
# t = 13, avg_loss = 0.5801
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 45 / 80
# t = 1, avg_loss = 0.4956
# t = 2, avg_loss = 0.4269
# t = 3, avg_loss = 0.5618
# t = 4, avg_loss = 0.5056
# t = 5, avg_loss = 0.5326
# t = 6, avg_loss = 0.5780
# t = 7, avg_loss = 0.5152
# t = 8, avg_loss = 0.5747
# t = 9, avg_loss = 0.5300
# t = 10, avg_loss = 0.5967
# t = 11, avg_loss = 0.6283
# t = 12, avg_loss = 0.6078
# t = 13, avg_loss = 0.5990
# Checking accuracy on test set
# Got 153 / 200 correct (76.50)
# acc = 0.765000
# Starting epoch 46 / 80
# t = 1, avg_loss = 0.6971
# t = 2, avg_loss = 0.6353
# t = 3, avg_loss = 0.6270
# t = 4, avg_loss = 0.5197
# t = 5, avg_loss = 0.5687
# t = 6, avg_loss = 0.5491
# t = 7, avg_loss = 0.5257
# t = 8, avg_loss = 0.5938
# t = 9, avg_loss = 0.5395
# t = 10, avg_loss = 0.4920
# t = 11, avg_loss = 0.5215
# t = 12, avg_loss = 0.5299
# t = 13, avg_loss = 0.5637
# Checking accuracy on test set
# Got 144 / 200 correct (72.00)
# acc = 0.720000
# Starting epoch 47 / 80
# t = 1, avg_loss = 0.5432
# t = 2, avg_loss = 0.6544
# t = 3, avg_loss = 0.5242
# t = 4, avg_loss = 0.6027
# t = 5, avg_loss = 0.6494
# t = 6, avg_loss = 0.5139
# t = 7, avg_loss = 0.5013
# t = 8, avg_loss = 0.4753
# t = 9, avg_loss = 0.5543
# t = 10, avg_loss = 0.5208
# t = 11, avg_loss = 0.5361
# t = 12, avg_loss = 0.5619
# t = 13, avg_loss = 0.5478
# Checking accuracy on test set
# Got 150 / 200 correct (75.00)
# acc = 0.750000
# Starting epoch 48 / 80
# t = 1, avg_loss = 0.4682
# t = 2, avg_loss = 0.4935
# t = 3, avg_loss = 0.5734
# t = 4, avg_loss = 0.6810
# t = 5, avg_loss = 0.4946
# t = 6, avg_loss = 0.5814
# t = 7, avg_loss = 0.6313
# t = 8, avg_loss = 0.5726
# t = 9, avg_loss = 0.6120
# t = 10, avg_loss = 0.5279
# t = 11, avg_loss = 0.5885
# t = 12, avg_loss = 0.6816
# t = 13, avg_loss = 0.3720
# Checking accuracy on test set
# Got 151 / 200 correct (75.50)
# acc = 0.755000
# Starting epoch 49 / 80
# t = 1, avg_loss = 0.5019
# t = 2, avg_loss = 0.5676
# t = 3, avg_loss = 0.4864
# t = 4, avg_loss = 0.5927
# t = 5, avg_loss = 0.6019
# t = 6, avg_loss = 0.5509
# t = 7, avg_loss = 0.6047
# t = 8, avg_loss = 0.4743
# t = 9, avg_loss = 0.5392
# t = 10, avg_loss = 0.6381
# t = 11, avg_loss = 0.4939
# t = 12, avg_loss = 0.6454
# t = 13, avg_loss = 0.5039
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 50 / 80
# t = 1, avg_loss = 0.6126
# t = 2, avg_loss = 0.5473
# t = 3, avg_loss = 0.4846
# t = 4, avg_loss = 0.6206
# t = 5, avg_loss = 0.5247
# t = 6, avg_loss = 0.5988
# t = 7, avg_loss = 0.5379
# t = 8, avg_loss = 0.5162
# t = 9, avg_loss = 0.6024
# t = 10, avg_loss = 0.5753
# t = 11, avg_loss = 0.6349
# t = 12, avg_loss = 0.6072
# t = 13, avg_loss = 0.5443
# Checking accuracy on test set
# Got 151 / 200 correct (75.50)
# acc = 0.755000
# Starting epoch 51 / 80
# t = 1, avg_loss = 0.5688
# t = 2, avg_loss = 0.6050
# t = 3, avg_loss = 0.6879
# t = 4, avg_loss = 0.5208
# t = 5, avg_loss = 0.7176
# t = 6, avg_loss = 0.4807
# t = 7, avg_loss = 0.5508
# t = 8, avg_loss = 0.4366
# t = 9, avg_loss = 0.5932
# t = 10, avg_loss = 0.5193
# t = 11, avg_loss = 0.4643
# t = 12, avg_loss = 0.6008
# t = 13, avg_loss = 0.5422
# Checking accuracy on test set
# Got 150 / 200 correct (75.00)
# acc = 0.750000
# Starting epoch 52 / 80
# t = 1, avg_loss = 0.4882
# t = 2, avg_loss = 0.6259
# t = 3, avg_loss = 0.5126
# t = 4, avg_loss = 0.5143
# t = 5, avg_loss = 0.5130
# t = 6, avg_loss = 0.5302
# t = 7, avg_loss = 0.4887
# t = 8, avg_loss = 0.5519
# t = 9, avg_loss = 0.6873
# t = 10, avg_loss = 0.5568
# t = 11, avg_loss = 0.6824
# t = 12, avg_loss = 0.6326
# t = 13, avg_loss = 0.5831
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 53 / 80
# t = 1, avg_loss = 0.5780
# t = 2, avg_loss = 0.6568
# t = 3, avg_loss = 0.4816
# t = 4, avg_loss = 0.4821
# t = 5, avg_loss = 0.6000
# t = 6, avg_loss = 0.5486
# t = 7, avg_loss = 0.4927
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-173c6a1d36c8> in <module>()
#      56 optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay)
#      57
# ---> 58 train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
#      59 check_accuracy(model_gpu, valid_loader)
#
# <ipython-input-9-7b7c48cb9b8f> in train(model, train_loader, loss_fn, optimizer, num_epochs, starting_from_epoch)
#       9         model.train()
#      10
# ---> 11         for t, (x, y) in enumerate(train_loader):
#      12             x_var = Variable(x.type(gpu_dtype))
#      13             y_var = Variable(y.type(gpu_dtype).long())
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-7-50a9cd504daf> in __getitem__(self, index)
#      16         else:
#      17           image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", index ))
# ---> 18         image = self.transform(image)
#      19         return image, label
#      20
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      68     def __call__(self, img):
#      69         for t in self.transforms:
# ---> 70             img = t(img)
#      71         return img
#      72
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#     205             PIL Image: Rescaled image.
#     206         """
# --> 207         return F.resize(img, self.size, self.interpolation)
#     208
#     209     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py in resize(img, size, interpolation)
#     254             return img.resize((ow, oh), interpolation)
#     255     else:
# --> 256         return img.resize(size[::-1], interpolation)
#     257
#     258
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1856             return im.convert(self.mode)
#    1857
# -> 1858         self.load()
#    1859
#    1860         if reducing_gap is not None and resample != NEAREST:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in load(self)
#     249
#     250                             b = b + s
# --> 251                             n, err_code = decoder.decode(b)
#     252                             if n < 0:
#     253                                 break
#
# KeyboardInterrupt:

# %%
check_accuracy(model_gpu, valid_loader)
# Out:
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# 0.725

# %%
def retry_from_backup()
  model_gpu = model_base.type(gpu_dtype)
  print(model_gpu)
  loss_fn = nn.modules.loss.CrossEntropyLoss()
  optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay) 



  checkpoint = torch.load(model_backup_path)
  model_gpu.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch = checkpoint['epoch']
  loss = checkpoint['loss']
  print("starting from epoch: " + str(epoch))
  print("starting from loss: " + str(loss))
  print(checkpoint['model_state_dict'])
  print(checkpoint['optimizer_state_dict'])

  train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs, starting_from_epoch=epoch)
  check_accuracy(model_gpu, valid_loader)
#retry_from_backup()

# %%
import matplotlib.pyplot as plt

plt.plot([print_every*batch_size*(i+1) for i in range((len(avg_loss_list)))],avg_loss_list)
print("Loss:")
plt.show()
# Out:
# Loss:

# %%
plt.plot([i+1 for i in range((len(acc_list)))],acc_list)
print("Accurancy:")
plt.show()
# Out:
# Accurancy:

# %%
#%tensorboard --logdir {logs_base_dir}
