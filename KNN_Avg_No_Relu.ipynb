# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilo116/KNN/blob/master/KNN_Avg_No_Relu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import os
import csv
import sys
from random import shuffle
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
# %matplotlib inline
from sklearn.model_selection import train_test_split

import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
from torch.utils.data.sampler import SubsetRandomSampler

import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T
import torchvision.transforms as transforms
import timeit

np.random.seed(4) 
torch.manual_seed(4) 
torch.cuda.manual_seed(4)

# %%
! git clone https://github.com/wang-chen/kervolution.git 

sys.path.append("kervolution/")
from kervolution import Kerv2d
# Out:
# Cloning into 'kervolution'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 53 (delta 2), reused 0 (delta 0), pack-reused 47
# Unpacking objects: 100% (53/53), done.

# %%
LIMIT_IMAGES_NUM = 500
train_test_split_size = 0.2
image_resize = (100, 100)
batch_size = 64
num_workers = 0

in_channels = 3
out_channels_1 = 16
out_channels_2 = 32
out_channels_3 = 64
out_channels_4 = 128

kernel_size = 3
padding_1 = 1
num_epochs = 80

learning_rate = 0.00001
weight_decay = 0

MALIGNANT_DATASET = '/content/drive/My Drive/Colab_data/malignant/malignant/'
BENIGN_DATASET = '/content/drive/My Drive/Colab_data/benign/benign/'
DATA_FOLDER = '/content/drive/My Drive/Colab_data/'
model_backup_path = os.path.join(DATA_FOLDER, 'backup_model')

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
benign_file_list = sorted(os.listdir(BENIGN_DATASET))
malignant_file_list = sorted(os.listdir(MALIGNANT_DATASET))
shuffle(benign_file_list)
shuffle(malignant_file_list)
benign_file_list = benign_file_list[:LIMIT_IMAGES_NUM]
malignant_file_list = malignant_file_list[:LIMIT_IMAGES_NUM]

print(f"Number of benign {len(benign_file_list)} images")
print(f"Number of malignant {len(malignant_file_list)} images")

data_transforms = transforms.Compose([
    transforms.Resize(image_resize),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Out:
# Number of benign 500 images
# Number of malignant 500 images

# %%
benign_dict = {filename: 0 for filename in benign_file_list}
malignant_dict = {filename: 1 for filename in malignant_file_list}
img_class_dict = {**benign_dict , **malignant_dict}
labeled_data = pd.Series(img_class_dict)

# %%
class IsicDataset(Dataset):
    def __init__(self, data_folder, labeled_data, 
                 transform=transforms.Compose([transforms.ToTensor()])):
        self.labeled_data = labeled_data
        self.transform = transform
        self.data_folder = data_folder
        
        
    def __len__(self):
        return len(self.labeled_data)

    def __getitem__(self, index):
        label = self.labeled_data[index]
        if label == 0:
          image = Image.open(os.path.join(self.data_folder, "benign", "benign", index ))
        else:
          image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", index ))
        image = self.transform(image)
        return image, label

    @property
    def labels(self):
      return self.labeled_data

# %%
 
dataset = IsicDataset(DATA_FOLDER, labeled_data, transform=data_transforms)
print(dataset.labels)

X_train, X_test = train_test_split(dataset.labels, test_size=train_test_split_size)
print("number of training data: ",len(X_train))
print("number of testing  data: ",len(X_test))

train_sampler = SubsetRandomSampler(list(X_train.index))
valid_sampler = SubsetRandomSampler(list(X_test.index))


train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
# Out:
# ISIC_0000371.jpeg    0
# ISIC_0000965.jpeg    0
# ISIC_0000681.jpeg    0
# ISIC_0002460.jpeg    0
# ISIC_0000059.jpeg    0
#                     ..
# ISIC_0011488.jpeg    1
# ISIC_0010912.jpeg    1
# ISIC_0013953.jpeg    1
# ISIC_0015193.jpeg    1
# ISIC_0010468.jpeg    1
# Length: 1000, dtype: int64
# number of training data:  800
# number of testing  data:  200

# %%
avg_loss_list = []
acc_list = []

def train(model, train_loader ,loss_fn, optimizer, num_epochs=1, starting_from_epoch=1):
    total_loss =0

    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()

        for t, (x, y) in enumerate(train_loader):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())
            scores = model(x_var)
            loss = loss_fn(scores, y_var)
            total_loss += loss.data
            
            if (t + 1) % print_every == 0:
                avg_loss = total_loss/print_every
                print('t = %d, avg_loss = %.4f' % (t + 1, avg_loss) )
                avg_loss_list.append(avg_loss)
                total_loss = 0
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        acc = check_accuracy(model_gpu, valid_loader)
        print('acc = %f' %(acc))
        torch.save({
            'epoch': epoch,
            'model_state_dict': model_gpu.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
            }, model_backup_path)
            
def check_accuracy(model, loader):
    print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() 
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype))

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    acc_list.append(acc)
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size()
        return x.view(N, -1)

# %%
gpu_dtype = torch.cuda.FloatTensor

print_every = 1


'''
Kerv2d
kervolution with following options:
kernel_type: [linear, polynomial, gaussian, etc.]
default is convolution:
          kernel_type --> linear,
balance, power, gamma is valid only when the kernel_type is specified
if learnable_kernel = True,  they just be the initial value of learable parameters
if learnable_kernel = False, they are the value of kernel_type's parameter
the parameter [power] cannot be learned due to integer limitation
dilation (int or tuple, optional): Spacing between kernel
elements. Default: 1
groups (int, optional): Number of blocked connections from input
channels to output channels. Default: 1
bias (bool, optional): If ``True``, adds a learnable bias to the output. Default: ``True``
kernel_type (str), Default: 'linear'
learnable_kernel (bool): Learnable kernel parameters.  Default: False 
balance: 0, 1
power: 3, 4, 5
gamma:
'''


model_base = nn.Sequential( 
                nn.Kerv2d(in_channels , out_channels_1, padding=padding_1, dilation=1, groups=1, bias=True, 
                          kernel_type='polynomial', kernel_size=kernel_size, learnable_kernel=True,
                          kernel_regularizer=True, stride=1, balance=1, power=3, gamma=1
                          ),
                nn.BatchNorm2d(out_channels_1),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_1 , out_channels_2, padding= padding_1, kernel_size=kernel_size, stride=1), 
                nn.BatchNorm2d(out_channels_2),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_2 , out_channels_3, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_3),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_3 , out_channels_4, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_4),
                nn.AvgPool2d(2, stride=2),
                nn.Dropout(0.5),
                Flatten(),
                nn.Linear(4608,64),
                nn.Linear(64,2)
            )
model_gpu = model_base.type(gpu_dtype)
print(model_gpu)
loss_fn = nn.modules.loss.CrossEntropyLoss()
optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay) 

train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
check_accuracy(model_gpu, valid_loader)
# Out:
# Sequential(
#   (0): Kerv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (9): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (12): Dropout(p=0.5, inplace=False)
#   (13): Flatten()
#   (14): Linear(in_features=4608, out_features=64, bias=True)
#   (15): Linear(in_features=64, out_features=2, bias=True)
# )
# Starting epoch 1 / 80
# t = 1, avg_loss = 0.7185
# t = 2, avg_loss = 0.6679
# t = 3, avg_loss = 0.6992
# t = 4, avg_loss = 0.7765
# t = 5, avg_loss = 0.7741
# t = 6, avg_loss = 0.8322
# t = 7, avg_loss = 0.6597
# t = 8, avg_loss = 0.6820
# t = 9, avg_loss = 0.7088
# t = 10, avg_loss = 0.6930
# t = 11, avg_loss = 0.7302
# t = 12, avg_loss = 0.6610
# t = 13, avg_loss = 0.6903
# Checking accuracy on test set
# Got 131 / 200 correct (65.50)
# acc = 0.655000
# Starting epoch 2 / 80
# t = 1, avg_loss = 0.6668
# t = 2, avg_loss = 0.6077
# t = 3, avg_loss = 0.6563
# t = 4, avg_loss = 0.6527
# t = 5, avg_loss = 0.7190
# t = 6, avg_loss = 0.6740
# t = 7, avg_loss = 0.6743
# t = 8, avg_loss = 0.6572
# t = 9, avg_loss = 0.6986
# t = 10, avg_loss = 0.7109
# t = 11, avg_loss = 0.7512
# t = 12, avg_loss = 0.6903
# t = 13, avg_loss = 0.6635
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 3 / 80
# t = 1, avg_loss = 0.6368
# t = 2, avg_loss = 0.7256
# t = 3, avg_loss = 0.6793
# t = 4, avg_loss = 0.6750
# t = 5, avg_loss = 0.6433
# t = 6, avg_loss = 0.6350
# t = 7, avg_loss = 0.6513
# t = 8, avg_loss = 0.7210
# t = 9, avg_loss = 0.6414
# t = 10, avg_loss = 0.6021
# t = 11, avg_loss = 0.6551
# t = 12, avg_loss = 0.6752
# t = 13, avg_loss = 0.6325
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 4 / 80
# t = 1, avg_loss = 0.6995
# t = 2, avg_loss = 0.6701
# t = 3, avg_loss = 0.5587
# t = 4, avg_loss = 0.7659
# t = 5, avg_loss = 0.6626
# t = 6, avg_loss = 0.6393
# t = 7, avg_loss = 0.7195
# t = 8, avg_loss = 0.7025
# t = 9, avg_loss = 0.6538
# t = 10, avg_loss = 0.6104
# t = 11, avg_loss = 0.5911
# t = 12, avg_loss = 0.6884
# t = 13, avg_loss = 0.7545
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 5 / 80
# t = 1, avg_loss = 0.7037
# t = 2, avg_loss = 0.6913
# t = 3, avg_loss = 0.6855
# t = 4, avg_loss = 0.7179
# t = 5, avg_loss = 0.6337
# t = 6, avg_loss = 0.6524
# t = 7, avg_loss = 0.7134
# t = 8, avg_loss = 0.6794
# t = 9, avg_loss = 0.7418
# t = 10, avg_loss = 0.7093
# t = 11, avg_loss = 0.6454
# t = 12, avg_loss = 0.6462
# t = 13, avg_loss = 0.6549
# Checking accuracy on test set
# Got 140 / 200 correct (70.00)
# acc = 0.700000
# Starting epoch 6 / 80
# t = 1, avg_loss = 0.6912
# t = 2, avg_loss = 0.6742
# t = 3, avg_loss = 0.6962
# t = 4, avg_loss = 0.6551
# t = 5, avg_loss = 0.6073
# t = 6, avg_loss = 0.6113
# t = 7, avg_loss = 0.6215
# t = 8, avg_loss = 0.6449
# t = 9, avg_loss = 0.6441
# t = 10, avg_loss = 0.7150
# t = 11, avg_loss = 0.6868
# t = 12, avg_loss = 0.5746
# t = 13, avg_loss = 0.6468
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 7 / 80
# t = 1, avg_loss = 0.6437
# t = 2, avg_loss = 0.6398
# t = 3, avg_loss = 0.6380
# t = 4, avg_loss = 0.6791
# t = 5, avg_loss = 0.6705
# t = 6, avg_loss = 0.6285
# t = 7, avg_loss = 0.6192
# t = 8, avg_loss = 0.5842
# t = 9, avg_loss = 0.6343
# t = 10, avg_loss = 0.5965
# t = 11, avg_loss = 0.6519
# t = 12, avg_loss = 0.6753
# t = 13, avg_loss = 0.7190
# Checking accuracy on test set
# Got 140 / 200 correct (70.00)
# acc = 0.700000
# Starting epoch 8 / 80
# t = 1, avg_loss = 0.7878
# t = 2, avg_loss = 0.6452
# t = 3, avg_loss = 0.6565
# t = 4, avg_loss = 0.7058
# t = 5, avg_loss = 0.6257
# t = 6, avg_loss = 0.6950
# t = 7, avg_loss = 0.6180
# t = 8, avg_loss = 0.6161
# t = 9, avg_loss = 0.6473
# t = 10, avg_loss = 0.6495
# t = 11, avg_loss = 0.5458
# t = 12, avg_loss = 0.6571
# t = 13, avg_loss = 0.6920
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 9 / 80
# t = 1, avg_loss = 0.6036
# t = 2, avg_loss = 0.6360
# t = 3, avg_loss = 0.6384
# t = 4, avg_loss = 0.6476
# t = 5, avg_loss = 0.5543
# t = 6, avg_loss = 0.7485
# t = 7, avg_loss = 0.6688
# t = 8, avg_loss = 0.6738
# t = 9, avg_loss = 0.6964
# t = 10, avg_loss = 0.5721
# t = 11, avg_loss = 0.6402
# t = 12, avg_loss = 0.6696
# t = 13, avg_loss = 0.5751
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 10 / 80
# t = 1, avg_loss = 0.5969
# t = 2, avg_loss = 0.6063
# t = 3, avg_loss = 0.6507
# t = 4, avg_loss = 0.6429
# t = 5, avg_loss = 0.6336
# t = 6, avg_loss = 0.5989
# t = 7, avg_loss = 0.5513
# t = 8, avg_loss = 0.6533
# t = 9, avg_loss = 0.6726
# t = 10, avg_loss = 0.6712
# t = 11, avg_loss = 0.6156
# t = 12, avg_loss = 0.6069
# t = 13, avg_loss = 0.7054
# Checking accuracy on test set
# Got 144 / 200 correct (72.00)
# acc = 0.720000
# Starting epoch 11 / 80
# t = 1, avg_loss = 0.5661
# t = 2, avg_loss = 0.6213
# t = 3, avg_loss = 0.6932
# t = 4, avg_loss = 0.6437
# t = 5, avg_loss = 0.7109
# t = 6, avg_loss = 0.5491
# t = 7, avg_loss = 0.7091
# t = 8, avg_loss = 0.6233
# t = 9, avg_loss = 0.6124
# t = 10, avg_loss = 0.6423
# t = 11, avg_loss = 0.6900
# t = 12, avg_loss = 0.6404
# t = 13, avg_loss = 0.6789
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 12 / 80
# t = 1, avg_loss = 0.5210
# t = 2, avg_loss = 0.6874
# t = 3, avg_loss = 0.6288
# t = 4, avg_loss = 0.6659
# t = 5, avg_loss = 0.6660
# t = 6, avg_loss = 0.6497
# t = 7, avg_loss = 0.6272
# t = 8, avg_loss = 0.5672
# t = 9, avg_loss = 0.6215
# t = 10, avg_loss = 0.6539
# t = 11, avg_loss = 0.6853
# t = 12, avg_loss = 0.6535
# t = 13, avg_loss = 0.6764
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 13 / 80
# t = 1, avg_loss = 0.6448
# t = 2, avg_loss = 0.6256
# t = 3, avg_loss = 0.6544
# t = 4, avg_loss = 0.6556
# t = 5, avg_loss = 0.6725
# t = 6, avg_loss = 0.5650
# t = 7, avg_loss = 0.7030
# t = 8, avg_loss = 0.6819
# t = 9, avg_loss = 0.5870
# t = 10, avg_loss = 0.5831
# t = 11, avg_loss = 0.6648
# t = 12, avg_loss = 0.7157
# t = 13, avg_loss = 0.5531
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 14 / 80
# t = 1, avg_loss = 0.6497
# t = 2, avg_loss = 0.6358
# t = 3, avg_loss = 0.6296
# t = 4, avg_loss = 0.5337
# t = 5, avg_loss = 0.6244
# t = 6, avg_loss = 0.6769
# t = 7, avg_loss = 0.7047
# t = 8, avg_loss = 0.6234
# t = 9, avg_loss = 0.6776
# t = 10, avg_loss = 0.5185
# t = 11, avg_loss = 0.6674
# t = 12, avg_loss = 0.5462
# t = 13, avg_loss = 0.6095
# Checking accuracy on test set
# Got 140 / 200 correct (70.00)
# acc = 0.700000
# Starting epoch 15 / 80
# t = 1, avg_loss = 0.6046
# t = 2, avg_loss = 0.5785
# t = 3, avg_loss = 0.6350
# t = 4, avg_loss = 0.5981
# t = 5, avg_loss = 0.5336
# t = 6, avg_loss = 0.6023
# t = 7, avg_loss = 0.5918
# t = 8, avg_loss = 0.6189
# t = 9, avg_loss = 0.6024
# t = 10, avg_loss = 0.6145
# t = 11, avg_loss = 0.6479
# t = 12, avg_loss = 0.7075
# t = 13, avg_loss = 0.5643
# Checking accuracy on test set
# Got 136 / 200 correct (68.00)
# acc = 0.680000
# Starting epoch 16 / 80
# t = 1, avg_loss = 0.6088
# t = 2, avg_loss = 0.6265
# t = 3, avg_loss = 0.6739
# t = 4, avg_loss = 0.5754
# t = 5, avg_loss = 0.6096
# t = 6, avg_loss = 0.6284
# t = 7, avg_loss = 0.6026
# t = 8, avg_loss = 0.6627
# t = 9, avg_loss = 0.5890
# t = 10, avg_loss = 0.6658
# t = 11, avg_loss = 0.6748
# t = 12, avg_loss = 0.6371
# t = 13, avg_loss = 0.6576
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 17 / 80
# t = 1, avg_loss = 0.6015
# t = 2, avg_loss = 0.5800
# t = 3, avg_loss = 0.7358
# t = 4, avg_loss = 0.6700
# t = 5, avg_loss = 0.6077
# t = 6, avg_loss = 0.5733
# t = 7, avg_loss = 0.5511
# t = 8, avg_loss = 0.6009
# t = 9, avg_loss = 0.5907
# t = 10, avg_loss = 0.7260
# t = 11, avg_loss = 0.6580
# t = 12, avg_loss = 0.6925
# t = 13, avg_loss = 0.6200
# Checking accuracy on test set
# Got 141 / 200 correct (70.50)
# acc = 0.705000
# Starting epoch 18 / 80
# t = 1, avg_loss = 0.6120
# t = 2, avg_loss = 0.6242
# t = 3, avg_loss = 0.5751
# t = 4, avg_loss = 0.6020
# t = 5, avg_loss = 0.5794
# t = 6, avg_loss = 0.6330
# t = 7, avg_loss = 0.5687
# t = 8, avg_loss = 0.6131
# t = 9, avg_loss = 0.6189
# t = 10, avg_loss = 0.6678
# t = 11, avg_loss = 0.6518
# t = 12, avg_loss = 0.5811
# t = 13, avg_loss = 0.6688
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 19 / 80
# t = 1, avg_loss = 0.5570
# t = 2, avg_loss = 0.6657
# t = 3, avg_loss = 0.6236
# t = 4, avg_loss = 0.6485
# t = 5, avg_loss = 0.6149
# t = 6, avg_loss = 0.6082
# t = 7, avg_loss = 0.6150
# t = 8, avg_loss = 0.5743
# t = 9, avg_loss = 0.6105
# t = 10, avg_loss = 0.6917
# t = 11, avg_loss = 0.5962
# t = 12, avg_loss = 0.5618
# t = 13, avg_loss = 0.5750
# Checking accuracy on test set
# Got 147 / 200 correct (73.50)
# acc = 0.735000
# Starting epoch 20 / 80
# t = 1, avg_loss = 0.6292
# t = 2, avg_loss = 0.5953
# t = 3, avg_loss = 0.5951
# t = 4, avg_loss = 0.5692
# t = 5, avg_loss = 0.6607
# t = 6, avg_loss = 0.6238
# t = 7, avg_loss = 0.5493
# t = 8, avg_loss = 0.6207
# t = 9, avg_loss = 0.6712
# t = 10, avg_loss = 0.6185
# t = 11, avg_loss = 0.6499
# t = 12, avg_loss = 0.4791
# t = 13, avg_loss = 0.5909
# Checking accuracy on test set
# Got 144 / 200 correct (72.00)
# acc = 0.720000
# Starting epoch 21 / 80
# t = 1, avg_loss = 0.5968
# t = 2, avg_loss = 0.6571
# t = 3, avg_loss = 0.7155
# t = 4, avg_loss = 0.6516
# t = 5, avg_loss = 0.5683
# t = 6, avg_loss = 0.6051
# t = 7, avg_loss = 0.5856
# t = 8, avg_loss = 0.5396
# t = 9, avg_loss = 0.5539
# t = 10, avg_loss = 0.6468
# t = 11, avg_loss = 0.5463
# t = 12, avg_loss = 0.5928
# t = 13, avg_loss = 0.5725
# Checking accuracy on test set
# Got 143 / 200 correct (71.50)
# acc = 0.715000
# Starting epoch 22 / 80
# t = 1, avg_loss = 0.4495
# t = 2, avg_loss = 0.6648
# t = 3, avg_loss = 0.5686
# t = 4, avg_loss = 0.5663
# t = 5, avg_loss = 0.5499
# t = 6, avg_loss = 0.6671
# t = 7, avg_loss = 0.6250
# t = 8, avg_loss = 0.5994
# t = 9, avg_loss = 0.6534
# t = 10, avg_loss = 0.7329
# t = 11, avg_loss = 0.5247
# t = 12, avg_loss = 0.5991
# t = 13, avg_loss = 0.6302
# Checking accuracy on test set
# Got 143 / 200 correct (71.50)
# acc = 0.715000
# Starting epoch 23 / 80
# t = 1, avg_loss = 0.6398
# t = 2, avg_loss = 0.6846
# t = 3, avg_loss = 0.5820
# t = 4, avg_loss = 0.5937
# t = 5, avg_loss = 0.5370
# t = 6, avg_loss = 0.5925
# t = 7, avg_loss = 0.6134
# t = 8, avg_loss = 0.5863
# t = 9, avg_loss = 0.5273
# t = 10, avg_loss = 0.5954
# t = 11, avg_loss = 0.6563
# t = 12, avg_loss = 0.6190
# t = 13, avg_loss = 0.6172
# Checking accuracy on test set
# Got 147 / 200 correct (73.50)
# acc = 0.735000
# Starting epoch 24 / 80
# t = 1, avg_loss = 0.5267
# t = 2, avg_loss = 0.6181
# t = 3, avg_loss = 0.5603
# t = 4, avg_loss = 0.6191
# t = 5, avg_loss = 0.5426
# t = 6, avg_loss = 0.7233
# t = 7, avg_loss = 0.6668
# t = 8, avg_loss = 0.6488
# t = 9, avg_loss = 0.6314
# t = 10, avg_loss = 0.5927
# t = 11, avg_loss = 0.5644
# t = 12, avg_loss = 0.5871
# t = 13, avg_loss = 0.5308
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 25 / 80
# t = 1, avg_loss = 0.6140
# t = 2, avg_loss = 0.5946
# t = 3, avg_loss = 0.7129
# t = 4, avg_loss = 0.5430
# t = 5, avg_loss = 0.6281
# t = 6, avg_loss = 0.5641
# t = 7, avg_loss = 0.7068
# t = 8, avg_loss = 0.5876
# t = 9, avg_loss = 0.6120
# t = 10, avg_loss = 0.5554
# t = 11, avg_loss = 0.5030
# t = 12, avg_loss = 0.5868
# t = 13, avg_loss = 0.5898
# Checking accuracy on test set
# Got 144 / 200 correct (72.00)
# acc = 0.720000
# Starting epoch 26 / 80
# t = 1, avg_loss = 0.5216
# t = 2, avg_loss = 0.6265
# t = 3, avg_loss = 0.6358
# t = 4, avg_loss = 0.6459
# t = 5, avg_loss = 0.5972
# t = 6, avg_loss = 0.6223
# t = 7, avg_loss = 0.6463
# t = 8, avg_loss = 0.6170
# t = 9, avg_loss = 0.5214
# t = 10, avg_loss = 0.6375
# t = 11, avg_loss = 0.5972
# t = 12, avg_loss = 0.6450
# t = 13, avg_loss = 0.5373
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 27 / 80
# t = 1, avg_loss = 0.5759
# t = 2, avg_loss = 0.6586
# t = 3, avg_loss = 0.5646
# t = 4, avg_loss = 0.5972
# t = 5, avg_loss = 0.5963
# t = 6, avg_loss = 0.5256
# t = 7, avg_loss = 0.5505
# t = 8, avg_loss = 0.5526
# t = 9, avg_loss = 0.6969
# t = 10, avg_loss = 0.5156
# t = 11, avg_loss = 0.6783
# t = 12, avg_loss = 0.7648
# t = 13, avg_loss = 0.5803
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 28 / 80
# t = 1, avg_loss = 0.6335
# t = 2, avg_loss = 0.5411
# t = 3, avg_loss = 0.6253
# t = 4, avg_loss = 0.5781
# t = 5, avg_loss = 0.5791
# t = 6, avg_loss = 0.5797
# t = 7, avg_loss = 0.5674
# t = 8, avg_loss = 0.6701
# t = 9, avg_loss = 0.6248
# t = 10, avg_loss = 0.6904
# t = 11, avg_loss = 0.6800
# t = 12, avg_loss = 0.5788
# t = 13, avg_loss = 0.6656
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 29 / 80
# t = 1, avg_loss = 0.6371
# t = 2, avg_loss = 0.6776
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7b8c17403705> in <module>()
#      53 optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay)
#      54
# ---> 55 train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
#      56 check_accuracy(model_gpu, valid_loader)
#
# <ipython-input-9-7b7c48cb9b8f> in train(model, train_loader, loss_fn, optimizer, num_epochs, starting_from_epoch)
#       9         model.train()
#      10
# ---> 11         for t, (x, y) in enumerate(train_loader):
#      12             x_var = Variable(x.type(gpu_dtype))
#      13             y_var = Variable(y.type(gpu_dtype).long())
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-7-50a9cd504daf> in __getitem__(self, index)
#      16         else:
#      17           image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", index ))
# ---> 18         image = self.transform(image)
#      19         return image, label
#      20
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      68     def __call__(self, img):
#      69         for t in self.transforms:
# ---> 70             img = t(img)
#      71         return img
#      72
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#     205             PIL Image: Rescaled image.
#     206         """
# --> 207         return F.resize(img, self.size, self.interpolation)
#     208
#     209     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py in resize(img, size, interpolation)
#     254             return img.resize((ow, oh), interpolation)
#     255     else:
# --> 256         return img.resize(size[::-1], interpolation)
#     257
#     258
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1856             return im.convert(self.mode)
#    1857
# -> 1858         self.load()
#    1859
#    1860         if reducing_gap is not None and resample != NEAREST:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in load(self)
#     249
#     250                             b = b + s
# --> 251                             n, err_code = decoder.decode(b)
#     252                             if n < 0:
#     253                                 break
#
# KeyboardInterrupt:

# %%
def retry_from_backup()
  model_gpu = model_base.type(gpu_dtype)
  print(model_gpu)
  loss_fn = nn.modules.loss.CrossEntropyLoss()
  optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay) 



  checkpoint = torch.load(model_backup_path)
  model_gpu.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch = checkpoint['epoch']
  loss = checkpoint['loss']
  print("starting from epoch: " + str(epoch))
  print("starting from loss: " + str(loss))
  print(checkpoint['model_state_dict'])
  print(checkpoint['optimizer_state_dict'])

  train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs, starting_from_epoch=epoch)
  check_accuracy(model_gpu, valid_loader)
#retry_from_backup()

# %%
import matplotlib.pyplot as plt

plt.plot([print_every*batch_size*(i+1) for i in range((len(avg_loss_list)))],avg_loss_list)
print("Loss:")
plt.show()
# Out:
# Loss:

# %%
plt.plot([i+1 for i in range((len(acc_list)))],acc_list)
print("Accurancy:")
plt.show()
# Out:
# Accurancy:

# %%
#%tensorboard --logdir {logs_base_dir}
