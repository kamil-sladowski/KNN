# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilo116/KNN/blob/master/KNN_Avg_No_Relu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import os
import csv
import sys
from random import shuffle
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
# %matplotlib inline
from sklearn.model_selection import train_test_split

import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
from torch.utils.data.sampler import SubsetRandomSampler

import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T
import torchvision.transforms as transforms
import timeit

np.random.seed(4) 
torch.manual_seed(4) 
torch.cuda.manual_seed(4)

# %%
! git clone https://github.com/wang-chen/kervolution.git 

sys.path.append("kervolution/")
from kervolution import Kerv2d
# Out:
# fatal: destination path 'kervolution' already exists and is not an empty directory.

# %%
LIMIT_IMAGES_NUM = 500
train_test_split_size = 0.2
image_resize = (100, 100)
batch_size = 64
num_workers = 0

in_channels = 3
out_channels_1 = 100
out_channels_2 = 64
out_channels_3 = 32
out_channels_4 = 16
out_channels_5 = 8

kernel_size = 3
padding_1 = 1
num_epochs = 80

learning_rate = 0.0007
weight_decay = 0

MALIGNANT_DATASET = '/content/drive/My Drive/Colab_data/malignant/malignant/'
BENIGN_DATASET = '/content/drive/My Drive/Colab_data/benign/benign/'
DATA_FOLDER = '/content/drive/My Drive/Colab_data/'
MODEL_BACKUP_PATH = os.path.join(DATA_FOLDER, 'backup_model')

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
benign_file_list = sorted(os.listdir(BENIGN_DATASET))
malignant_file_list = sorted(os.listdir(MALIGNANT_DATASET))
shuffle(benign_file_list)
shuffle(malignant_file_list)
benign_file_list = benign_file_list[:LIMIT_IMAGES_NUM]
malignant_file_list = malignant_file_list[:LIMIT_IMAGES_NUM]

print(f"Number of benign {len(benign_file_list)} images")
print(f"Number of malignant {len(malignant_file_list)} images")

data_transforms = transforms.Compose([
    transforms.Resize(image_resize),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Out:
# Number of benign 500 images
# Number of malignant 500 images

# %%
benign_dict = {filename: 0 for filename in benign_file_list}
malignant_dict = {filename: 1 for filename in malignant_file_list}
img_class_dict = {**benign_dict , **malignant_dict}
labeled_data = pd.Series(img_class_dict)

# %%
class IsicDataset(Dataset):
    def __init__(self, data_folder, labeled_data, 
                 transform=transforms.Compose([transforms.ToTensor()])):
        self.labeled_data = labeled_data
        self.transform = transform
        self.data_folder = data_folder
        
        
    def __len__(self):
        return len(self.labeled_data)

    def __getitem__(self, index):
        label = self.labeled_data[index]
        if label == 0:
          image = Image.open(os.path.join(self.data_folder, "benign", "benign", index ))
        else:
          image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", index ))
        image = self.transform(image)
        return image, label

    @property
    def labels(self):
      return self.labeled_data

# %%
 
dataset = IsicDataset(DATA_FOLDER, labeled_data, transform=data_transforms)
print(dataset.labels)

X_train, X_test = train_test_split(dataset.labels, test_size=train_test_split_size)
print("number of training data: ",len(X_train))
print("number of testing  data: ",len(X_test))

train_sampler = SubsetRandomSampler(list(X_train.index))
valid_sampler = SubsetRandomSampler(list(X_test.index))


train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
# Out:
# ISIC_0000966.jpeg    0
# ISIC_0001063.jpeg    0
# ISIC_0000746.jpeg    0
# ISIC_0000082.jpeg    0
# ISIC_0000938.jpeg    0
#                     ..
# ISIC_0025891.jpg     1
# ISIC_0013615.jpeg    1
# ISIC_0000429.jpeg    1
# ISIC_0015046.jpeg    1
# ISIC_0011125.jpeg    1
# Length: 1000, dtype: int64
# number of training data:  800
# number of testing  data:  200

# %%
avg_loss_list = []
acc_list = []

def train(model, train_loader ,loss_fn, optimizer, num_epochs=1, starting_from_epoch=1):
    total_loss =0

    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()

        for t, (x, y) in enumerate(train_loader):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())
            scores = model(x_var)
            loss = loss_fn(scores, y_var)
            total_loss += loss.data
            
            if (t + 1) % print_every == 0:
                avg_loss = total_loss/print_every
                print('t = %d, avg_loss = %.4f' % (t + 1, avg_loss) )
                avg_loss_list.append(avg_loss)
                total_loss = 0
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        acc = check_accuracy(model_gpu, valid_loader)
        print('acc = %f' %(acc))
        torch.save({
            'epoch': epoch,
            'model_state_dict': model_gpu.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
            }, MODEL_BACKUP_PATH)
            
def check_accuracy(model, loader):
    print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() 
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype))

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    acc_list.append(acc)
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size()
        return x.view(N, -1)

# %%
gpu_dtype = torch.cuda.FloatTensor

print_every = 1


'''
Kerv2d
kervolution with following options:
kernel_type: [linear, polynomial, gaussian, etc.]
default is convolution:
          kernel_type --> linear,
balance, power, gamma is valid only when the kernel_type is specified
if learnable_kernel = True,  they just be the initial value of learable parameters
if learnable_kernel = False, they are the value of kernel_type's parameter
the parameter [power] cannot be learned due to integer limitation
dilation (int or tuple, optional): Spacing between kernel
elements. Default: 1
groups (int, optional): Number of blocked connections from input
channels to output channels. Default: 1
bias (bool, optional): If ``True``, adds a learnable bias to the output. Default: ``True``
kernel_type (str), Default: 'linear'
learnable_kernel (bool): Learnable kernel parameters.  Default: False 
balance: 0, 1
power: 3, 4, 5
gamma:
'''


model_base = nn.Sequential( 
                nn.Kerv2d(in_channels , out_channels_1, padding=padding_1, dilation=1, groups=1, bias=True, 
                          kernel_type='polynomial', kernel_size=kernel_size, learnable_kernel=True,
                          kernel_regularizer=True, stride=1, balance=1, power=3, gamma=1
                          ), 
                nn.BatchNorm2d(out_channels_1),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_1 , out_channels_2, padding= padding_1, kernel_size=kernel_size, stride=1), 
                nn.BatchNorm2d(out_channels_2),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_2 , out_channels_3, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_3),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_3 , out_channels_4, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_4),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_channels_4 , out_channels_5, padding= padding_1, kernel_size=kernel_size, stride=1),  
                nn.BatchNorm2d(out_channels_5),
                nn.AvgPool2d(2, stride=2),
                nn.Dropout(0.5),
                Flatten(),
                nn.Linear(72,2)
            )
model_gpu = model_base.type(gpu_dtype)
print(model_gpu)
loss_fn = nn.modules.loss.CrossEntropyLoss()
optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay) 

train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
check_accuracy(model_gpu, valid_loader)
# Out:
# Sequential(
#   (0): Kerv2d(3, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (3): Conv2d(100, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (6): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (9): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (10): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (12): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (15): Dropout(p=0.5, inplace=False)
#   (16): Flatten()
#   (17): Linear(in_features=72, out_features=2, bias=True)
# )
# Starting epoch 1 / 80
# t = 1, avg_loss = 0.9160
# t = 2, avg_loss = 0.6634
# t = 3, avg_loss = 0.7652
# t = 4, avg_loss = 0.7215
# t = 5, avg_loss = 0.7630
# t = 6, avg_loss = 0.6726
# t = 7, avg_loss = 0.8843
# t = 8, avg_loss = 0.6570
# t = 9, avg_loss = 0.5889
# t = 10, avg_loss = 0.7080
# t = 11, avg_loss = 0.6449
# t = 12, avg_loss = 0.7119
# t = 13, avg_loss = 0.6172
# Checking accuracy on test set
# Got 92 / 200 correct (46.00)
# acc = 0.460000
# Starting epoch 2 / 80
# t = 1, avg_loss = 0.8162
# t = 2, avg_loss = 0.6585
# t = 3, avg_loss = 0.7219
# t = 4, avg_loss = 0.7199
# t = 5, avg_loss = 0.6903
# t = 6, avg_loss = 0.6992
# t = 7, avg_loss = 0.6478
# t = 8, avg_loss = 0.7095
# t = 9, avg_loss = 0.5990
# t = 10, avg_loss = 0.6548
# t = 11, avg_loss = 0.7539
# t = 12, avg_loss = 0.6668
# t = 13, avg_loss = 0.7647
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 3 / 80
# t = 1, avg_loss = 0.6846
# t = 2, avg_loss = 0.6112
# t = 3, avg_loss = 0.6150
# t = 4, avg_loss = 0.7121
# t = 5, avg_loss = 0.5774
# t = 6, avg_loss = 0.6679
# t = 7, avg_loss = 0.6579
# t = 8, avg_loss = 0.6317
# t = 9, avg_loss = 0.7178
# t = 10, avg_loss = 0.7587
# t = 11, avg_loss = 0.5428
# t = 12, avg_loss = 0.7351
# t = 13, avg_loss = 0.6280
# Checking accuracy on test set
# Got 140 / 200 correct (70.00)
# acc = 0.700000
# Starting epoch 4 / 80
# t = 1, avg_loss = 0.6563
# t = 2, avg_loss = 0.6802
# t = 3, avg_loss = 0.7077
# t = 4, avg_loss = 0.6875
# t = 5, avg_loss = 0.5504
# t = 6, avg_loss = 0.6712
# t = 7, avg_loss = 0.5994
# t = 8, avg_loss = 0.6830
# t = 9, avg_loss = 0.6236
# t = 10, avg_loss = 0.6290
# t = 11, avg_loss = 0.6026
# t = 12, avg_loss = 0.6910
# t = 13, avg_loss = 0.6985
# Checking accuracy on test set
# Got 123 / 200 correct (61.50)
# acc = 0.615000
# Starting epoch 5 / 80
# t = 1, avg_loss = 0.6577
# t = 2, avg_loss = 0.6814
# t = 3, avg_loss = 0.6976
# t = 4, avg_loss = 0.5896
# t = 5, avg_loss = 0.6128
# t = 6, avg_loss = 0.6916
# t = 7, avg_loss = 0.7004
# t = 8, avg_loss = 0.5832
# t = 9, avg_loss = 0.7795
# t = 10, avg_loss = 0.7715
# t = 11, avg_loss = 0.6818
# t = 12, avg_loss = 0.6515
# t = 13, avg_loss = 0.5566
# Checking accuracy on test set
# Got 129 / 200 correct (64.50)
# acc = 0.645000
# Starting epoch 6 / 80
# t = 1, avg_loss = 0.7041
# t = 2, avg_loss = 0.5931
# t = 3, avg_loss = 0.6395
# t = 4, avg_loss = 0.6130
# t = 5, avg_loss = 0.7282
# t = 6, avg_loss = 0.6140
# t = 7, avg_loss = 0.6131
# t = 8, avg_loss = 0.5942
# t = 9, avg_loss = 0.6180
# t = 10, avg_loss = 0.7045
# t = 11, avg_loss = 0.5459
# t = 12, avg_loss = 0.7009
# t = 13, avg_loss = 0.5781
# Checking accuracy on test set
# Got 135 / 200 correct (67.50)
# acc = 0.675000
# Starting epoch 7 / 80
# t = 1, avg_loss = 0.6962
# t = 2, avg_loss = 0.6421
# t = 3, avg_loss = 0.5899
# t = 4, avg_loss = 0.7616
# t = 5, avg_loss = 0.6149
# t = 6, avg_loss = 0.6303
# t = 7, avg_loss = 0.6482
# t = 8, avg_loss = 0.6774
# t = 9, avg_loss = 0.5978
# t = 10, avg_loss = 0.6584
# t = 11, avg_loss = 0.5583
# t = 12, avg_loss = 0.8073
# t = 13, avg_loss = 0.5608
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 8 / 80
# t = 1, avg_loss = 0.5752
# t = 2, avg_loss = 0.7108
# t = 3, avg_loss = 0.6100
# t = 4, avg_loss = 0.6659
# t = 5, avg_loss = 0.7341
# t = 6, avg_loss = 0.6669
# t = 7, avg_loss = 0.6503
# t = 8, avg_loss = 0.6476
# t = 9, avg_loss = 0.6532
# t = 10, avg_loss = 0.5986
# t = 11, avg_loss = 0.6560
# t = 12, avg_loss = 0.5789
# t = 13, avg_loss = 0.7032
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 9 / 80
# t = 1, avg_loss = 0.6370
# t = 2, avg_loss = 0.6344
# t = 3, avg_loss = 0.5896
# t = 4, avg_loss = 0.5861
# t = 5, avg_loss = 0.6161
# t = 6, avg_loss = 0.6534
# t = 7, avg_loss = 0.7365
# t = 8, avg_loss = 0.6324
# t = 9, avg_loss = 0.7235
# t = 10, avg_loss = 0.6438
# t = 11, avg_loss = 0.6378
# t = 12, avg_loss = 0.6257
# t = 13, avg_loss = 0.6283
# Checking accuracy on test set
# Got 134 / 200 correct (67.00)
# acc = 0.670000
# Starting epoch 10 / 80
# t = 1, avg_loss = 0.6217
# t = 2, avg_loss = 0.5833
# t = 3, avg_loss = 0.6081
# t = 4, avg_loss = 0.5816
# t = 5, avg_loss = 0.5476
# t = 6, avg_loss = 0.6190
# t = 7, avg_loss = 0.7503
# t = 8, avg_loss = 0.6618
# t = 9, avg_loss = 0.5602
# t = 10, avg_loss = 0.7244
# t = 11, avg_loss = 0.5956
# t = 12, avg_loss = 0.6320
# t = 13, avg_loss = 0.6081
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 11 / 80
# t = 1, avg_loss = 0.6217
# t = 2, avg_loss = 0.6609
# t = 3, avg_loss = 0.5443
# t = 4, avg_loss = 0.5673
# t = 5, avg_loss = 0.6156
# t = 6, avg_loss = 0.7141
# t = 7, avg_loss = 0.5372
# t = 8, avg_loss = 0.5670
# t = 9, avg_loss = 0.6367
# t = 10, avg_loss = 0.7430
# t = 11, avg_loss = 0.6307
# t = 12, avg_loss = 0.6191
# t = 13, avg_loss = 0.7173
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 12 / 80
# t = 1, avg_loss = 0.6125
# t = 2, avg_loss = 0.5327
# t = 3, avg_loss = 0.5551
# t = 4, avg_loss = 0.8156
# t = 5, avg_loss = 0.7158
# t = 6, avg_loss = 0.6329
# t = 7, avg_loss = 0.5923
# t = 8, avg_loss = 0.6453
# t = 9, avg_loss = 0.7020
# t = 10, avg_loss = 0.6262
# t = 11, avg_loss = 0.6670
# t = 12, avg_loss = 0.5923
# t = 13, avg_loss = 0.5270
# Checking accuracy on test set
# Got 134 / 200 correct (67.00)
# acc = 0.670000
# Starting epoch 13 / 80
# t = 1, avg_loss = 0.6592
# t = 2, avg_loss = 0.5445
# t = 3, avg_loss = 0.6638
# t = 4, avg_loss = 0.6367
# t = 5, avg_loss = 0.6621
# t = 6, avg_loss = 0.7021
# t = 7, avg_loss = 0.7218
# t = 8, avg_loss = 0.6333
# t = 9, avg_loss = 0.6170
# t = 10, avg_loss = 0.5744
# t = 11, avg_loss = 0.6201
# t = 12, avg_loss = 0.5934
# t = 13, avg_loss = 0.5628
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 14 / 80
# t = 1, avg_loss = 0.6249
# t = 2, avg_loss = 0.5708
# t = 3, avg_loss = 0.6202
# t = 4, avg_loss = 0.5989
# t = 5, avg_loss = 0.6070
# t = 6, avg_loss = 0.5964
# t = 7, avg_loss = 0.6050
# t = 8, avg_loss = 0.6288
# t = 9, avg_loss = 0.5998
# t = 10, avg_loss = 0.6355
# t = 11, avg_loss = 0.6545
# t = 12, avg_loss = 0.6802
# t = 13, avg_loss = 0.7224
# Checking accuracy on test set
# Got 131 / 200 correct (65.50)
# acc = 0.655000
# Starting epoch 15 / 80
# t = 1, avg_loss = 0.5882
# t = 2, avg_loss = 0.5164
# t = 3, avg_loss = 0.6304
# t = 4, avg_loss = 0.6445
# t = 5, avg_loss = 0.7221
# t = 6, avg_loss = 0.5480
# t = 7, avg_loss = 0.5434
# t = 8, avg_loss = 0.6274
# t = 9, avg_loss = 0.6341
# t = 10, avg_loss = 0.6036
# t = 11, avg_loss = 0.5550
# t = 12, avg_loss = 0.6162
# t = 13, avg_loss = 0.6118
# Checking accuracy on test set
# Got 142 / 200 correct (71.00)
# acc = 0.710000
# Starting epoch 16 / 80
# t = 1, avg_loss = 0.6418
# t = 2, avg_loss = 0.5652
# t = 3, avg_loss = 0.6032
# t = 4, avg_loss = 0.5908
# t = 5, avg_loss = 0.5901
# t = 6, avg_loss = 0.5341
# t = 7, avg_loss = 0.6080
# t = 8, avg_loss = 0.5807
# t = 9, avg_loss = 0.6837
# t = 10, avg_loss = 0.5840
# t = 11, avg_loss = 0.5742
# t = 12, avg_loss = 0.7145
# t = 13, avg_loss = 0.5675
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 17 / 80
# t = 1, avg_loss = 0.6354
# t = 2, avg_loss = 0.5799
# t = 3, avg_loss = 0.7996
# t = 4, avg_loss = 0.5567
# t = 5, avg_loss = 0.5526
# t = 6, avg_loss = 0.6370
# t = 7, avg_loss = 0.6970
# t = 8, avg_loss = 0.5592
# t = 9, avg_loss = 0.5482
# t = 10, avg_loss = 0.7717
# t = 11, avg_loss = 0.6779
# t = 12, avg_loss = 0.5263
# t = 13, avg_loss = 0.7088
# Checking accuracy on test set
# Got 131 / 200 correct (65.50)
# acc = 0.655000
# Starting epoch 18 / 80
# t = 1, avg_loss = 0.6477
# t = 2, avg_loss = 0.5673
# t = 3, avg_loss = 0.6189
# t = 4, avg_loss = 0.5204
# t = 5, avg_loss = 0.6417
# t = 6, avg_loss = 0.5728
# t = 7, avg_loss = 0.6139
# t = 8, avg_loss = 0.6134
# t = 9, avg_loss = 0.5593
# t = 10, avg_loss = 0.7156
# t = 11, avg_loss = 0.5939
# t = 12, avg_loss = 0.6060
# t = 13, avg_loss = 0.5901
# Checking accuracy on test set
# Got 131 / 200 correct (65.50)
# acc = 0.655000
# Starting epoch 19 / 80
# t = 1, avg_loss = 0.5766
# t = 2, avg_loss = 0.5769
# t = 3, avg_loss = 0.5477
# t = 4, avg_loss = 0.6244
# t = 5, avg_loss = 0.6720
# t = 6, avg_loss = 0.6268
# t = 7, avg_loss = 0.6760
# t = 8, avg_loss = 0.6438
# t = 9, avg_loss = 0.6057
# t = 10, avg_loss = 0.6956
# t = 11, avg_loss = 0.6300
# t = 12, avg_loss = 0.5962
# t = 13, avg_loss = 0.4840
# Checking accuracy on test set
# Got 136 / 200 correct (68.00)
# acc = 0.680000
# Starting epoch 20 / 80
# t = 1, avg_loss = 0.6223
# t = 2, avg_loss = 0.5895
# t = 3, avg_loss = 0.6241
# t = 4, avg_loss = 0.5570
# t = 5, avg_loss = 0.6257
# t = 6, avg_loss = 0.5310
# t = 7, avg_loss = 0.6516
# t = 8, avg_loss = 0.6371
# t = 9, avg_loss = 0.6485
# t = 10, avg_loss = 0.6063
# t = 11, avg_loss = 0.5884
# t = 12, avg_loss = 0.5736
# t = 13, avg_loss = 0.5854
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 21 / 80
# t = 1, avg_loss = 0.5405
# t = 2, avg_loss = 0.7020
# t = 3, avg_loss = 0.5904
# t = 4, avg_loss = 0.5235
# t = 5, avg_loss = 0.6455
# t = 6, avg_loss = 0.5733
# t = 7, avg_loss = 0.5989
# t = 8, avg_loss = 0.5432
# t = 9, avg_loss = 0.6077
# t = 10, avg_loss = 0.5822
# t = 11, avg_loss = 0.5438
# t = 12, avg_loss = 0.6727
# t = 13, avg_loss = 0.7968
# Checking accuracy on test set
# Got 128 / 200 correct (64.00)
# acc = 0.640000
# Starting epoch 22 / 80
# t = 1, avg_loss = 0.5846
# t = 2, avg_loss = 0.7265
# t = 3, avg_loss = 0.5874
# t = 4, avg_loss = 0.5701
# t = 5, avg_loss = 0.5967
# t = 6, avg_loss = 0.6745
# t = 7, avg_loss = 0.5384
# t = 8, avg_loss = 0.5321
# t = 9, avg_loss = 0.6165
# t = 10, avg_loss = 0.6379
# t = 11, avg_loss = 0.5477
# t = 12, avg_loss = 0.5432
# t = 13, avg_loss = 0.5370
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 23 / 80
# t = 1, avg_loss = 0.5371
# t = 2, avg_loss = 0.6362
# t = 3, avg_loss = 0.6087
# t = 4, avg_loss = 0.6205
# t = 5, avg_loss = 0.5743
# t = 6, avg_loss = 0.6226
# t = 7, avg_loss = 0.5937
# t = 8, avg_loss = 0.6240
# t = 9, avg_loss = 0.6097
# t = 10, avg_loss = 0.5436
# t = 11, avg_loss = 0.5959
# t = 12, avg_loss = 0.6156
# t = 13, avg_loss = 0.6452
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 24 / 80
# t = 1, avg_loss = 0.6698
# t = 2, avg_loss = 0.5230
# t = 3, avg_loss = 0.6660
# t = 4, avg_loss = 0.5925
# t = 5, avg_loss = 0.5843
# t = 6, avg_loss = 0.6377
# t = 7, avg_loss = 0.6423
# t = 8, avg_loss = 0.5935
# t = 9, avg_loss = 0.5876
# t = 10, avg_loss = 0.6985
# t = 11, avg_loss = 0.6120
# t = 12, avg_loss = 0.5911
# t = 13, avg_loss = 0.5787
# Checking accuracy on test set
# Got 139 / 200 correct (69.50)
# acc = 0.695000
# Starting epoch 25 / 80
# t = 1, avg_loss = 0.5423
# t = 2, avg_loss = 0.6208
# t = 3, avg_loss = 0.6118
# t = 4, avg_loss = 0.5292
# t = 5, avg_loss = 0.5536
# t = 6, avg_loss = 0.6000
# t = 7, avg_loss = 0.7510
# t = 8, avg_loss = 0.6212
# t = 9, avg_loss = 0.5661
# t = 10, avg_loss = 0.5996
# t = 11, avg_loss = 0.6076
# t = 12, avg_loss = 0.5065
# t = 13, avg_loss = 0.5777
# Checking accuracy on test set
# Got 135 / 200 correct (67.50)
# acc = 0.675000
# Starting epoch 26 / 80
# t = 1, avg_loss = 0.4897
# t = 2, avg_loss = 0.6036
# t = 3, avg_loss = 0.6300
# t = 4, avg_loss = 0.5598
# t = 5, avg_loss = 0.5134
# t = 6, avg_loss = 0.6637
# t = 7, avg_loss = 0.6115
# t = 8, avg_loss = 0.4667
# t = 9, avg_loss = 0.6258
# t = 10, avg_loss = 0.5996
# t = 11, avg_loss = 0.5626
# t = 12, avg_loss = 0.6984
# t = 13, avg_loss = 0.5003
# Checking accuracy on test set
# Got 133 / 200 correct (66.50)
# acc = 0.665000
# Starting epoch 27 / 80
# t = 1, avg_loss = 0.5022
# t = 2, avg_loss = 0.5791
# t = 3, avg_loss = 0.6291
# t = 4, avg_loss = 0.6135
# t = 5, avg_loss = 0.6366
# t = 6, avg_loss = 0.5737
# t = 7, avg_loss = 0.6706
# t = 8, avg_loss = 0.5363
# t = 9, avg_loss = 0.5580
# t = 10, avg_loss = 0.6699
# t = 11, avg_loss = 0.5825
# t = 12, avg_loss = 0.5689
# t = 13, avg_loss = 0.7398
# Checking accuracy on test set
# Got 136 / 200 correct (68.00)
# acc = 0.680000
# Starting epoch 28 / 80
# t = 1, avg_loss = 0.5336
# t = 2, avg_loss = 0.6164
# t = 3, avg_loss = 0.5975
# t = 4, avg_loss = 0.6090
# t = 5, avg_loss = 0.5469
# t = 6, avg_loss = 0.6360
# t = 7, avg_loss = 0.6036
# t = 8, avg_loss = 0.4670
# t = 9, avg_loss = 0.8042
# t = 10, avg_loss = 0.5765
# t = 11, avg_loss = 0.5979
# t = 12, avg_loss = 0.5234
# t = 13, avg_loss = 0.5126
# Checking accuracy on test set
# Got 138 / 200 correct (69.00)
# acc = 0.690000
# Starting epoch 29 / 80
# t = 1, avg_loss = 0.5894
# t = 2, avg_loss = 0.6446
# t = 3, avg_loss = 0.5892
# t = 4, avg_loss = 0.5398
# t = 5, avg_loss = 0.6070
# t = 6, avg_loss = 0.5218
# t = 7, avg_loss = 0.6482
# t = 8, avg_loss = 0.5932
# t = 9, avg_loss = 0.7044
# t = 10, avg_loss = 0.5069
# t = 11, avg_loss = 0.7437
# t = 12, avg_loss = 0.7190
# t = 13, avg_loss = 0.5370
# Checking accuracy on test set
# Got 132 / 200 correct (66.00)
# acc = 0.660000
# Starting epoch 30 / 80
# t = 1, avg_loss = 0.5680
# t = 2, avg_loss = 0.5569
# t = 3, avg_loss = 0.6088
# t = 4, avg_loss = 0.6275
# t = 5, avg_loss = 0.6053
# t = 6, avg_loss = 0.5379
# t = 7, avg_loss = 0.6284
# t = 8, avg_loss = 0.5506
# t = 9, avg_loss = 0.6203
# t = 10, avg_loss = 0.5795
# t = 11, avg_loss = 0.6276
# t = 12, avg_loss = 0.5890
# t = 13, avg_loss = 0.5631
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 31 / 80
# t = 1, avg_loss = 0.6376
# t = 2, avg_loss = 0.5581
# t = 3, avg_loss = 0.6469
# t = 4, avg_loss = 0.5702
# t = 5, avg_loss = 0.5950
# t = 6, avg_loss = 0.5221
# t = 7, avg_loss = 0.6229
# t = 8, avg_loss = 0.6294
# t = 9, avg_loss = 0.5404
# t = 10, avg_loss = 0.5432
# t = 11, avg_loss = 0.5368
# t = 12, avg_loss = 0.4638
# t = 13, avg_loss = 0.7170
# Checking accuracy on test set
# Got 134 / 200 correct (67.00)
# acc = 0.670000
# Starting epoch 32 / 80
# t = 1, avg_loss = 0.5801
# t = 2, avg_loss = 0.5642
# t = 3, avg_loss = 0.4726
# t = 4, avg_loss = 0.6122
# t = 5, avg_loss = 0.5294
# t = 6, avg_loss = 0.6751
# t = 7, avg_loss = 0.6235
# t = 8, avg_loss = 0.5755
# t = 9, avg_loss = 0.5546
# t = 10, avg_loss = 0.5968
# t = 11, avg_loss = 0.5932
# t = 12, avg_loss = 0.6112
# t = 13, avg_loss = 0.5614
# Checking accuracy on test set
# Got 143 / 200 correct (71.50)
# acc = 0.715000
# Starting epoch 33 / 80
# t = 1, avg_loss = 0.5427
# t = 2, avg_loss = 0.4388
# t = 3, avg_loss = 0.6348
# t = 4, avg_loss = 0.5326
# t = 5, avg_loss = 0.5844
# t = 6, avg_loss = 0.6211
# t = 7, avg_loss = 0.5082
# t = 8, avg_loss = 0.4719
# t = 9, avg_loss = 0.5772
# t = 10, avg_loss = 0.5535
# t = 11, avg_loss = 0.5606
# t = 12, avg_loss = 0.6905
# t = 13, avg_loss = 0.6547
# Checking accuracy on test set
# Got 134 / 200 correct (67.00)
# acc = 0.670000
# Starting epoch 34 / 80
# t = 1, avg_loss = 0.5494
# t = 2, avg_loss = 0.5675
# t = 3, avg_loss = 0.5382
# t = 4, avg_loss = 0.5747
# t = 5, avg_loss = 0.5909
# t = 6, avg_loss = 0.6114
# t = 7, avg_loss = 0.4898
# t = 8, avg_loss = 0.6449
# t = 9, avg_loss = 0.5111
# t = 10, avg_loss = 0.6360
# t = 11, avg_loss = 0.5123
# t = 12, avg_loss = 0.6712
# t = 13, avg_loss = 0.4898
# Checking accuracy on test set
# Got 131 / 200 correct (65.50)
# acc = 0.655000
# Starting epoch 35 / 80
# t = 1, avg_loss = 0.5332
# t = 2, avg_loss = 0.5513
# t = 3, avg_loss = 0.6047
# t = 4, avg_loss = 0.5547
# t = 5, avg_loss = 0.5029
# t = 6, avg_loss = 0.5955
# t = 7, avg_loss = 0.5432
# t = 8, avg_loss = 0.5428
# t = 9, avg_loss = 0.4998
# t = 10, avg_loss = 0.5409
# t = 11, avg_loss = 0.5118
# t = 12, avg_loss = 0.6487
# t = 13, avg_loss = 0.5234
# Checking accuracy on test set
# Got 129 / 200 correct (64.50)
# acc = 0.645000
# Starting epoch 36 / 80
# t = 1, avg_loss = 0.5559
# t = 2, avg_loss = 0.4917
# t = 3, avg_loss = 0.5533
# t = 4, avg_loss = 0.5074
# t = 5, avg_loss = 0.6847
# t = 6, avg_loss = 0.6347
# t = 7, avg_loss = 0.6208
# t = 8, avg_loss = 0.6144
# t = 9, avg_loss = 0.5560
# t = 10, avg_loss = 0.5759
# t = 11, avg_loss = 0.4860
# t = 12, avg_loss = 0.5299
# t = 13, avg_loss = 0.5769
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 37 / 80
# t = 1, avg_loss = 0.6288
# t = 2, avg_loss = 0.5743
# t = 3, avg_loss = 0.4642
# t = 4, avg_loss = 0.6318
# t = 5, avg_loss = 0.4934
# t = 6, avg_loss = 0.7133
# t = 7, avg_loss = 0.6066
# t = 8, avg_loss = 0.4769
# t = 9, avg_loss = 0.4897
# t = 10, avg_loss = 0.5356
# t = 11, avg_loss = 0.4867
# t = 12, avg_loss = 0.6411
# t = 13, avg_loss = 0.5193
# Checking accuracy on test set
# Got 140 / 200 correct (70.00)
# acc = 0.700000
# Starting epoch 38 / 80
# t = 1, avg_loss = 0.5046
# t = 2, avg_loss = 0.5018
# t = 3, avg_loss = 0.6207
# t = 4, avg_loss = 0.5776
# t = 5, avg_loss = 0.5806
# t = 6, avg_loss = 0.4452
# t = 7, avg_loss = 0.5263
# t = 8, avg_loss = 0.5682
# t = 9, avg_loss = 0.6960
# t = 10, avg_loss = 0.6369
# t = 11, avg_loss = 0.5079
# t = 12, avg_loss = 0.4956
# t = 13, avg_loss = 0.6257
# Checking accuracy on test set
# Got 135 / 200 correct (67.50)
# acc = 0.675000
# Starting epoch 39 / 80
# t = 1, avg_loss = 0.5745
# t = 2, avg_loss = 0.5896
# t = 3, avg_loss = 0.4678
# t = 4, avg_loss = 0.7328
# t = 5, avg_loss = 0.7091
# t = 6, avg_loss = 0.5505
# t = 7, avg_loss = 0.5516
# t = 8, avg_loss = 0.5249
# t = 9, avg_loss = 0.4846
# t = 10, avg_loss = 0.4995
# t = 11, avg_loss = 0.4956
# t = 12, avg_loss = 0.4654
# t = 13, avg_loss = 0.7471
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 40 / 80
# t = 1, avg_loss = 0.5766
# t = 2, avg_loss = 0.5255
# t = 3, avg_loss = 0.5691
# t = 4, avg_loss = 0.4950
# t = 5, avg_loss = 0.5551
# t = 6, avg_loss = 0.5491
# t = 7, avg_loss = 0.4486
# t = 8, avg_loss = 0.5708
# t = 9, avg_loss = 0.6785
# t = 10, avg_loss = 0.5091
# t = 11, avg_loss = 0.6248
# t = 12, avg_loss = 0.4736
# t = 13, avg_loss = 0.6202
# Checking accuracy on test set
# Got 135 / 200 correct (67.50)
# acc = 0.675000
# Starting epoch 41 / 80
# t = 1, avg_loss = 0.6217
# t = 2, avg_loss = 0.5726
# t = 3, avg_loss = 0.5634
# t = 4, avg_loss = 0.5165
# t = 5, avg_loss = 0.5812
# t = 6, avg_loss = 0.5474
# t = 7, avg_loss = 0.5029
# t = 8, avg_loss = 0.4903
# t = 9, avg_loss = 0.6491
# t = 10, avg_loss = 0.6810
# t = 11, avg_loss = 0.6094
# t = 12, avg_loss = 0.4711
# t = 13, avg_loss = 0.5123
# Checking accuracy on test set
# Got 147 / 200 correct (73.50)
# acc = 0.735000
# Starting epoch 42 / 80
# t = 1, avg_loss = 0.5628
# t = 2, avg_loss = 0.5720
# t = 3, avg_loss = 0.4703
# t = 4, avg_loss = 0.5660
# t = 5, avg_loss = 0.5265
# t = 6, avg_loss = 0.4291
# t = 7, avg_loss = 0.6278
# t = 8, avg_loss = 0.5895
# t = 9, avg_loss = 0.5680
# t = 10, avg_loss = 0.4984
# t = 11, avg_loss = 0.5700
# t = 12, avg_loss = 0.5836
# t = 13, avg_loss = 0.6638
# Checking accuracy on test set
# Got 135 / 200 correct (67.50)
# acc = 0.675000
# Starting epoch 43 / 80
# t = 1, avg_loss = 0.6353
# t = 2, avg_loss = 0.4961
# t = 3, avg_loss = 0.6313
# t = 4, avg_loss = 0.5644
# t = 5, avg_loss = 0.5765
# t = 6, avg_loss = 0.5493
# t = 7, avg_loss = 0.5802
# t = 8, avg_loss = 0.4857
# t = 9, avg_loss = 0.5289
# t = 10, avg_loss = 0.4997
# t = 11, avg_loss = 0.5972
# t = 12, avg_loss = 0.5839
# t = 13, avg_loss = 0.4654
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 44 / 80
# t = 1, avg_loss = 0.4936
# t = 2, avg_loss = 0.5894
# t = 3, avg_loss = 0.4884
# t = 4, avg_loss = 0.5348
# t = 5, avg_loss = 0.5404
# t = 6, avg_loss = 0.4926
# t = 7, avg_loss = 0.6000
# t = 8, avg_loss = 0.5609
# t = 9, avg_loss = 0.6046
# t = 10, avg_loss = 0.5893
# t = 11, avg_loss = 0.5743
# t = 12, avg_loss = 0.4658
# t = 13, avg_loss = 0.5577
# Checking accuracy on test set
# Got 112 / 200 correct (56.00)
# acc = 0.560000
# Starting epoch 45 / 80
# t = 1, avg_loss = 0.5738
# t = 2, avg_loss = 0.6085
# t = 3, avg_loss = 0.5235
# t = 4, avg_loss = 0.6672
# t = 5, avg_loss = 0.7199
# t = 6, avg_loss = 0.6259
# t = 7, avg_loss = 0.6023
# t = 8, avg_loss = 0.6478
# t = 9, avg_loss = 0.6795
# t = 10, avg_loss = 0.4755
# t = 11, avg_loss = 0.5563
# t = 12, avg_loss = 0.5358
# t = 13, avg_loss = 0.6107
# Checking accuracy on test set
# Got 134 / 200 correct (67.00)
# acc = 0.670000
# Starting epoch 46 / 80
# t = 1, avg_loss = 0.6515
# t = 2, avg_loss = 0.5038
# t = 3, avg_loss = 0.6120
# t = 4, avg_loss = 0.5147
# t = 5, avg_loss = 0.6378
# t = 6, avg_loss = 0.5655
# t = 7, avg_loss = 0.5726
# t = 8, avg_loss = 0.6109
# t = 9, avg_loss = 0.5684
# t = 10, avg_loss = 0.5725
# t = 11, avg_loss = 0.5362
# t = 12, avg_loss = 0.5623
# t = 13, avg_loss = 0.6068
# Checking accuracy on test set
# Got 146 / 200 correct (73.00)
# acc = 0.730000
# Starting epoch 47 / 80
# t = 1, avg_loss = 0.5468
# t = 2, avg_loss = 0.5705
# t = 3, avg_loss = 0.5684
# t = 4, avg_loss = 0.5277
# t = 5, avg_loss = 0.5426
# t = 6, avg_loss = 0.5629
# t = 7, avg_loss = 0.6076
# t = 8, avg_loss = 0.5273
# t = 9, avg_loss = 0.6834
# t = 10, avg_loss = 0.5619
# t = 11, avg_loss = 0.5786
# t = 12, avg_loss = 0.5283
# t = 13, avg_loss = 0.5519
# Checking accuracy on test set
# Got 145 / 200 correct (72.50)
# acc = 0.725000
# Starting epoch 48 / 80
# t = 1, avg_loss = 0.4434
# t = 2, avg_loss = 0.4886
# t = 3, avg_loss = 0.4485
# t = 4, avg_loss = 0.4967
# t = 5, avg_loss = 0.5722
# t = 6, avg_loss = 0.5715
# t = 7, avg_loss = 0.5744
# t = 8, avg_loss = 0.5220
# t = 9, avg_loss = 0.5965
# t = 10, avg_loss = 0.5587
# t = 11, avg_loss = 0.6378
# t = 12, avg_loss = 0.6669
# t = 13, avg_loss = 0.5972
# Checking accuracy on test set
# Got 127 / 200 correct (63.50)
# acc = 0.635000
# Starting epoch 49 / 80
# t = 1, avg_loss = 0.5881
# t = 2, avg_loss = 0.5335
# t = 3, avg_loss = 0.5308
# t = 4, avg_loss = 0.5637
# t = 5, avg_loss = 0.5904
# t = 6, avg_loss = 0.5512
# t = 7, avg_loss = 0.5805
# t = 8, avg_loss = 0.4899
# t = 9, avg_loss = 0.5840
# t = 10, avg_loss = 0.4545
# t = 11, avg_loss = 0.4986
# t = 12, avg_loss = 0.5148
# t = 13, avg_loss = 0.6007
# Checking accuracy on test set
# Got 137 / 200 correct (68.50)
# acc = 0.685000
# Starting epoch 50 / 80
# t = 1, avg_loss = 0.6389
# t = 2, avg_loss = 0.4042
# t = 3, avg_loss = 0.5766
# t = 4, avg_loss = 0.4905
# t = 5, avg_loss = 0.5106
# t = 6, avg_loss = 0.4834
# t = 7, avg_loss = 0.5176
# t = 8, avg_loss = 0.6223
# t = 9, avg_loss = 0.5931
# t = 10, avg_loss = 0.4885
# t = 11, avg_loss = 0.5572
# t = 12, avg_loss = 0.5421
# t = 13, avg_loss = 0.6474
# Checking accuracy on test set
# Got 151 / 200 correct (75.50)
# acc = 0.755000
# Starting epoch 51 / 80
# t = 1, avg_loss = 0.5127
# t = 2, avg_loss = 0.6817
# t = 3, avg_loss = 0.5180
# t = 4, avg_loss = 0.4762
# t = 5, avg_loss = 0.6021
# t = 6, avg_loss = 0.4441
# t = 7, avg_loss = 0.6142
# t = 8, avg_loss = 0.5505
# t = 9, avg_loss = 0.5739
# t = 10, avg_loss = 0.5897
# t = 11, avg_loss = 0.5108
# t = 12, avg_loss = 0.3975
# t = 13, avg_loss = 0.5395
# Checking accuracy on test set
# Got 132 / 200 correct (66.00)
# acc = 0.660000
# Starting epoch 52 / 80
# t = 1, avg_loss = 0.5300
# t = 2, avg_loss = 0.5646
# t = 3, avg_loss = 0.4498
# t = 4, avg_loss = 0.6338
# t = 5, avg_loss = 0.7388
# t = 6, avg_loss = 0.5176
# t = 7, avg_loss = 0.5705
# t = 8, avg_loss = 0.4656
# t = 9, avg_loss = 0.5702
# t = 10, avg_loss = 0.4675
# t = 11, avg_loss = 0.5514
# t = 12, avg_loss = 0.5902
# t = 13, avg_loss = 0.4655
# Checking accuracy on test set
# Got 146 / 200 correct (73.00)
# acc = 0.730000
# Starting epoch 53 / 80
# t = 1, avg_loss = 0.4645
# t = 2, avg_loss = 0.4749
# t = 3, avg_loss = 0.5313
# t = 4, avg_loss = 0.6149
# t = 5, avg_loss = 0.4929
# t = 6, avg_loss = 0.5050
# t = 7, avg_loss = 0.5393
# t = 8, avg_loss = 0.4326
# t = 9, avg_loss = 0.5845
# t = 10, avg_loss = 0.5957
# t = 11, avg_loss = 0.4845
# t = 12, avg_loss = 0.5927
# t = 13, avg_loss = 0.4642
# Checking accuracy on test set
# Got 149 / 200 correct (74.50)
# acc = 0.745000
# Starting epoch 54 / 80
# t = 1, avg_loss = 0.4300
# t = 2, avg_loss = 0.5098
# t = 3, avg_loss = 0.5775
# t = 4, avg_loss = 0.5382
# t = 5, avg_loss = 0.5245
# t = 6, avg_loss = 0.4335
# t = 7, avg_loss = 0.5698
# t = 8, avg_loss = 0.4996

# %%
check_accuracy(model_gpu, valid_loader)

# %%
#! pip install torch-lr-finder -v --global-option="amp"
#from torch_lr_finder import LRFinder

#lr_finder = LRFinder(model_gpu, optimizer, loss_fn, device="cuda")

#lr_finder.range_test(train_loader, end_lr=1, num_iter=100, start_lr=1e-05)
#lr_finder.plot()

# %%
def retry_from_backup()
  model_gpu = model_base.type(gpu_dtype)
  print(model_gpu)
  loss_fn = nn.modules.loss.CrossEntropyLoss()
  optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay) 



  checkpoint = torch.load(MODEL_BACKUP_PATH)
  model_gpu.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch = checkpoint['epoch']
  loss = checkpoint['loss']
  print("starting from epoch: " + str(epoch))
  print("starting from loss: " + str(loss))
  print(checkpoint['model_state_dict'])
  print(checkpoint['optimizer_state_dict'])

  train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs, starting_from_epoch=epoch)
  check_accuracy(model_gpu, valid_loader)
#retry_from_backup()

# %%
import matplotlib.pyplot as plt

plt.plot([print_every*batch_size*(i+1) for i in range((len(avg_loss_list)))],avg_loss_list)
print("Loss:")
plt.show()

# %%
plt.plot([i+1 for i in range((len(acc_list)))],acc_list)
print("Accurancy:")
plt.show()

# %%
#%tensorboard --logdir {logs_base_dir}
