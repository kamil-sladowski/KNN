# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilo116/KNN/blob/master/KNN_ascending_layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import os
import csv
import sys
from random import shuffle
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
# %matplotlib inline
from sklearn.model_selection import train_test_split

import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
from torch.utils.data.sampler import SubsetRandomSampler

import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as T
import torchvision.transforms as transforms
import timeit

np.random.seed(4) 
torch.manual_seed(4) 
torch.cuda.manual_seed(4)

# %%
! git clone https://github.com/wang-chen/kervolution.git 

sys.path.append("kervolution/")
from kervolution import Kerv2d
# Out:
# Cloning into 'kervolution'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 53 (delta 2), reused 0 (delta 0), pack-reused 47
# Unpacking objects: 100% (53/53), done.

# %%
LIMIT_IMAGES_NUM = 1000
train_test_split_size = 0.2
image_resize = (100, 100)
batch_size = 64
num_workers = 0

out_1 = 16
out_2 = 32
out_3 = 64
out_4 = 128



k_size_1 = 3
padding_1 = 1
in_channels = 3

kernel_size = 3
num_epochs = 80

learning_rate = 0.00012
weight_decay = 0.08

MALIGNANT_DATASET = '/content/drive/My Drive/Colab_data/malignant/malignant/'
BENIGN_DATASET = '/content/drive/My Drive/Colab_data/benign/benign/'
DATA_FOLDER = '/content/drive/My Drive/Colab_data/'
model_backup_path = os.path.join(DATA_FOLDER, 'backup_model3') 
TRAIN_DATA_PER_CATEGORY = 101

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
benign_train_list = sorted(os.listdir(BENIGN_DATASET))[:LIMIT_IMAGES_NUM]
malignant_train_list = sorted(os.listdir(MALIGNANT_DATASET))[:LIMIT_IMAGES_NUM]

shuffle(benign_train_list)
shuffle(malignant_train_list)

test_benign_file_list = os.listdir(BENIGN_DATASET + 'test_set')[:TRAIN_DATA_PER_CATEGORY]
test_malignant_file_list = os.listdir(MALIGNANT_DATASET + 'test_set')[:TRAIN_DATA_PER_CATEGORY]

print(f"Number of training benign {len(benign_train_list)} images")
print(f"Number of training malignant {len(malignant_train_list)} images")
print(f"Number of test benign {len(test_benign_file_list)} images")
print(f"Number of test malignant {len(test_malignant_file_list)} images")

data_transforms = transforms.Compose([
    transforms.Resize(image_resize),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    #transforms.RandomRotation(45),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

data_transforms_test = transforms.Compose([
    transforms.Resize(image_resize),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Out:
# Number of training benign 1000 images
# Number of training malignant 1000 images
# Number of test benign 101 images
# Number of test malignant 101 images

# %%
class IsicDataset(Dataset):
    def __init__(self, data_folder, labeled_data, 
                 transform=transforms.Compose([transforms.ToTensor()]), datatype='train'):
        self.labeled_data = labeled_data
        self.transform = transform
        self.data_folder = data_folder
        self.datatype = datatype
        
        
    def __len__(self):
        return len(self.labeled_data)

    def __getitem__(self, index):
        label = self.labeled_data[index]
        test_set = ''
        if self.datatype == 'test':
          test_set = 'test_set'  
        if label == 0:
          image = Image.open(os.path.join(self.data_folder, "benign", "benign", test_set, index ))
        else:
          image = Image.open(os.path.join(self.data_folder, "malignant", "malignant", test_set, index ))
        image = self.transform(image)
        return image, label

    @property
    def labels(self):
      return self.labeled_data

# %%
avg_loss_list = []
acc_list = []

def prepare_dataset(benign_file_list, malignant_file_list, transform, datatype='train'):
  benign_dict = {filename: 0 for filename in benign_file_list}
  malignant_dict = {filename: 1 for filename in malignant_file_list}
  img_class_dict = {**benign_dict , **malignant_dict}
  labeled_data = pd.Series(img_class_dict)

  dataset = IsicDataset(DATA_FOLDER, labeled_data, transform=transform, datatype=datatype)
  print(dataset.labels)
  return dataset

def train(model, train_loader ,loss_fn, optimizer, num_epochs=1, starting_from_epoch=1):
    total_loss =0

    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch, num_epochs))
        model.train()

        for t, (x, y) in enumerate(train_loader):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())
            scores = model(x_var)
            loss = loss_fn(scores, y_var)
            total_loss += loss.data
            
            if (t + 1) % print_every == 0:
                avg_loss = total_loss/print_every
                print('t = %d, avg_loss = %.4f' % (t + 1, avg_loss) )
                avg_loss_list.append(avg_loss)
                total_loss = 0
                
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        acc = check_accuracy(model_gpu, valid_loader)
        print('acc = %f' %(acc))
        torch.save({
            'epoch': epoch,
            'model_state_dict': model_gpu.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss,
            'acc_list': acc_list,
            }, model_backup_path)
            
def check_accuracy(model, loader, datatype='train'):
    print(f'Checking accuracy on {datatype} set')   
    num_correct = 0
    num_samples = 0
    model.eval() 
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype))

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    if datatype is 'train':
      acc_list.append(acc)
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc
    
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size()
        return x.view(N, -1)

# %%
train_dataset = prepare_dataset(benign_train_list, malignant_train_list, data_transforms)

X_train, X_valid = train_test_split(train_dataset.labels, test_size=train_test_split_size)

print("number of training data: ",len(X_train))
print("number of valid  data: ",len(X_valid))

train_sampler = SubsetRandomSampler(list(X_train.index))
valid_sampler = SubsetRandomSampler(list(X_valid.index))

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
# Out:
# ISIC_0000816.jpeg    0
# ISIC_0000138.jpeg    0
# ISIC_0001293.jpeg    0
# ISIC_0000363.jpeg    0
# ISIC_0000273.jpeg    0
#                     ..
# ISIC_0011923.jpeg    1
# ISIC_0000171.jpeg    1
# ISIC_0014062.jpeg    1
# ISIC_0000440.jpeg    1
# ISIC_0011764.jpeg    1
# Length: 2000, dtype: int64
# number of training data:  1600
# number of valid  data:  400

# %%
test_dataset = prepare_dataset(test_benign_file_list, test_malignant_file_list, data_transforms_test, datatype='test')
test_part, _ = train_test_split(test_dataset.labels, test_size=1)
test_sampler = SubsetRandomSampler(list(test_part.index))
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=50, sampler=test_sampler, num_workers=num_workers)
# Out:
# ISIC_0000081.jpeg    0
# ISIC_0000033.jpeg    0
# ISIC_0000023.jpeg    0
# ISIC_0000137.jpeg    0
# ISIC_0000073.jpeg    0
#                     ..
# ISIC_0025783.jpg     1
# ISIC_0026604.jpg     1
# ISIC_0026754.jpg     1
# ISIC_0026847.jpg     1
# ISIC_0027060.jpg     1
# Length: 202, dtype: int64

# %%
print_every = 5
gpu_dtype = torch.cuda.FloatTensor


'''
Kerv2d
kervolution with following options:
kernel_type: [linear, polynomial, gaussian, etc.]
default is convolution:
          kernel_type --> linear,
balance, power, gamma is valid only when the kernel_type is specified
if learnable_kernel = True,  they just be the initial value of learable parameters
if learnable_kernel = False, they are the value of kernel_type's parameter
the parameter [power] cannot be learned due to integer limitation
dilation (int or tuple, optional): Spacing between kernel
elements. Default: 1
groups (int, optional): Number of blocked connections from input
channels to output channels. Default: 1
bias (bool, optional): If ``True``, adds a learnable bias to the output. Default: ``True``
kernel_type (str), Default: 'linear'
learnable_kernel (bool): Learnable kernel parameters.  Default: False 
balance: 0, 1
power: 3, 4, 5
gamma:
'''


model_base = nn.Sequential( 
                #nn.Conv2d(in_channels , out_1, padding= padding_1, kernel_size=k_size_1, stride=1),
                nn.Kerv2d(in_channels , out_1, padding=padding_1, dilation=1, groups=1, bias=True, 
                          kernel_type='polynomial', kernel_size=k_size_1, learnable_kernel=True,
                          kernel_regularizer=True, stride=1, balance=0.9, power=3, gamma=1
                          ), 
                #nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_1),
                nn.AvgPool2d(2, stride=2),
                nn.Conv2d(out_1 , out_2, padding= padding_1, kernel_size=k_size_1, stride=1), 
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_2),
                nn.MaxPool2d(2, stride=2),
                nn.Conv2d(out_2 , out_3, padding= padding_1, kernel_size=k_size_1, stride=1),  
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_3),
                nn.MaxPool2d(2, stride=2),
                nn.Conv2d(out_3 , out_4, padding= padding_1, kernel_size=k_size_1, stride=1),  
                nn.ReLU(inplace=True),
                nn.BatchNorm2d(out_4),
                nn.MaxPool2d(2, stride=2),
                nn.Dropout(0.5),
                Flatten(),
                nn.Linear(4608,64),
                nn.ReLU(inplace=True),
                nn.Linear(64,2)
            )
model_gpu = model_base.type(gpu_dtype)
print(model_gpu)
loss_fn = nn.modules.loss.CrossEntropyLoss()
#optimizer = optim.Adam(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay)
optimizer = optim.RMSprop(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay)
# Out:
# Sequential(
#   (0): Kerv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU(inplace=True)
#   (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (12): ReLU(inplace=True)
#   (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (15): Dropout(p=0.5, inplace=False)
#   (16): Flatten()
#   (17): Linear(in_features=4608, out_features=64, bias=True)
#   (18): ReLU(inplace=True)
#   (19): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=num_epochs)
# Out:
# Starting epoch 0 / 80
# t = 5, avg_loss = 0.8180
# t = 10, avg_loss = 0.5067
# t = 15, avg_loss = 0.4290
# t = 20, avg_loss = 0.4399
# t = 25, avg_loss = 0.4695
# Checking accuracy on train set
# Got 213 / 400 correct (53.25)
# acc = 0.532500
# Starting epoch 1 / 80
# t = 5, avg_loss = 0.3763
# t = 10, avg_loss = 0.3992
# t = 15, avg_loss = 0.3529
# t = 20, avg_loss = 0.3864
# t = 25, avg_loss = 0.3694
# Checking accuracy on train set
# Got 333 / 400 correct (83.25)
# acc = 0.832500
# Starting epoch 2 / 80
# t = 5, avg_loss = 0.3531
# t = 10, avg_loss = 0.3993
# t = 15, avg_loss = 0.3502
# t = 20, avg_loss = 0.2809
# t = 25, avg_loss = 0.3383
# Checking accuracy on train set
# Got 342 / 400 correct (85.50)
# acc = 0.855000
# Starting epoch 3 / 80
# t = 5, avg_loss = 0.3449
# t = 10, avg_loss = 0.3506
# t = 15, avg_loss = 0.3108
# t = 20, avg_loss = 0.2989
# t = 25, avg_loss = 0.2970
# Checking accuracy on train set
# Got 340 / 400 correct (85.00)
# acc = 0.850000
# Starting epoch 4 / 80
# t = 5, avg_loss = 0.3069
# t = 10, avg_loss = 0.3070
# t = 15, avg_loss = 0.3087
# t = 20, avg_loss = 0.2677
# t = 25, avg_loss = 0.3367
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 5 / 80
# t = 5, avg_loss = 0.2891
# t = 10, avg_loss = 0.3283
# t = 15, avg_loss = 0.2931
# t = 20, avg_loss = 0.2741
# t = 25, avg_loss = 0.3084
# Checking accuracy on train set
# Got 340 / 400 correct (85.00)
# acc = 0.850000
# Starting epoch 6 / 80
# t = 5, avg_loss = 0.2809
# t = 10, avg_loss = 0.2878
# t = 15, avg_loss = 0.2813
# t = 20, avg_loss = 0.2624
# t = 25, avg_loss = 0.2924
# Checking accuracy on train set
# Got 344 / 400 correct (86.00)
# acc = 0.860000
# Starting epoch 7 / 80
# t = 5, avg_loss = 0.2661
# t = 10, avg_loss = 0.2707
# t = 15, avg_loss = 0.2216
# t = 20, avg_loss = 0.2448
# t = 25, avg_loss = 0.3260
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 8 / 80
# t = 5, avg_loss = 0.2628
# t = 10, avg_loss = 0.3094
# t = 15, avg_loss = 0.2627
# t = 20, avg_loss = 0.2316
# t = 25, avg_loss = 0.2645
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 9 / 80
# t = 5, avg_loss = 0.2559
# t = 10, avg_loss = 0.2762
# t = 15, avg_loss = 0.2535
# t = 20, avg_loss = 0.2263
# t = 25, avg_loss = 0.2609
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 10 / 80
# t = 5, avg_loss = 0.1846
# t = 10, avg_loss = 0.2691
# t = 15, avg_loss = 0.2231
# t = 20, avg_loss = 0.2638
# t = 25, avg_loss = 0.2404
# Checking accuracy on train set
# Got 343 / 400 correct (85.75)
# acc = 0.857500
# Starting epoch 11 / 80
# t = 5, avg_loss = 0.2302
# t = 10, avg_loss = 0.2350
# t = 15, avg_loss = 0.2431
# t = 20, avg_loss = 0.2748
# t = 25, avg_loss = 0.2388
# Checking accuracy on train set
# Got 337 / 400 correct (84.25)
# acc = 0.842500
# Starting epoch 12 / 80
# t = 5, avg_loss = 0.2118
# t = 10, avg_loss = 0.1978
# t = 15, avg_loss = 0.2602
# t = 20, avg_loss = 0.2305
# t = 25, avg_loss = 0.2616
# Checking accuracy on train set
# Got 345 / 400 correct (86.25)
# acc = 0.862500
# Starting epoch 13 / 80
# t = 5, avg_loss = 0.2173
# t = 10, avg_loss = 0.2847
# t = 15, avg_loss = 0.2248
# t = 20, avg_loss = 0.2313
# t = 25, avg_loss = 0.1971
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 14 / 80
# t = 5, avg_loss = 0.2209
# t = 10, avg_loss = 0.1943
# t = 15, avg_loss = 0.2494
# t = 20, avg_loss = 0.2108
# t = 25, avg_loss = 0.2091
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 15 / 80
# t = 5, avg_loss = 0.1974
# t = 10, avg_loss = 0.2125
# t = 15, avg_loss = 0.2214
# t = 20, avg_loss = 0.2055
# t = 25, avg_loss = 0.2428
# Checking accuracy on train set
# Got 343 / 400 correct (85.75)
# acc = 0.857500
# Starting epoch 16 / 80
# t = 5, avg_loss = 0.1807
# t = 10, avg_loss = 0.2205
# t = 15, avg_loss = 0.2545
# t = 20, avg_loss = 0.1984
# t = 25, avg_loss = 0.2018
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 17 / 80
# t = 5, avg_loss = 0.1815
# t = 10, avg_loss = 0.1826
# t = 15, avg_loss = 0.2050
# t = 20, avg_loss = 0.2361
# t = 25, avg_loss = 0.2049
# Checking accuracy on train set
# Got 344 / 400 correct (86.00)
# acc = 0.860000
# Starting epoch 18 / 80
# t = 5, avg_loss = 0.1585
# t = 10, avg_loss = 0.2008
# t = 15, avg_loss = 0.2071
# t = 20, avg_loss = 0.1964
# t = 25, avg_loss = 0.2189
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 19 / 80
# t = 5, avg_loss = 0.2157
# t = 10, avg_loss = 0.2090
# t = 15, avg_loss = 0.1659
# t = 20, avg_loss = 0.1764
# t = 25, avg_loss = 0.1806
# Checking accuracy on train set
# Got 356 / 400 correct (89.00)
# acc = 0.890000
# Starting epoch 20 / 80
# t = 5, avg_loss = 0.1829
# t = 10, avg_loss = 0.2165
# t = 15, avg_loss = 0.1758
# t = 20, avg_loss = 0.1614
# t = 25, avg_loss = 0.1864
# Checking accuracy on train set
# Got 341 / 400 correct (85.25)
# acc = 0.852500
# Starting epoch 21 / 80
# t = 5, avg_loss = 0.1912
# t = 10, avg_loss = 0.1895
# t = 15, avg_loss = 0.1619
# t = 20, avg_loss = 0.1843
# t = 25, avg_loss = 0.2128
# Checking accuracy on train set
# Got 323 / 400 correct (80.75)
# acc = 0.807500
# Starting epoch 22 / 80
# t = 5, avg_loss = 0.2017
# t = 10, avg_loss = 0.2018
# t = 15, avg_loss = 0.1753
# t = 20, avg_loss = 0.1887
# t = 25, avg_loss = 0.1773
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 23 / 80
# t = 5, avg_loss = 0.1882
# t = 10, avg_loss = 0.1702
# t = 15, avg_loss = 0.1368
# t = 20, avg_loss = 0.1663
# t = 25, avg_loss = 0.2000
# Checking accuracy on train set
# Got 358 / 400 correct (89.50)
# acc = 0.895000
# Starting epoch 24 / 80
# t = 5, avg_loss = 0.1560
# t = 10, avg_loss = 0.1757
# t = 15, avg_loss = 0.1288
# t = 20, avg_loss = 0.1497
# t = 25, avg_loss = 0.2511
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 25 / 80
# t = 5, avg_loss = 0.1540
# t = 10, avg_loss = 0.2191
# t = 15, avg_loss = 0.1238
# t = 20, avg_loss = 0.1794
# t = 25, avg_loss = 0.1519
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 26 / 80
# t = 5, avg_loss = 0.1350
# t = 10, avg_loss = 0.1793
# t = 15, avg_loss = 0.1694
# t = 20, avg_loss = 0.1550
# t = 25, avg_loss = 0.1452
# Checking accuracy on train set
# Got 354 / 400 correct (88.50)
# acc = 0.885000
# Starting epoch 27 / 80
# t = 5, avg_loss = 0.1264
# t = 10, avg_loss = 0.1815
# t = 15, avg_loss = 0.2049
# t = 20, avg_loss = 0.1857
# t = 25, avg_loss = 0.1587
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 28 / 80
# t = 5, avg_loss = 0.1704
# t = 10, avg_loss = 0.1445
# t = 15, avg_loss = 0.1450
# t = 20, avg_loss = 0.1615
# t = 25, avg_loss = 0.1721
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 29 / 80
# t = 5, avg_loss = 0.1474
# t = 10, avg_loss = 0.1415
# t = 15, avg_loss = 0.1327
# t = 20, avg_loss = 0.1711
# t = 25, avg_loss = 0.1727
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 30 / 80
# t = 5, avg_loss = 0.1452
# t = 10, avg_loss = 0.1314
# t = 15, avg_loss = 0.1473
# t = 20, avg_loss = 0.1377
# t = 25, avg_loss = 0.1629
# Checking accuracy on train set
# Got 354 / 400 correct (88.50)
# acc = 0.885000
# Starting epoch 31 / 80
# t = 5, avg_loss = 0.0942
# t = 10, avg_loss = 0.1345
# t = 15, avg_loss = 0.1504
# t = 20, avg_loss = 0.1690
# t = 25, avg_loss = 0.1689
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 32 / 80
# t = 5, avg_loss = 0.1573
# t = 10, avg_loss = 0.1318
# t = 15, avg_loss = 0.1714
# t = 20, avg_loss = 0.1585
# t = 25, avg_loss = 0.1394
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 33 / 80
# t = 5, avg_loss = 0.1476
# t = 10, avg_loss = 0.1638
# t = 15, avg_loss = 0.1748
# t = 20, avg_loss = 0.1273
# t = 25, avg_loss = 0.1300
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 34 / 80
# t = 5, avg_loss = 0.1610
# t = 10, avg_loss = 0.1266
# t = 15, avg_loss = 0.1301
# t = 20, avg_loss = 0.1573
# t = 25, avg_loss = 0.1183
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 35 / 80
# t = 5, avg_loss = 0.1261
# t = 10, avg_loss = 0.1248
# t = 15, avg_loss = 0.1201
# t = 20, avg_loss = 0.1572
# t = 25, avg_loss = 0.1426
# Checking accuracy on train set
# Got 343 / 400 correct (85.75)
# acc = 0.857500
# Starting epoch 36 / 80
# t = 5, avg_loss = 0.1328
# t = 10, avg_loss = 0.1454
# t = 15, avg_loss = 0.1293
# t = 20, avg_loss = 0.1231
# t = 25, avg_loss = 0.0886
# Checking accuracy on train set
# Got 353 / 400 correct (88.25)
# acc = 0.882500
# Starting epoch 37 / 80
# t = 5, avg_loss = 0.1783
# t = 10, avg_loss = 0.1411
# t = 15, avg_loss = 0.1015
# t = 20, avg_loss = 0.1106
# t = 25, avg_loss = 0.1338
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 38 / 80
# t = 5, avg_loss = 0.1137
# t = 10, avg_loss = 0.1725
# t = 15, avg_loss = 0.1321
# t = 20, avg_loss = 0.1768
# t = 25, avg_loss = 0.1584
# Checking accuracy on train set
# Got 349 / 400 correct (87.25)
# acc = 0.872500
# Starting epoch 39 / 80
# t = 5, avg_loss = 0.1205
# t = 10, avg_loss = 0.1497
# t = 15, avg_loss = 0.1725
# t = 20, avg_loss = 0.1302
# t = 25, avg_loss = 0.1792
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 40 / 80
# t = 5, avg_loss = 0.1019
# t = 10, avg_loss = 0.1347
# t = 15, avg_loss = 0.1082
# t = 20, avg_loss = 0.1369
# t = 25, avg_loss = 0.1331
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 41 / 80
# t = 5, avg_loss = 0.1451
# t = 10, avg_loss = 0.1310
# t = 15, avg_loss = 0.1516
# t = 20, avg_loss = 0.0988
# t = 25, avg_loss = 0.1407
# Checking accuracy on train set
# Got 353 / 400 correct (88.25)
# acc = 0.882500
# Starting epoch 42 / 80
# t = 5, avg_loss = 0.0934
# t = 10, avg_loss = 0.1094
# t = 15, avg_loss = 0.1124
# t = 20, avg_loss = 0.1233
# t = 25, avg_loss = 0.1001
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 43 / 80
# t = 5, avg_loss = 0.1128
# t = 10, avg_loss = 0.0991
# t = 15, avg_loss = 0.1035
# t = 20, avg_loss = 0.1403
# t = 25, avg_loss = 0.1532
# Checking accuracy on train set
# Got 341 / 400 correct (85.25)
# acc = 0.852500
# Starting epoch 44 / 80
# t = 5, avg_loss = 0.1194
# t = 10, avg_loss = 0.1034
# t = 15, avg_loss = 0.0964
# t = 20, avg_loss = 0.1101
# t = 25, avg_loss = 0.1202
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 45 / 80
# t = 5, avg_loss = 0.1371
# t = 10, avg_loss = 0.1117
# t = 15, avg_loss = 0.1050
# t = 20, avg_loss = 0.1022
# t = 25, avg_loss = 0.0837
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 46 / 80
# t = 5, avg_loss = 0.0811
# t = 10, avg_loss = 0.0677
# t = 15, avg_loss = 0.1496
# t = 20, avg_loss = 0.1015
# t = 25, avg_loss = 0.1089
# Checking accuracy on train set
# Got 335 / 400 correct (83.75)
# acc = 0.837500
# Starting epoch 47 / 80
# t = 5, avg_loss = 0.1224
# t = 10, avg_loss = 0.0861
# t = 15, avg_loss = 0.1191
# t = 20, avg_loss = 0.1113
# t = 25, avg_loss = 0.1110
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 48 / 80
# t = 5, avg_loss = 0.1299
# t = 10, avg_loss = 0.1017
# t = 15, avg_loss = 0.1089
# t = 20, avg_loss = 0.1165
# t = 25, avg_loss = 0.0995
# Checking accuracy on train set
# Got 356 / 400 correct (89.00)
# acc = 0.890000
# Starting epoch 49 / 80
# t = 5, avg_loss = 0.1029
# t = 10, avg_loss = 0.0956
# t = 15, avg_loss = 0.1090
# t = 20, avg_loss = 0.0706
# t = 25, avg_loss = 0.1063
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 50 / 80
# t = 5, avg_loss = 0.1081
# t = 10, avg_loss = 0.0744
# t = 15, avg_loss = 0.0790
# t = 20, avg_loss = 0.1354
# t = 25, avg_loss = 0.1114
# Checking accuracy on train set
# Got 342 / 400 correct (85.50)
# acc = 0.855000
# Starting epoch 51 / 80
# t = 5, avg_loss = 0.0984
# t = 10, avg_loss = 0.0879
# t = 15, avg_loss = 0.0901
# t = 20, avg_loss = 0.0765
# t = 25, avg_loss = 0.1693
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 52 / 80
# t = 5, avg_loss = 0.0905
# t = 10, avg_loss = 0.0695
# t = 15, avg_loss = 0.1043
# t = 20, avg_loss = 0.1230
# t = 25, avg_loss = 0.1281
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 53 / 80
# t = 5, avg_loss = 0.1150
# t = 10, avg_loss = 0.0831
# t = 15, avg_loss = 0.1505
# t = 20, avg_loss = 0.1192
# t = 25, avg_loss = 0.1439
# Checking accuracy on train set
# Got 349 / 400 correct (87.25)
# acc = 0.872500
# Starting epoch 54 / 80
# t = 5, avg_loss = 0.0754
# t = 10, avg_loss = 0.0819
# t = 15, avg_loss = 0.0785
# t = 20, avg_loss = 0.0859
# t = 25, avg_loss = 0.1589
# Checking accuracy on train set
# Got 346 / 400 correct (86.50)
# acc = 0.865000
# Starting epoch 55 / 80
# t = 5, avg_loss = 0.0881
# t = 10, avg_loss = 0.0700
# t = 15, avg_loss = 0.0729
# t = 20, avg_loss = 0.1561
# t = 25, avg_loss = 0.1194
# Checking accuracy on train set
# Got 349 / 400 correct (87.25)
# acc = 0.872500
# Starting epoch 56 / 80
# t = 5, avg_loss = 0.0885
# t = 10, avg_loss = 0.0862
# t = 15, avg_loss = 0.1187
# t = 20, avg_loss = 0.0890
# t = 25, avg_loss = 0.0844
# Checking accuracy on train set
# Got 357 / 400 correct (89.25)
# acc = 0.892500
# Starting epoch 57 / 80
# t = 5, avg_loss = 0.0828
# t = 10, avg_loss = 0.1112
# t = 15, avg_loss = 0.1150
# t = 20, avg_loss = 0.1021
# t = 25, avg_loss = 0.0996
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 58 / 80
# t = 5, avg_loss = 0.0841
# t = 10, avg_loss = 0.1323
# t = 15, avg_loss = 0.0805
# t = 20, avg_loss = 0.0780
# t = 25, avg_loss = 0.0765
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 59 / 80
# t = 5, avg_loss = 0.0747
# t = 10, avg_loss = 0.0768
# t = 15, avg_loss = 0.0937
# t = 20, avg_loss = 0.1010
# t = 25, avg_loss = 0.0961
# Checking accuracy on train set
# Got 356 / 400 correct (89.00)
# acc = 0.890000
# Starting epoch 60 / 80
# t = 5, avg_loss = 0.0746
# t = 10, avg_loss = 0.0987
# t = 15, avg_loss = 0.1594
# t = 20, avg_loss = 0.0640
# t = 25, avg_loss = 0.0756
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 61 / 80
# t = 5, avg_loss = 0.0929
# t = 10, avg_loss = 0.0947
# t = 15, avg_loss = 0.0643
# t = 20, avg_loss = 0.0937
# t = 25, avg_loss = 0.1174
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 62 / 80
# t = 5, avg_loss = 0.0773
# t = 10, avg_loss = 0.0973
# t = 15, avg_loss = 0.0934
# t = 20, avg_loss = 0.0846
# t = 25, avg_loss = 0.1114
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 63 / 80
# t = 5, avg_loss = 0.0748
# t = 10, avg_loss = 0.1034
# t = 15, avg_loss = 0.0968
# t = 20, avg_loss = 0.0698
# t = 25, avg_loss = 0.0693
# Checking accuracy on train set
# Got 354 / 400 correct (88.50)
# acc = 0.885000
# Starting epoch 64 / 80
# t = 5, avg_loss = 0.0768
# t = 10, avg_loss = 0.1120
# t = 15, avg_loss = 0.1083
# t = 20, avg_loss = 0.1227
# t = 25, avg_loss = 0.0555
# Checking accuracy on train set
# Got 348 / 400 correct (87.00)
# acc = 0.870000
# Starting epoch 65 / 80
# t = 5, avg_loss = 0.0779
# t = 10, avg_loss = 0.1018
# t = 15, avg_loss = 0.0830
# t = 20, avg_loss = 0.0624
# t = 25, avg_loss = 0.0764
# Checking accuracy on train set
# Got 357 / 400 correct (89.25)
# acc = 0.892500
# Starting epoch 66 / 80
# t = 5, avg_loss = 0.0537
# t = 10, avg_loss = 0.0829
# t = 15, avg_loss = 0.0723
# t = 20, avg_loss = 0.0865
# t = 25, avg_loss = 0.0909
# Checking accuracy on train set
# Got 354 / 400 correct (88.50)
# acc = 0.885000
# Starting epoch 67 / 80
# t = 5, avg_loss = 0.0762
# t = 10, avg_loss = 0.1065
# t = 15, avg_loss = 0.0623
# t = 20, avg_loss = 0.0470
# t = 25, avg_loss = 0.1411
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 68 / 80
# t = 5, avg_loss = 0.1039
# t = 10, avg_loss = 0.0537
# t = 15, avg_loss = 0.0750
# t = 20, avg_loss = 0.0941
# t = 25, avg_loss = 0.0971
# Checking accuracy on train set
# Got 357 / 400 correct (89.25)
# acc = 0.892500
# Starting epoch 69 / 80
# t = 5, avg_loss = 0.0675
# t = 10, avg_loss = 0.0983
# t = 15, avg_loss = 0.0660
# t = 20, avg_loss = 0.0912
# t = 25, avg_loss = 0.1245
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 70 / 80
# t = 5, avg_loss = 0.0595
# t = 10, avg_loss = 0.0643
# t = 15, avg_loss = 0.0858
# t = 20, avg_loss = 0.0676
# t = 25, avg_loss = 0.0743
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 71 / 80
# t = 5, avg_loss = 0.0757
# t = 10, avg_loss = 0.1124
# t = 15, avg_loss = 0.0630
# t = 20, avg_loss = 0.1022
# t = 25, avg_loss = 0.0711
# Checking accuracy on train set
# Got 356 / 400 correct (89.00)
# acc = 0.890000
# Starting epoch 72 / 80
# t = 5, avg_loss = 0.0775
# t = 10, avg_loss = 0.0696
# t = 15, avg_loss = 0.1256
# t = 20, avg_loss = 0.0751
# t = 25, avg_loss = 0.0895
# Checking accuracy on train set
# Got 345 / 400 correct (86.25)
# acc = 0.862500
# Starting epoch 73 / 80
# t = 5, avg_loss = 0.0618
# t = 10, avg_loss = 0.0488
# t = 15, avg_loss = 0.0959
# t = 20, avg_loss = 0.0693
# t = 25, avg_loss = 0.0811
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 74 / 80
# t = 5, avg_loss = 0.0445
# t = 10, avg_loss = 0.0511
# t = 15, avg_loss = 0.0622
# t = 20, avg_loss = 0.0719
# t = 25, avg_loss = 0.0827
# Checking accuracy on train set
# Got 356 / 400 correct (89.00)
# acc = 0.890000
# Starting epoch 75 / 80
# t = 5, avg_loss = 0.0575
# t = 10, avg_loss = 0.0881
# t = 15, avg_loss = 0.0839
# t = 20, avg_loss = 0.0846
# t = 25, avg_loss = 0.1080
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 76 / 80
# t = 5, avg_loss = 0.0744
# t = 10, avg_loss = 0.0523
# t = 15, avg_loss = 0.0626
# t = 20, avg_loss = 0.0663
# t = 25, avg_loss = 0.0665
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 77 / 80
# t = 5, avg_loss = 0.1044
# t = 10, avg_loss = 0.0869
# t = 15, avg_loss = 0.0872
# t = 20, avg_loss = 0.0432
# t = 25, avg_loss = 0.0931
# Checking accuracy on train set
# Got 354 / 400 correct (88.50)
# acc = 0.885000
# Starting epoch 78 / 80
# t = 5, avg_loss = 0.0612
# t = 10, avg_loss = 0.0646
# t = 15, avg_loss = 0.0704
# t = 20, avg_loss = 0.0613
# t = 25, avg_loss = 0.0950
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 79 / 80
# t = 5, avg_loss = 0.0608
# t = 10, avg_loss = 0.0713
# t = 15, avg_loss = 0.0813
# t = 20, avg_loss = 0.0751
# t = 25, avg_loss = 0.0636
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000

# %%
def plot_accurancy(acc_list):
  plt.plot([i+1 for i in range((len(acc_list)))],acc_list)
  print("Accurancy:")
  plt.show()

def plot_loss_function(avg_loss_list):
  plt.plot([print_every*batch_size*(i+1) for i in range((len(avg_loss_list)))],avg_loss_list)
  print("Loss:")
  plt.show()

# %%
plot_accurancy(acc_list)
plot_loss_function(avg_loss_list)
# Out:
# Accurancy:
# Loss:

# %%
check_accuracy(model_gpu, test_loader, datatype='test')
# Out:
# Checking accuracy on test set
# Got 183 / 201 correct (91.04)
# 0.9104477611940298

# %%
def retry_from_backup():
  model_gpu = model_base.type(gpu_dtype)
  print(model_gpu)
  loss_fn = nn.modules.loss.CrossEntropyLoss()
  optimizer = optim.RMSprop(model_gpu.parameters(), lr = learning_rate, weight_decay=weight_decay)

  checkpoint = torch.load(model_backup_path)
  model_gpu.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  epoch = checkpoint['epoch']
  loss = checkpoint['loss']
  acc_list = checkpoint['acc_list']
  print("starting from epoch: " + str(epoch))
  print("starting from loss: " + str(loss))
  print(acc_list)
  
  
  train(model_gpu, train_loader ,loss_fn, optimizer, num_epochs=20, starting_from_epoch=epoch)
  check_accuracy(model_gpu, valid_loader)

  plot_accurancy(acc_list)
  plot_loss_function(avg_loss_list)

# %%
retry_from_backup()
# Out:
# Sequential(
#   (0): Kerv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): ReLU(inplace=True)
#   (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (12): ReLU(inplace=True)
#   (13): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (15): Dropout(p=0.5, inplace=False)
#   (16): Flatten()
#   (17): Linear(in_features=4608, out_features=64, bias=True)
#   (18): ReLU(inplace=True)
#   (19): Linear(in_features=64, out_features=2, bias=True)
# )
# starting from epoch: 79
# starting from loss: tensor(0.0446, device='cuda:0', requires_grad=True)
# [0.5325, 0.8325, 0.855, 0.85, 0.8675, 0.85, 0.86, 0.875, 0.875, 0.865, 0.8575, 0.8425, 0.8625, 0.865, 0.8775, 0.8575, 0.8675, 0.86, 0.865, 0.89, 0.8525, 0.8075, 0.8775, 0.895, 0.8675, 0.8875, 0.885, 0.88, 0.88, 0.88, 0.885, 0.865, 0.865, 0.875, 0.8775, 0.8575, 0.8825, 0.875, 0.8725, 0.8875, 0.8675, 0.8825, 0.88, 0.8525, 0.875, 0.8875, 0.8375, 0.8775, 0.89, 0.8675, 0.855, 0.88, 0.865, 0.8725, 0.865, 0.8725, 0.8925, 0.875, 0.875, 0.89, 0.88, 0.8775, 0.875, 0.885, 0.87, 0.8925, 0.885, 0.8875, 0.8925, 0.8775, 0.8675, 0.89, 0.8625, 0.8875, 0.89, 0.88, 0.88, 0.885, 0.8875, 0.88]
# Starting epoch 0 / 20
# t = 5, avg_loss = 0.0575
# t = 10, avg_loss = 0.1020
# t = 15, avg_loss = 0.0627
# t = 20, avg_loss = 0.0880
# t = 25, avg_loss = 0.0594
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 1 / 20
# t = 5, avg_loss = 0.0606
# t = 10, avg_loss = 0.1096
# t = 15, avg_loss = 0.0978
# t = 20, avg_loss = 0.1052
# t = 25, avg_loss = 0.0605
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 2 / 20
# t = 5, avg_loss = 0.0633
# t = 10, avg_loss = 0.0500
# t = 15, avg_loss = 0.0458
# t = 20, avg_loss = 0.0560
# t = 25, avg_loss = 0.0529
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 3 / 20
# t = 5, avg_loss = 0.0529
# t = 10, avg_loss = 0.1021
# t = 15, avg_loss = 0.1170
# t = 20, avg_loss = 0.0748
# t = 25, avg_loss = 0.0580
# Checking accuracy on train set
# Got 348 / 400 correct (87.00)
# acc = 0.870000
# Starting epoch 4 / 20
# t = 5, avg_loss = 0.0418
# t = 10, avg_loss = 0.0671
# t = 15, avg_loss = 0.1094
# t = 20, avg_loss = 0.0739
# t = 25, avg_loss = 0.0725
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 5 / 20
# t = 5, avg_loss = 0.0767
# t = 10, avg_loss = 0.0719
# t = 15, avg_loss = 0.1202
# t = 20, avg_loss = 0.0926
# t = 25, avg_loss = 0.1012
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 6 / 20
# t = 5, avg_loss = 0.0703
# t = 10, avg_loss = 0.0710
# t = 15, avg_loss = 0.0633
# t = 20, avg_loss = 0.0751
# t = 25, avg_loss = 0.0728
# Checking accuracy on train set
# Got 353 / 400 correct (88.25)
# acc = 0.882500
# Starting epoch 7 / 20
# t = 5, avg_loss = 0.0887
# t = 10, avg_loss = 0.0662
# t = 15, avg_loss = 0.0667
# t = 20, avg_loss = 0.1085
# t = 25, avg_loss = 0.0608
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 8 / 20
# t = 5, avg_loss = 0.0890
# t = 10, avg_loss = 0.0506
# t = 15, avg_loss = 0.0731
# t = 20, avg_loss = 0.0613
# t = 25, avg_loss = 0.1088
# Checking accuracy on train set
# Got 356 / 400 correct (89.00)
# acc = 0.890000
# Starting epoch 9 / 20
# t = 5, avg_loss = 0.0866
# t = 10, avg_loss = 0.0658
# t = 15, avg_loss = 0.0728
# t = 20, avg_loss = 0.0754
# t = 25, avg_loss = 0.0444
# Checking accuracy on train set
# Got 347 / 400 correct (86.75)
# acc = 0.867500
# Starting epoch 10 / 20
# t = 5, avg_loss = 0.0332
# t = 10, avg_loss = 0.0687
# t = 15, avg_loss = 0.0557
# t = 20, avg_loss = 0.0563
# t = 25, avg_loss = 0.0504
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 11 / 20
# t = 5, avg_loss = 0.0587
# t = 10, avg_loss = 0.0534
# t = 15, avg_loss = 0.0895
# t = 20, avg_loss = 0.1167
# t = 25, avg_loss = 0.1032
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 12 / 20
# t = 5, avg_loss = 0.0514
# t = 10, avg_loss = 0.0549
# t = 15, avg_loss = 0.0660
# t = 20, avg_loss = 0.0958
# t = 25, avg_loss = 0.0584
# Checking accuracy on train set
# Got 354 / 400 correct (88.50)
# acc = 0.885000
# Starting epoch 13 / 20
# t = 5, avg_loss = 0.0584
# t = 10, avg_loss = 0.0716
# t = 15, avg_loss = 0.0739
# t = 20, avg_loss = 0.0521
# t = 25, avg_loss = 0.0680
# Checking accuracy on train set
# Got 350 / 400 correct (87.50)
# acc = 0.875000
# Starting epoch 14 / 20
# t = 5, avg_loss = 0.0605
# t = 10, avg_loss = 0.0670
# t = 15, avg_loss = 0.0600
# t = 20, avg_loss = 0.0880
# t = 25, avg_loss = 0.0772
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 15 / 20
# t = 5, avg_loss = 0.1011
# t = 10, avg_loss = 0.0767
# t = 15, avg_loss = 0.0813
# t = 20, avg_loss = 0.0763
# t = 25, avg_loss = 0.0835
# Checking accuracy on train set
# Got 353 / 400 correct (88.25)
# acc = 0.882500
# Starting epoch 16 / 20
# t = 5, avg_loss = 0.0412
# t = 10, avg_loss = 0.0646
# t = 15, avg_loss = 0.0819
# t = 20, avg_loss = 0.0738
# t = 25, avg_loss = 0.0449
# Checking accuracy on train set
# Got 351 / 400 correct (87.75)
# acc = 0.877500
# Starting epoch 17 / 20
# t = 5, avg_loss = 0.0380
# t = 10, avg_loss = 0.1005
# t = 15, avg_loss = 0.0810
# t = 20, avg_loss = 0.0774
# t = 25, avg_loss = 0.0630
# Checking accuracy on train set
# Got 355 / 400 correct (88.75)
# acc = 0.887500
# Starting epoch 18 / 20
# t = 5, avg_loss = 0.0622
# t = 10, avg_loss = 0.1053
# t = 15, avg_loss = 0.1120
# t = 20, avg_loss = 0.0541
# t = 25, avg_loss = 0.0558
# Checking accuracy on train set
# Got 352 / 400 correct (88.00)
# acc = 0.880000
# Starting epoch 19 / 20
# t = 5, avg_loss = 0.0521
# t = 10, avg_loss = 0.0455
# t = 15, avg_loss = 0.0432
# t = 20, avg_loss = 0.0736
# t = 25, avg_loss = 0.1193
# Checking accuracy on train set
# Got 357 / 400 correct (89.25)
# acc = 0.892500
# Checking accuracy on train set
# Got 357 / 400 correct (89.25)
# Accurancy:
# Loss:

# %%
check_accuracy(model_gpu, test_loader, datatype='test')
plot_accurancy(acc_list)
plot_loss_function(avg_loss_list)
# Out:
# Checking accuracy on test set
# Got 185 / 201 correct (92.04)
# Accurancy:
# Loss:

# %%
  print(acc_list)
# Out:
# [0.5325, 0.8325, 0.855, 0.85, 0.8675, 0.85, 0.86, 0.875, 0.875, 0.865, 0.8575, 0.8425, 0.8625, 0.865, 0.8775, 0.8575, 0.8675, 0.86, 0.865, 0.89, 0.8525, 0.8075, 0.8775, 0.895, 0.8675, 0.8875, 0.885, 0.88, 0.88, 0.88, 0.885, 0.865, 0.865, 0.875, 0.8775, 0.8575, 0.8825, 0.875, 0.8725, 0.8875, 0.8675, 0.8825, 0.88, 0.8525, 0.875, 0.8875, 0.8375, 0.8775, 0.89, 0.8675, 0.855, 0.88, 0.865, 0.8725, 0.865, 0.8725, 0.8925, 0.875, 0.875, 0.89, 0.88, 0.8775, 0.875, 0.885, 0.87, 0.8925, 0.885, 0.8875, 0.8925, 0.8775, 0.8675, 0.89, 0.8625, 0.8875, 0.89, 0.88, 0.88, 0.885, 0.8875, 0.88, 0.88, 0.88, 0.88, 0.87, 0.8875, 0.8775, 0.8825, 0.8875, 0.89, 0.8675, 0.8775, 0.8875, 0.885, 0.875, 0.8875, 0.8825, 0.8775, 0.8875, 0.88, 0.8925, 0.8925]
